# %%
import os
import pandas as pd
from tqdm import tqdm

def read_slice_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image slice files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)
        mask_path = mask_path.split(".")[0] + ".tiff"

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask slice folders
image_slice_folder = "/kaggle/input/lits-slices/kaggle/working/images"
mask_slice_folder = "/kaggle/input/lits-slices/kaggle/working/masks"

# Read slice paths and create a DataFrame
df_slices = read_slice_paths(image_slice_folder, mask_slice_folder)
# Out:
# 100%|██████████| 19131/19131 [02:25<00:00, 131.46it/s]

# %%
df_slices.head(5)
# Out:
#                                                Image  \
# 0  /kaggle/input/lits-slices/kaggle/working/image...
# 1  /kaggle/input/lits-slices/kaggle/working/image...
# 2  /kaggle/input/lits-slices/kaggle/working/image...
# 3  /kaggle/input/lits-slices/kaggle/working/image...
# 4  /kaggle/input/lits-slices/kaggle/working/image...
#
#                                                 Mask
# 0  /kaggle/input/lits-slices/kaggle/working/masks...
# 1  /kaggle/input/lits-slices/kaggle/working/masks...
# 2  /kaggle/input/lits-slices/kaggle/working/masks...
# 3  /kaggle/input/lits-slices/kaggle/working/masks...
# 4  /kaggle/input/lits-slices/kaggle/working/masks...

# %%
#sanity check
print(df_slices["Image"][0])
print(df_slices["Mask"][0])
# Out:
# /kaggle/input/lits-slices/kaggle/working/images/volume-126_slice_228.jpg
#
# /kaggle/input/lits-slices/kaggle/working/masks/volume-126_slice_228.tiff

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                #mask = mask.astype(np.int32)
    

            augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        #masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        masks = np.array(tf.one_hot(masks, 3, dtype = tf.float32))
        return  images, masks

# Example usage of the CustomDataGenerator
train_generator = CustomDataGenerator(df_slices, batch_size=8, image_size=(256, 256), shuffle=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import matplotlib.pyplot as plt

# Load a single batch
batch = train_generator[0]  # Assuming you want to load the first batch

# Extract images and labels from the batch
images, masks = batch

# Display the images and masks
n_images_to_display = len(images)
fig, ax = plt.subplots(n_images_to_display, 2, figsize=(10, 20))

for i in range(n_images_to_display):
    ax[i, 0].imshow(images[i], cmap='bone')
    #print(np.max(images[i]))
    ax[i, 0].set_title('Image')
    ax[i, 1].imshow(masks[i], cmap='bone')
    #print(np.max(masks[i]))
    ax[i, 1].set_title('Mask')

    ax[i, 0].axis('off')
    ax[i, 1].axis('off')
plt.show()

# %%
import cv2
import pandas as pd

# Assuming df_slices is your DataFrame with "Image" and "Mask" columns
# Add the "Num_Classes" column with default value 0
df_slices["Num_Classes"] = 0

# Function to read the mask using cv2 and return the number of unique classes
def read_mask_and_count_classes(mask_path):
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    mask = mask.astype(np.int32)
    val, counts = np.unique(mask, return_counts=True)
    return len(counts)

# Apply the function to each row in the DataFrame
tqdm.pandas(desc="Processing Masks", unit="mask")
df_slices["Num_Classes"] = df_slices["Mask"].progress_apply(read_mask_and_count_classes)
# Out:
# Processing Masks: 100%|██████████| 19131/19131 [05:23<00:00, 59.05mask/s]

# %%
df_slices.head(5)
# Out:
#                                                Image  \
# 0  /kaggle/input/lits-slices/kaggle/working/image...
# 1  /kaggle/input/lits-slices/kaggle/working/image...
# 2  /kaggle/input/lits-slices/kaggle/working/image...
# 3  /kaggle/input/lits-slices/kaggle/working/image...
# 4  /kaggle/input/lits-slices/kaggle/working/image...
#
#                                                 Mask  Num_Classes
# 0  /kaggle/input/lits-slices/kaggle/working/masks...            3
# 1  /kaggle/input/lits-slices/kaggle/working/masks...            3
# 2  /kaggle/input/lits-slices/kaggle/working/masks...            2
# 3  /kaggle/input/lits-slices/kaggle/working/masks...            3
# 4  /kaggle/input/lits-slices/kaggle/working/masks...            2

# %%
from sklearn.model_selection import train_test_split

df_shuffled = df_slices.sample(frac=1, random_state=42)

df_train, df_temp = train_test_split(df_shuffled, test_size=0.30, stratify=df_shuffled["Num_Classes"], random_state=42)
df_val, df_test = train_test_split(df_temp, test_size=0.6, stratify=df_temp["Num_Classes"], random_state=42)

# %%
unique_values = df_slices['Num_Classes'].unique()
print("Unique values in 'Num_Classes' column:", unique_values)
value_counts = df_slices['Num_Classes'].value_counts(normalize=True)
print("\nRatio of each unique value in 'num_classes' column:",value_counts)
# Out:
# Unique values in 'Num_Classes' column: [3 2]
#
#
#
# Ratio of each unique value in 'num_classes' column: Num_Classes
#
# 2    0.624536
#
# 3    0.375464
#
# Name: proportion, dtype: float64

# %%
unique_values = df_train['Num_Classes'].unique()
print("Unique values in 'Num_Classes' column:", unique_values)
value_counts = df_train['Num_Classes'].value_counts(normalize=True)
print("\nRatio of each unique value in 'num_classes' column:",value_counts)
# Out:
# Unique values in 'Num_Classes' column: [2 3]
#
#
#
# Ratio of each unique value in 'num_classes' column: Num_Classes
#
# 2    0.624524
#
# 3    0.375476
#
# Name: proportion, dtype: float64

# %%
unique_values = df_val['Num_Classes'].unique()
print("Unique values in 'Num_Classes' column:", unique_values)
value_counts = df_val['Num_Classes'].value_counts(normalize=True)
print("\nRatio of each unique value in 'num_classes' column:",value_counts)
# Out:
# Unique values in 'Num_Classes' column: [2 3]
#
#
#
# Ratio of each unique value in 'num_classes' column: Num_Classes
#
# 2    0.624564
#
# 3    0.375436
#
# Name: proportion, dtype: float64

# %%
unique_values = df_test['Num_Classes'].unique()
print("Unique values in 'Num_Classes' column:", unique_values)
value_counts = df_test['Num_Classes'].value_counts(normalize=True)
print("\nRatio of each unique value in 'num_classes' column:",value_counts)
# Out:
# Unique values in 'Num_Classes' column: [3 2]
#
#
#
# Ratio of each unique value in 'num_classes' column: Num_Classes
#
# 2    0.624564
#
# 3    0.375436
#
# Name: proportion, dtype: float64

# %%
# bar plot
from matplotlib import pyplot as plt
sizes = [len(df_train), len(df_val), len(df_test)]
labels = ['Train', 'Validation', 'Test']

plt.bar(labels, sizes, color=['blue', 'orange', 'green'])
plt.xlabel('Data Split')
plt.ylabel('Number of Samples')
plt.title('Dataset Split: Train, Validation')
plt.show()

# %% [markdown]
# # Model Architecture and Helper blocks

# %%
#GCSE Block...from the GCSER UNET (Mukherjee et al.)
def GCSE(input_tensor, ratio=16):


    # Compute the global statistics (mean and std deviation) along the channel axis.
    mean = tf.reduce_mean(input_tensor, axis=[1, 2], keepdims=True)
    std = tf.math.reduce_std(input_tensor, axis=[1, 2], keepdims=True)

    # Compute channel-wise attention using a convolutional neural network.
    attn_channel = tf.concat([mean, std], axis=-1)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1] // ratio, kernel_size=(1, 1), activation='relu')(attn_channel)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1], kernel_size=(1, 1), activation='sigmoid')(attn_channel)

    # Compute spatial attention using global information from the input tensor.
    global_info = tf.reduce_mean(input_tensor, axis=-1, keepdims=True)
    attn_spatial = tf.keras.layers.Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(global_info)

    # Combine channel-wise and spatial attention.
    attn = tf.keras.layers.Multiply()([attn_channel,attn_spatial])

    # Multiply the input tensor by the learned attention weights.
    output_tensor = tf.keras.layers.Multiply()([input_tensor,attn])

    return output_tensor

# %%
def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=3, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=5, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=7, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
from tensorflow.keras.applications import ResNet50
def build_encoder2(inputs):

    s=[]
    """ Pre-trained ResNet50 Model """
    resnet50= ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
    for layer in resnet50.layers:
        layer.trainable = True


    """ Encoder """
    s1 = resnet50.get_layer("model_input").output    
    s.append(s1)
    s2 = resnet50.get_layer("conv1_relu").output   
    s.append(s2)
    s3 = resnet50.get_layer("conv2_block3_out").output  
    s.append(s3)
    s4 = resnet50.get_layer("conv3_block4_out").output  
    s.append(s4)

    """ Bridge """
    #b1 = resnet50.get_layer("conv4_block6_out").output 
    b = resnet50.get_layer("conv4_block2_out").output 
    b = ASPP(b,128)
    
    encoder2 = Model(inputs,outputs=[s,b],name = "encoder2")

    return encoder2

# %% [markdown]
# # Asymmetric architecture

# %%
# Code for W-Net

from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D,Conv2DTranspose, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input, ZeroPadding2D,Dropout,Dense,MaxPooling2D,Reshape,Multiply,GlobalAveragePooling2D,AveragePooling2D
from tensorflow.keras.models import Model


"""def complementary_loss(y_true, y_pred):
    mse_loss = tf.reduce_mean(tf.square(y_true - y_pred))
    return tf.math.sigmoid(mse_loss)"""
def complementary_loss(feature_map1,feature_map2):
    # Normalize the feature maps to [0, 1]
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    m1 = tf.reduce_mean(feature_map1)
    m2  = tf.reduce_mean(feature_map2)

    return tf.math.sigmoid(tf.abs(m1-m2))


def batchnorm_relu(inputs):
    x = BatchNormalization()(inputs)
    #x = Activation("relu")(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    return x

def residual_block(inputs, num_filters):
    """ Convolutional Layer """
    x = batchnorm_relu(inputs)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
    x = Dropout(0.1)(x)
    x = batchnorm_relu(x)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)


    """ Shortcut Connection """
    s = Conv2D(num_filters, 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = x + s
    return x

def decoder_block(inputs, s1,s2, num_filters):
    x = Conv2DTranspose(num_filters,2, strides=(2,2), kernel_initializer="he_normal",padding = "same")(inputs)
    x = Concatenate()([x,s1,s2])
    x = residual_block(x, num_filters)
    x = GCSE(x)
    return x
def build_encoder1(inputs,f):
    
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = batchnorm_relu(x)
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(x)
    s = Conv2D(f[0], 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)

    c1 = x + s
    c1 = GCSE(c1)
    p1 = MaxPooling2D((2,2))(c1)
    s1 = c1

    c2 = residual_block(p1, f[1])
    c2 = GCSE(c2)
    p2 = MaxPooling2D((2,2))(c2)
    s2 = c2

    c3 = residual_block(p2, f[2])
    c3 = GCSE(c3)
    p3 = MaxPooling2D((2,2))(c3)
    s3 = c3

    c4 = residual_block(p3, f[3])
    c4 = GCSE(c4)
    p4 = MaxPooling2D((2,2))(c4)
    s4 = c4
    
    s_ = [s1,s2,s3,s4]
    """ Bridge """
    b = ASPP(p4,128)
    encoder1 = Model(inputs,outputs=[s_,b],name="encoder1")
    return encoder1

    
    

def build_WNet(input_shape):
    f = [16,32,64,128]

    inputs = Input(input_shape,name="model_input")
    encoder1 = build_encoder1(inputs,f)
    encoder2 = build_encoder2(inputs)
    s1,b1 = encoder1(inputs)
    s2,b2 = encoder2(inputs)

    b = Concatenate()([b1,b2])

    """ Decoder 1, 2, 3 """
    d1 = decoder_block(b, s2[3],s1[3], f[3]+512)
    d2 = decoder_block(d1, s2[2],s1[2], f[2]+256)
    d3 = decoder_block(d2, s2[1],s1[1], f[1]+64)
    d4 = decoder_block(d3, s2[0],s1[0],f[0]+3)
    
    """comp1 = complementary_loss(s2[0], s1[0])
    comp2 = complementary_loss(s2[1], s1[1])
    comp3 = complementary_loss(s2[2], s1[2])
    comp4 = complementary_loss(s2[3], s1[3])

    

    output_2 = tf.keras.layers.Add(name='output_2')([comp1/4.0,comp2/4.0,comp3/4.0,comp4/4.0])"""

    """ Classifier """
    output_1 = Conv2D(3, (1,1) , activation="softmax",name='output_1')(d4)

    """ Model """
    #model = Model(inputs,outputs=[output_1,output_2])
    model = Model(inputs,outputs=output_1)
    return model

# %% [markdown]
# # Evaluation Metrics

# %%
from keras import backend as K
def iou_liver(targets, inputs, smooth=1e-6):
    
    #flatten label and prediction tensors
    targets_f = K.flatten(targets[:,:,:,1])
    inputs_f = K.flatten(inputs[:,:,:,1])
    
    
    intersection = K.sum((targets_f*inputs_f))
    total = K.sum(targets_f) + K.sum(inputs_f)
    union = total - intersection
    
    IoU = (intersection + smooth) / (union + smooth)
    return IoU

def iou_tumor(targets, inputs, smooth=1e-6):
    
    #flatten label and prediction tensors
    targets_f = K.flatten(targets[:,:,:,2])
    inputs_f = K.flatten(inputs[:,:,:,2])
    
    intersection = K.sum((targets_f * inputs_f))
    total = K.sum(targets_f) + K.sum(inputs_f)
    union = total - intersection
    
    IoU = (intersection + smooth) / (union + smooth)
    return IoU

def iou(targets, inputs, smooth=1e-6):
    
    #flatten label and prediction tensors
    class_num = 3
    for i in range(class_num):
        targets_f= K.flatten(targets[:,:,:,i])
        inputs_f = K.flatten(inputs[:,:,:,i])
       

        intersection = K.sum((targets_f*inputs_f))
        total = K.sum(targets_f) + K.sum(inputs_f)
        union = total - intersection
        loss = (intersection + smooth) / (union + smooth)
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss
def dice_coef(y_true, y_pred, smooth=1e-5):
    class_num = 3
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
   #     K.print_tensor(loss, message='loss value for class {} : '.format(SEGMENT_CLASSES[i]))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
#    K.print_tensor(total_loss, message=' total dice coef: ')
    return total_loss
def dice_coef_liver(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true[:,:,:,1])
    y_pred_f = K.flatten(y_pred[:,:,:,1])
    intersection = K.sum(y_true_f * y_pred_f)
    loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
    return loss

def dice_coef_tumor(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true[:,:,:,2])
    y_pred_f = K.flatten(y_pred[:,:,:,2])
    intersection = K.sum(y_true_f * y_pred_f)
    loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
    return loss

# Computing Sensitivity      
def sensitivity_liver(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true[:,:,:,1] * y_pred[:,:,:,1], 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true[:,:,:,1], 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def sensitivity_tumor(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true[:,:,:,2] * y_pred[:,:,:,2], 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true[:,:,:,2], 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


# Computing Specificity
def specificity_liver(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true[:,:,:,1]) * (1-y_pred[:,:,:,1]), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true[:,:,:,1], 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())
def specificity_tumor(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true[:,:,:,2]) * (1-y_pred[:,:,:,2]), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true[:,:,:,2], 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def tversky(y_true, y_pred):
    smooth=1
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return (3 - tversky(y_true[:,:,:,0],y_pred[:,:,:,0])-tversky(y_true[:,:,:,1],y_pred[:,:,:,1])-tversky(y_true[:,:,:,2],y_pred[:,:,:,2]))

def focal_tversky_loss(y_true,y_pred):
    pt_1 = tversky(y_true[:,:,:,0],y_pred[:,:,:,0])
    pt_2 = tversky(y_true[:,:,:,1],y_pred[:,:,:,1])
    pt_3 = tversky(y_true[:,:,:,2],y_pred[:,:,:,2])
    
    gamma = 0.75
    return K.pow((3-pt_1-pt_2-pt_3), gamma)

# %%
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

# %%
# !pip install -U segmentation-models
#%env SM_FRAMEWORK=tf.keras
# Out:
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.3 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation-models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from efficientnet==1.0.0->segmentation-models) (0.21.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.10/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.24.3)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.9.0)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (9.5.0)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.8.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (21.3)
# Requirement already satisfied: lazy_loader>=0.2 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image->efficientnet==1.0.0->segmentation-models) (3.0.9)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1

# %%
import segmentation_models as sm
dice_loss = sm.losses.DiceLoss(class_weights = [0.33,0.33,0.33]) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from keras.callbacks import CSVLogger
model = build_WNet((256,256,3))
adam = tf.keras.optimizers.Adam(learning_rate = 0.0001)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
#
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
#
# __________________________________________________________________________________________________
#
#  Layer (type)                Output Shape                 Param #   Connected to
#
# ==================================================================================================
#
#  model_input (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#
#
#  encoder1 (Functional)       [[(None, 256, 256, 16),      870567    ['model_input[0][0]']
#
#                               (None, 128, 128, 32),
#
#                               (None, 64, 64, 64),
#
#                               (None, 32, 32, 128)],
#
#                               (None, 16, 16, 128)]
#
#
#
#  encoder2 (Functional)       [[(None, 256, 256, 3),       7988224   ['model_input[0][0]']
#
#                               (None, 128, 128, 64),
#
#                               (None, 64, 64, 256),
#
#                               (None, 32, 32, 512)],
#
#                               (None, 16, 16, 128)]
#
#
#
#  concatenate_2 (Concatenate  (None, 16, 16, 256)          0         ['encoder1[0][4]',
#
#  )                                                                   'encoder2[0][4]']
#
#
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 640)          656000    ['concatenate_2[0][0]']
#
#  anspose)
#
#
#
#  concatenate_3 (Concatenate  (None, 32, 32, 1280)         0         ['conv2d_transpose[0][0]',
#
#  )                                                                   'encoder2[0][3]',
#
#                                                                      'encoder1[0][3]']
#
#
#
#  batch_normalization_19 (Ba  (None, 32, 32, 1280)         5120      ['concatenate_3[0][0]']
#
#  tchNormalization)
#
#
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 32, 1280)         0         ['batch_normalization_19[0][0]
#
#                                                                     ']
#
#
#
#  conv2d_36 (Conv2D)          (None, 32, 32, 640)          7373440   ['leaky_re_lu_7[0][0]']
#
#
#
#  dropout_3 (Dropout)         (None, 32, 32, 640)          0         ['conv2d_36[0][0]']
#
#
#
#  batch_normalization_20 (Ba  (None, 32, 32, 640)          2560      ['dropout_3[0][0]']
#
#  tchNormalization)
#
#
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 32, 32, 640)          0         ['batch_normalization_20[0][0]
#
#                                                                     ']
#
#
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 640)          3687040   ['leaky_re_lu_8[0][0]']
#
#
#
#  conv2d_38 (Conv2D)          (None, 32, 32, 640)          819840    ['concatenate_3[0][0]']
#
#
#
#  tf.__operators__.add_4 (TF  (None, 32, 32, 640)          0         ['conv2d_37[0][0]',
#
#  OpLambda)                                                           'conv2d_38[0][0]']
#
#
#
#  tf.math.reduce_mean_8 (TFO  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#
#  pLambda)                                                           ']
#
#
#
#  tf.math.reduce_std_4 (TFOp  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#
#  Lambda)                                                            ']
#
#
#
#  tf.concat_4 (TFOpLambda)    (None, 1, 1, 1280)           0         ['tf.math.reduce_mean_8[0][0]'
#
#                                                                     , 'tf.math.reduce_std_4[0][0]'
#
#                                                                     ]
#
#
#
#  conv2d_39 (Conv2D)          (None, 1, 1, 40)             51240     ['tf.concat_4[0][0]']
#
#
#
#  tf.math.reduce_mean_9 (TFO  (None, 32, 32, 1)            0         ['tf.__operators__.add_4[0][0]
#
#  pLambda)                                                           ']
#
#
#
#  conv2d_40 (Conv2D)          (None, 1, 1, 640)            26240     ['conv2d_39[0][0]']
#
#
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 1)            2         ['tf.math.reduce_mean_9[0][0]'
#
#                                                                     ]
#
#
#
#  multiply_8 (Multiply)       (None, 32, 32, 640)          0         ['conv2d_40[0][0]',
#
#                                                                      'conv2d_41[0][0]']
#
#
#
#  multiply_9 (Multiply)       (None, 32, 32, 640)          0         ['tf.__operators__.add_4[0][0]
#
#                                                                     ',
#
#                                                                      'multiply_8[0][0]']
#
#
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 320)          819520    ['multiply_9[0][0]']
#
#  Transpose)
#
#
#
#  concatenate_4 (Concatenate  (None, 64, 64, 640)          0         ['conv2d_transpose_1[0][0]',
#
#  )                                                                   'encoder2[0][2]',
#
#                                                                      'encoder1[0][2]']
#
#
#
#  batch_normalization_21 (Ba  (None, 64, 64, 640)          2560      ['concatenate_4[0][0]']
#
#  tchNormalization)
#
#
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 64, 64, 640)          0         ['batch_normalization_21[0][0]
#
#                                                                     ']
#
#
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 320)          1843520   ['leaky_re_lu_9[0][0]']
#
#
#
#  dropout_4 (Dropout)         (None, 64, 64, 320)          0         ['conv2d_42[0][0]']
#
#
#
#  batch_normalization_22 (Ba  (None, 64, 64, 320)          1280      ['dropout_4[0][0]']
#
#  tchNormalization)
#
#
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 64, 320)          0         ['batch_normalization_22[0][0]
#
#                                                                     ']
#
#
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 320)          921920    ['leaky_re_lu_10[0][0]']
#
#
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 320)          205120    ['concatenate_4[0][0]']
#
#
#
#  tf.__operators__.add_5 (TF  (None, 64, 64, 320)          0         ['conv2d_43[0][0]',
#
#  OpLambda)                                                           'conv2d_44[0][0]']
#
#
#
#  tf.math.reduce_mean_10 (TF  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#
#  OpLambda)                                                          ']
#
#
#
#  tf.math.reduce_std_5 (TFOp  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#
#  Lambda)                                                            ']
#
#
#
#  tf.concat_5 (TFOpLambda)    (None, 1, 1, 640)            0         ['tf.math.reduce_mean_10[0][0]
#
#                                                                     ',
#
#                                                                      'tf.math.reduce_std_5[0][0]']
#
#
#
#  conv2d_45 (Conv2D)          (None, 1, 1, 20)             12820     ['tf.concat_5[0][0]']
#
#
#
#  tf.math.reduce_mean_11 (TF  (None, 64, 64, 1)            0         ['tf.__operators__.add_5[0][0]
#
#  OpLambda)                                                          ']
#
#
#
#  conv2d_46 (Conv2D)          (None, 1, 1, 320)            6720      ['conv2d_45[0][0]']
#
#
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 1)            2         ['tf.math.reduce_mean_11[0][0]
#
#                                                                     ']
#
#
#
#  multiply_10 (Multiply)      (None, 64, 64, 320)          0         ['conv2d_46[0][0]',
#
#                                                                      'conv2d_47[0][0]']
#
#
#
#  multiply_11 (Multiply)      (None, 64, 64, 320)          0         ['tf.__operators__.add_5[0][0]
#
#                                                                     ',
#
#                                                                      'multiply_10[0][0]']
#
#
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 96)         122976    ['multiply_11[0][0]']
#
#  Transpose)
#
#
#
#  concatenate_5 (Concatenate  (None, 128, 128, 192)        0         ['conv2d_transpose_2[0][0]',
#
#  )                                                                   'encoder2[0][1]',
#
#                                                                      'encoder1[0][1]']
#
#
#
#  batch_normalization_23 (Ba  (None, 128, 128, 192)        768       ['concatenate_5[0][0]']
#
#  tchNormalization)
#
#
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128, 128, 192)        0         ['batch_normalization_23[0][0]
#
#                                                                     ']
#
#
#
#  conv2d_48 (Conv2D)          (None, 128, 128, 96)         165984    ['leaky_re_lu_11[0][0]']
#
#
#
#  dropout_5 (Dropout)         (None, 128, 128, 96)         0         ['conv2d_48[0][0]']
#
#
#
#  batch_normalization_24 (Ba  (None, 128, 128, 96)         384       ['dropout_5[0][0]']
#
#  tchNormalization)
#
#
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 128, 128, 96)         0         ['batch_normalization_24[0][0]
#
#                                                                     ']
#
#
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 96)         83040     ['leaky_re_lu_12[0][0]']
#
#
#
#  conv2d_50 (Conv2D)          (None, 128, 128, 96)         18528     ['concatenate_5[0][0]']
#
#
#
#  tf.__operators__.add_6 (TF  (None, 128, 128, 96)         0         ['conv2d_49[0][0]',
#
#  OpLambda)                                                           'conv2d_50[0][0]']
#
#
#
#  tf.math.reduce_mean_12 (TF  (None, 1, 1, 96)             0         ['tf.__operators__.add_6[0][0]
#
#  OpLambda)                                                          ']
#
#
#
#  tf.math.reduce_std_6 (TFOp  (None, 1, 1, 96)             0         ['tf.__operators__.add_6[0][0]
#
#  Lambda)                                                            ']
#
#
#
#  tf.concat_6 (TFOpLambda)    (None, 1, 1, 192)            0         ['tf.math.reduce_mean_12[0][0]
#
#                                                                     ',
#
#                                                                      'tf.math.reduce_std_6[0][0]']
#
#
#
#  conv2d_51 (Conv2D)          (None, 1, 1, 6)              1158      ['tf.concat_6[0][0]']
#
#
#
#  tf.math.reduce_mean_13 (TF  (None, 128, 128, 1)          0         ['tf.__operators__.add_6[0][0]
#
#  OpLambda)                                                          ']
#
#
#
#  conv2d_52 (Conv2D)          (None, 1, 1, 96)             672       ['conv2d_51[0][0]']
#
#
#
#  conv2d_53 (Conv2D)          (None, 128, 128, 1)          2         ['tf.math.reduce_mean_13[0][0]
#
#                                                                     ']
#
#
#
#  multiply_12 (Multiply)      (None, 128, 128, 96)         0         ['conv2d_52[0][0]',
#
#                                                                      'conv2d_53[0][0]']
#
#
#
#  multiply_13 (Multiply)      (None, 128, 128, 96)         0         ['tf.__operators__.add_6[0][0]
#
#                                                                     ',
#
#                                                                      'multiply_12[0][0]']
#
#
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 19)         7315      ['multiply_13[0][0]']
#
#  Transpose)
#
#
#
#  concatenate_6 (Concatenate  (None, 256, 256, 38)         0         ['conv2d_transpose_3[0][0]',
#
#  )                                                                   'encoder2[0][0]',
#
#                                                                      'encoder1[0][0]']
#
#
#
#  batch_normalization_25 (Ba  (None, 256, 256, 38)         152       ['concatenate_6[0][0]']
#
#  tchNormalization)
#
#
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 256, 256, 38)         0         ['batch_normalization_25[0][0]
#
#                                                                     ']
#
#
#
#  conv2d_54 (Conv2D)          (None, 256, 256, 19)         6517      ['leaky_re_lu_13[0][0]']
#
#
#
#  dropout_6 (Dropout)         (None, 256, 256, 19)         0         ['conv2d_54[0][0]']
#
#
#
#  batch_normalization_26 (Ba  (None, 256, 256, 19)         76        ['dropout_6[0][0]']
#
#  tchNormalization)
#
#
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 256, 256, 19)         0         ['batch_normalization_26[0][0]
#
#                                                                     ']
#
#
#
#  conv2d_55 (Conv2D)          (None, 256, 256, 19)         3268      ['leaky_re_lu_14[0][0]']
#
#
#
#  conv2d_56 (Conv2D)          (None, 256, 256, 19)         741       ['concatenate_6[0][0]']
#
#
#
#  tf.__operators__.add_7 (TF  (None, 256, 256, 19)         0         ['conv2d_55[0][0]',
#
#  OpLambda)                                                           'conv2d_56[0][0]']
#
#
#
#  tf.math.reduce_mean_14 (TF  (None, 1, 1, 19)             0         ['tf.__operators__.add_7[0][0]
#
#  OpLambda)                                                          ']
#
#
#
#  tf.math.reduce_std_7 (TFOp  (None, 1, 1, 19)             0         ['tf.__operators__.add_7[0][0]
#
#  Lambda)                                                            ']
#
#
#
#  tf.concat_7 (TFOpLambda)    (None, 1, 1, 38)             0         ['tf.math.reduce_mean_14[0][0]
#
#                                                                     ',
#
#                                                                      'tf.math.reduce_std_7[0][0]']
#
#
#
#  conv2d_57 (Conv2D)          (None, 1, 1, 1)              39        ['tf.concat_7[0][0]']
#
#
#
#  tf.math.reduce_mean_15 (TF  (None, 256, 256, 1)          0         ['tf.__operators__.add_7[0][0]
#
#  OpLambda)                                                          ']
#
#
#
#  conv2d_58 (Conv2D)          (None, 1, 1, 19)             38        ['conv2d_57[0][0]']
#
#
#
#  conv2d_59 (Conv2D)          (None, 256, 256, 1)          2         ['tf.math.reduce_mean_15[0][0]
#
#                                                                     ']
#
#
#
#  multiply_14 (Multiply)      (None, 256, 256, 19)         0         ['conv2d_58[0][0]',
#
#                                                                      'conv2d_59[0][0]']
#
#
#
#  multiply_15 (Multiply)      (None, 256, 256, 19)         0         ['tf.__operators__.add_7[0][0]
#
#                                                                     ',
#
#                                                                      'multiply_14[0][0]']
#
#
#
#  output_1 (Conv2D)           (None, 256, 256, 3)          60        ['multiply_15[0][0]']
#
#
#
# ==================================================================================================
#
# Total params: 25705455 (98.06 MB)
#
# Trainable params: 25676925 (97.95 MB)
#
# Non-trainable params: 28530 (111.45 KB)
#
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001), loss=total_loss,
              metrics = {"output_1":[dice_coef_liver,dice_coef_tumor,iou_liver,iou_tumor,sensitivity_liver,sensitivity_tumor,specificity_liver,specificity_tumor]})

#callbacks
csv_logger = CSVLogger('/kaggle/working/training_log_WNet_Res50', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min', 
                              verbose=1, 
                              patience=6
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_Res50.h5", 
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, earlystopping, reduce_lr, csv_logger]

# %%
batch_size = 16
N = 256
train_generator = CustomDataGenerator(df_train, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(df_val, batch_size=batch_size, image_size=(N,N), shuffle=False)
history_ = model.fit(train_generator, steps_per_epoch=len(df_train) // batch_size,
                    validation_data=val_generator, validation_steps=len(df_val) // batch_size,
                    epochs=50,callbacks=callbacks)
# Out:
# Epoch 1/50
# 2024-01-20 20:52:20.919692: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/encoder1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 836/836 [==============================] - ETA: 0s - loss: 0.7272 - dice_coef_liver: 0.8937 - dice_coef_tumor: 0.6307 - iou_liver: 0.8236 - iou_tumor: 0.4974 - sensitivity_liver: 0.8980 - sensitivity_tumor: 0.6213 - specificity_liver: 0.9947 - specificity_tumor: 0.9993
#
# Epoch 1: val_loss improved from inf to 0.83809, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 626s 670ms/step - loss: 0.7272 - dice_coef_liver: 0.8937 - dice_coef_tumor: 0.6307 - iou_liver: 0.8236 - iou_tumor: 0.4974 - sensitivity_liver: 0.8980 - sensitivity_tumor: 0.6213 - specificity_liver: 0.9947 - specificity_tumor: 0.9993 - val_loss: 0.8381 - val_dice_coef_liver: 0.4568 - val_dice_coef_tumor: 0.2567 - val_iou_liver: 0.3001 - val_iou_tumor: 0.1658 - val_sensitivity_liver: 0.2985 - val_sensitivity_tumor: 0.1690 - val_specificity_liver: 0.9993 - val_specificity_tumor: 0.9999 - lr: 1.0000e-04
#
# Epoch 2/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.7027 - dice_coef_liver: 0.9447 - dice_coef_tumor: 0.7820 - iou_liver: 0.8954 - iou_tumor: 0.6581 - sensitivity_liver: 0.9477 - sensitivity_tumor: 0.7691 - specificity_liver: 0.9967 - specificity_tumor: 0.9995
#
# Epoch 2: val_loss improved from 0.83809 to 0.70021, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 538s 643ms/step - loss: 0.7027 - dice_coef_liver: 0.9447 - dice_coef_tumor: 0.7820 - iou_liver: 0.8954 - iou_tumor: 0.6581 - sensitivity_liver: 0.9477 - sensitivity_tumor: 0.7691 - specificity_liver: 0.9967 - specificity_tumor: 0.9995 - val_loss: 0.7002 - val_dice_coef_liver: 0.9518 - val_dice_coef_tumor: 0.7940 - val_iou_liver: 0.9080 - val_iou_tumor: 0.6780 - val_sensitivity_liver: 0.9604 - val_sensitivity_tumor: 0.8061 - val_specificity_liver: 0.9965 - val_specificity_tumor: 0.9994 - lr: 1.0000e-04
#
# Epoch 3/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6986 - dice_coef_liver: 0.9522 - dice_coef_tumor: 0.8085 - iou_liver: 0.9089 - iou_tumor: 0.6929 - sensitivity_liver: 0.9543 - sensitivity_tumor: 0.7947 - specificity_liver: 0.9971 - specificity_tumor: 0.9996
#
# Epoch 3: val_loss improved from 0.70021 to 0.69768, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 538s 643ms/step - loss: 0.6986 - dice_coef_liver: 0.9522 - dice_coef_tumor: 0.8085 - iou_liver: 0.9089 - iou_tumor: 0.6929 - sensitivity_liver: 0.9543 - sensitivity_tumor: 0.7947 - specificity_liver: 0.9971 - specificity_tumor: 0.9996 - val_loss: 0.6977 - val_dice_coef_liver: 0.9530 - val_dice_coef_tumor: 0.8144 - val_iou_liver: 0.9102 - val_iou_tumor: 0.7032 - val_sensitivity_liver: 0.9559 - val_sensitivity_tumor: 0.7910 - val_specificity_liver: 0.9972 - val_specificity_tumor: 0.9996 - lr: 1.0000e-04
#
# Epoch 4/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6953 - dice_coef_liver: 0.9559 - dice_coef_tumor: 0.8330 - iou_liver: 0.9156 - iou_tumor: 0.7272 - sensitivity_liver: 0.9581 - sensitivity_tumor: 0.8220 - specificity_liver: 0.9973 - specificity_tumor: 0.9996
#
# Epoch 4: val_loss improved from 0.69768 to 0.69581, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 539s 644ms/step - loss: 0.6953 - dice_coef_liver: 0.9559 - dice_coef_tumor: 0.8330 - iou_liver: 0.9156 - iou_tumor: 0.7272 - sensitivity_liver: 0.9581 - sensitivity_tumor: 0.8220 - specificity_liver: 0.9973 - specificity_tumor: 0.9996 - val_loss: 0.6958 - val_dice_coef_liver: 0.9554 - val_dice_coef_tumor: 0.8297 - val_iou_liver: 0.9148 - val_iou_tumor: 0.7269 - val_sensitivity_liver: 0.9555 - val_sensitivity_tumor: 0.8120 - val_specificity_liver: 0.9973 - val_specificity_tumor: 0.9996 - lr: 1.0000e-04
#
# Epoch 5/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6944 - dice_coef_liver: 0.9576 - dice_coef_tumor: 0.8390 - iou_liver: 0.9187 - iou_tumor: 0.7329 - sensitivity_liver: 0.9599 - sensitivity_tumor: 0.8259 - specificity_liver: 0.9974 - specificity_tumor: 0.9996
#
# Epoch 5: val_loss improved from 0.69581 to 0.69580, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 540s 646ms/step - loss: 0.6944 - dice_coef_liver: 0.9576 - dice_coef_tumor: 0.8390 - iou_liver: 0.9187 - iou_tumor: 0.7329 - sensitivity_liver: 0.9599 - sensitivity_tumor: 0.8259 - specificity_liver: 0.9974 - specificity_tumor: 0.9996 - val_loss: 0.6958 - val_dice_coef_liver: 0.9554 - val_dice_coef_tumor: 0.8283 - val_iou_liver: 0.9146 - val_iou_tumor: 0.7246 - val_sensitivity_liver: 0.9735 - val_sensitivity_tumor: 0.8080 - val_specificity_liver: 0.9962 - val_specificity_tumor: 0.9996 - lr: 1.0000e-04
#
# Epoch 6/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6932 - dice_coef_liver: 0.9598 - dice_coef_tumor: 0.8465 - iou_liver: 0.9228 - iou_tumor: 0.7465 - sensitivity_liver: 0.9621 - sensitivity_tumor: 0.8348 - specificity_liver: 0.9975 - specificity_tumor: 0.9996
#
# Epoch 6: val_loss improved from 0.69580 to 0.69435, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 540s 645ms/step - loss: 0.6932 - dice_coef_liver: 0.9598 - dice_coef_tumor: 0.8465 - iou_liver: 0.9228 - iou_tumor: 0.7465 - sensitivity_liver: 0.9621 - sensitivity_tumor: 0.8348 - specificity_liver: 0.9975 - specificity_tumor: 0.9996 - val_loss: 0.6943 - val_dice_coef_liver: 0.9578 - val_dice_coef_tumor: 0.8381 - val_iou_liver: 0.9191 - val_iou_tumor: 0.7383 - val_sensitivity_liver: 0.9749 - val_sensitivity_tumor: 0.8065 - val_specificity_liver: 0.9963 - val_specificity_tumor: 0.9997 - lr: 1.0000e-04
#
# Epoch 7/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6922 - dice_coef_liver: 0.9604 - dice_coef_tumor: 0.8546 - iou_liver: 0.9239 - iou_tumor: 0.7575 - sensitivity_liver: 0.9624 - sensitivity_tumor: 0.8427 - specificity_liver: 0.9976 - specificity_tumor: 0.9997
#
# Epoch 7: val_loss did not improve from 0.69435
#
# 836/836 [==============================] - 539s 645ms/step - loss: 0.6922 - dice_coef_liver: 0.9604 - dice_coef_tumor: 0.8546 - iou_liver: 0.9239 - iou_tumor: 0.7575 - sensitivity_liver: 0.9624 - sensitivity_tumor: 0.8427 - specificity_liver: 0.9976 - specificity_tumor: 0.9997 - val_loss: 0.6961 - val_dice_coef_liver: 0.9529 - val_dice_coef_tumor: 0.8311 - val_iou_liver: 0.9101 - val_iou_tumor: 0.7263 - val_sensitivity_liver: 0.9595 - val_sensitivity_tumor: 0.8414 - val_specificity_liver: 0.9967 - val_specificity_tumor: 0.9995 - lr: 1.0000e-04
#
# Epoch 8/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6914 - dice_coef_liver: 0.9614 - dice_coef_tumor: 0.8600 - iou_liver: 0.9258 - iou_tumor: 0.7653 - sensitivity_liver: 0.9641 - sensitivity_tumor: 0.8474 - specificity_liver: 0.9976 - specificity_tumor: 0.9997
#
# Epoch 8: val_loss improved from 0.69435 to 0.69303, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 539s 645ms/step - loss: 0.6914 - dice_coef_liver: 0.9614 - dice_coef_tumor: 0.8600 - iou_liver: 0.9258 - iou_tumor: 0.7653 - sensitivity_liver: 0.9641 - sensitivity_tumor: 0.8474 - specificity_liver: 0.9976 - specificity_tumor: 0.9997 - val_loss: 0.6930 - val_dice_coef_liver: 0.9588 - val_dice_coef_tumor: 0.8487 - val_iou_liver: 0.9209 - val_iou_tumor: 0.7521 - val_sensitivity_liver: 0.9775 - val_sensitivity_tumor: 0.8269 - val_specificity_liver: 0.9962 - val_specificity_tumor: 0.9997 - lr: 1.0000e-04
#
# Epoch 9/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6904 - dice_coef_liver: 0.9632 - dice_coef_tumor: 0.8665 - iou_liver: 0.9291 - iou_tumor: 0.7742 - sensitivity_liver: 0.9657 - sensitivity_tumor: 0.8543 - specificity_liver: 0.9977 - specificity_tumor: 0.9997
#
# Epoch 9: val_loss improved from 0.69303 to 0.69225, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 541s 646ms/step - loss: 0.6904 - dice_coef_liver: 0.9632 - dice_coef_tumor: 0.8665 - iou_liver: 0.9291 - iou_tumor: 0.7742 - sensitivity_liver: 0.9657 - sensitivity_tumor: 0.8543 - specificity_liver: 0.9977 - specificity_tumor: 0.9997 - val_loss: 0.6923 - val_dice_coef_liver: 0.9603 - val_dice_coef_tumor: 0.8534 - val_iou_liver: 0.9236 - val_iou_tumor: 0.7582 - val_sensitivity_liver: 0.9728 - val_sensitivity_tumor: 0.8627 - val_specificity_liver: 0.9968 - val_specificity_tumor: 0.9995 - lr: 1.0000e-04
#
# Epoch 10/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6897 - dice_coef_liver: 0.9642 - dice_coef_tumor: 0.8710 - iou_liver: 0.9310 - iou_tumor: 0.7817 - sensitivity_liver: 0.9666 - sensitivity_tumor: 0.8605 - specificity_liver: 0.9978 - specificity_tumor: 0.9997
#
# Epoch 10: val_loss improved from 0.69225 to 0.69136, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 539s 644ms/step - loss: 0.6897 - dice_coef_liver: 0.9642 - dice_coef_tumor: 0.8710 - iou_liver: 0.9310 - iou_tumor: 0.7817 - sensitivity_liver: 0.9666 - sensitivity_tumor: 0.8605 - specificity_liver: 0.9978 - specificity_tumor: 0.9997 - val_loss: 0.6914 - val_dice_coef_liver: 0.9638 - val_dice_coef_tumor: 0.8564 - val_iou_liver: 0.9301 - val_iou_tumor: 0.7641 - val_sensitivity_liver: 0.9661 - val_sensitivity_tumor: 0.8619 - val_specificity_liver: 0.9977 - val_specificity_tumor: 0.9996 - lr: 1.0000e-04
#
# Epoch 11/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6907 - dice_coef_liver: 0.9620 - dice_coef_tumor: 0.8651 - iou_liver: 0.9268 - iou_tumor: 0.7714 - sensitivity_liver: 0.9648 - sensitivity_tumor: 0.8540 - specificity_liver: 0.9976 - specificity_tumor: 0.9997
#
# Epoch 11: val_loss improved from 0.69136 to 0.69136, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 539s 644ms/step - loss: 0.6907 - dice_coef_liver: 0.9620 - dice_coef_tumor: 0.8651 - iou_liver: 0.9268 - iou_tumor: 0.7714 - sensitivity_liver: 0.9648 - sensitivity_tumor: 0.8540 - specificity_liver: 0.9976 - specificity_tumor: 0.9997 - val_loss: 0.6914 - val_dice_coef_liver: 0.9638 - val_dice_coef_tumor: 0.8564 - val_iou_liver: 0.9301 - val_iou_tumor: 0.7648 - val_sensitivity_liver: 0.9699 - val_sensitivity_tumor: 0.8584 - val_specificity_liver: 0.9975 - val_specificity_tumor: 0.9996 - lr: 1.0000e-04
#
# Epoch 12/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6884 - dice_coef_liver: 0.9650 - dice_coef_tumor: 0.8820 - iou_liver: 0.9325 - iou_tumor: 0.7955 - sensitivity_liver: 0.9675 - sensitivity_tumor: 0.8722 - specificity_liver: 0.9978 - specificity_tumor: 0.9997
#
# Epoch 12: val_loss improved from 0.69136 to 0.69106, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 540s 645ms/step - loss: 0.6884 - dice_coef_liver: 0.9650 - dice_coef_tumor: 0.8820 - iou_liver: 0.9325 - iou_tumor: 0.7955 - sensitivity_liver: 0.9675 - sensitivity_tumor: 0.8722 - specificity_liver: 0.9978 - specificity_tumor: 0.9997 - val_loss: 0.6911 - val_dice_coef_liver: 0.9636 - val_dice_coef_tumor: 0.8603 - val_iou_liver: 0.9299 - val_iou_tumor: 0.7678 - val_sensitivity_liver: 0.9726 - val_sensitivity_tumor: 0.8805 - val_specificity_liver: 0.9972 - val_specificity_tumor: 0.9995 - lr: 1.0000e-04
#
# Epoch 13/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6890 - dice_coef_liver: 0.9649 - dice_coef_tumor: 0.8759 - iou_liver: 0.9323 - iou_tumor: 0.7885 - sensitivity_liver: 0.9677 - sensitivity_tumor: 0.8640 - specificity_liver: 0.9978 - specificity_tumor: 0.9997
#
# Epoch 13: val_loss improved from 0.69106 to 0.68995, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 539s 644ms/step - loss: 0.6890 - dice_coef_liver: 0.9649 - dice_coef_tumor: 0.8759 - iou_liver: 0.9323 - iou_tumor: 0.7885 - sensitivity_liver: 0.9677 - sensitivity_tumor: 0.8640 - specificity_liver: 0.9978 - specificity_tumor: 0.9997 - val_loss: 0.6899 - val_dice_coef_liver: 0.9648 - val_dice_coef_tumor: 0.8689 - val_iou_liver: 0.9320 - val_iou_tumor: 0.7814 - val_sensitivity_liver: 0.9774 - val_sensitivity_tumor: 0.8670 - val_specificity_liver: 0.9969 - val_specificity_tumor: 0.9996 - lr: 1.0000e-04
#
# Epoch 14/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6880 - dice_coef_liver: 0.9649 - dice_coef_tumor: 0.8856 - iou_liver: 0.9322 - iou_tumor: 0.8016 - sensitivity_liver: 0.9679 - sensitivity_tumor: 0.8801 - specificity_liver: 0.9978 - specificity_tumor: 0.9997
#
# Epoch 14: val_loss improved from 0.68995 to 0.68983, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 540s 645ms/step - loss: 0.6880 - dice_coef_liver: 0.9649 - dice_coef_tumor: 0.8856 - iou_liver: 0.9322 - iou_tumor: 0.8016 - sensitivity_liver: 0.9679 - sensitivity_tumor: 0.8801 - specificity_liver: 0.9978 - specificity_tumor: 0.9997 - val_loss: 0.6898 - val_dice_coef_liver: 0.9623 - val_dice_coef_tumor: 0.8724 - val_iou_liver: 0.9274 - val_iou_tumor: 0.7831 - val_sensitivity_liver: 0.9750 - val_sensitivity_tumor: 0.8459 - val_specificity_liver: 0.9968 - val_specificity_tumor: 0.9997 - lr: 1.0000e-04
#
# Epoch 15/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6873 - dice_coef_liver: 0.9653 - dice_coef_tumor: 0.8907 - iou_liver: 0.9331 - iou_tumor: 0.8082 - sensitivity_liver: 0.9682 - sensitivity_tumor: 0.8848 - specificity_liver: 0.9978 - specificity_tumor: 0.9997
#
# Epoch 15: val_loss did not improve from 0.68983
#
# 836/836 [==============================] - 537s 641ms/step - loss: 0.6873 - dice_coef_liver: 0.9653 - dice_coef_tumor: 0.8907 - iou_liver: 0.9331 - iou_tumor: 0.8082 - sensitivity_liver: 0.9682 - sensitivity_tumor: 0.8848 - specificity_liver: 0.9978 - specificity_tumor: 0.9997 - val_loss: 0.6977 - val_dice_coef_liver: 0.9393 - val_dice_coef_tumor: 0.8384 - val_iou_liver: 0.8858 - val_iou_tumor: 0.7348 - val_sensitivity_liver: 0.9181 - val_sensitivity_tumor: 0.8737 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9994 - lr: 1.0000e-04
#
# Epoch 16/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6868 - dice_coef_liver: 0.9662 - dice_coef_tumor: 0.8935 - iou_liver: 0.9347 - iou_tumor: 0.8130 - sensitivity_liver: 0.9689 - sensitivity_tumor: 0.8881 - specificity_liver: 0.9979 - specificity_tumor: 0.9997
#
# Epoch 16: val_loss improved from 0.68983 to 0.68961, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 538s 643ms/step - loss: 0.6868 - dice_coef_liver: 0.9662 - dice_coef_tumor: 0.8935 - iou_liver: 0.9347 - iou_tumor: 0.8130 - sensitivity_liver: 0.9689 - sensitivity_tumor: 0.8881 - specificity_liver: 0.9979 - specificity_tumor: 0.9997 - val_loss: 0.6896 - val_dice_coef_liver: 0.9640 - val_dice_coef_tumor: 0.8731 - val_iou_liver: 0.9305 - val_iou_tumor: 0.7868 - val_sensitivity_liver: 0.9692 - val_sensitivity_tumor: 0.8586 - val_specificity_liver: 0.9974 - val_specificity_tumor: 0.9997 - lr: 1.0000e-04
#
# Epoch 17/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6864 - dice_coef_liver: 0.9672 - dice_coef_tumor: 0.8964 - iou_liver: 0.9365 - iou_tumor: 0.8191 - sensitivity_liver: 0.9700 - sensitivity_tumor: 0.8918 - specificity_liver: 0.9979 - specificity_tumor: 0.9997
#
# Epoch 17: val_loss did not improve from 0.68961
#
# 836/836 [==============================] - 537s 641ms/step - loss: 0.6864 - dice_coef_liver: 0.9672 - dice_coef_tumor: 0.8964 - iou_liver: 0.9365 - iou_tumor: 0.8191 - sensitivity_liver: 0.9700 - sensitivity_tumor: 0.8918 - specificity_liver: 0.9979 - specificity_tumor: 0.9997 - val_loss: 0.6930 - val_dice_coef_liver: 0.9639 - val_dice_coef_tumor: 0.8429 - val_iou_liver: 0.9304 - val_iou_tumor: 0.7394 - val_sensitivity_liver: 0.9664 - val_sensitivity_tumor: 0.7601 - val_specificity_liver: 0.9976 - val_specificity_tumor: 0.9999 - lr: 1.0000e-04
#
# Epoch 18/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6867 - dice_coef_liver: 0.9664 - dice_coef_tumor: 0.8942 - iou_liver: 0.9350 - iou_tumor: 0.8138 - sensitivity_liver: 0.9691 - sensitivity_tumor: 0.8891 - specificity_liver: 0.9979 - specificity_tumor: 0.9997
#
# Epoch 18: val_loss improved from 0.68961 to 0.68821, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 540s 646ms/step - loss: 0.6867 - dice_coef_liver: 0.9664 - dice_coef_tumor: 0.8942 - iou_liver: 0.9350 - iou_tumor: 0.8138 - sensitivity_liver: 0.9691 - sensitivity_tumor: 0.8891 - specificity_liver: 0.9979 - specificity_tumor: 0.9997 - val_loss: 0.6882 - val_dice_coef_liver: 0.9646 - val_dice_coef_tumor: 0.8841 - val_iou_liver: 0.9316 - val_iou_tumor: 0.8007 - val_sensitivity_liver: 0.9789 - val_sensitivity_tumor: 0.9037 - val_specificity_liver: 0.9968 - val_specificity_tumor: 0.9996 - lr: 1.0000e-04
#
# Epoch 19/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6855 - dice_coef_liver: 0.9678 - dice_coef_tumor: 0.9037 - iou_liver: 0.9377 - iou_tumor: 0.8277 - sensitivity_liver: 0.9706 - sensitivity_tumor: 0.8979 - specificity_liver: 0.9979 - specificity_tumor: 0.9997
#
# Epoch 19: val_loss improved from 0.68821 to 0.68692, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 537s 642ms/step - loss: 0.6855 - dice_coef_liver: 0.9678 - dice_coef_tumor: 0.9037 - iou_liver: 0.9377 - iou_tumor: 0.8277 - sensitivity_liver: 0.9706 - sensitivity_tumor: 0.8979 - specificity_liver: 0.9979 - specificity_tumor: 0.9997 - val_loss: 0.6869 - val_dice_coef_liver: 0.9678 - val_dice_coef_tumor: 0.8909 - val_iou_liver: 0.9376 - val_iou_tumor: 0.8109 - val_sensitivity_liver: 0.9758 - val_sensitivity_tumor: 0.8751 - val_specificity_liver: 0.9975 - val_specificity_tumor: 0.9997 - lr: 1.0000e-04
#
# Epoch 20/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6861 - dice_coef_liver: 0.9677 - dice_coef_tumor: 0.8985 - iou_liver: 0.9374 - iou_tumor: 0.8215 - sensitivity_liver: 0.9706 - sensitivity_tumor: 0.8958 - specificity_liver: 0.9979 - specificity_tumor: 0.9997
#
# Epoch 20: val_loss improved from 0.68692 to 0.68666, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 539s 644ms/step - loss: 0.6861 - dice_coef_liver: 0.9677 - dice_coef_tumor: 0.8985 - iou_liver: 0.9374 - iou_tumor: 0.8215 - sensitivity_liver: 0.9706 - sensitivity_tumor: 0.8958 - specificity_liver: 0.9979 - specificity_tumor: 0.9997 - val_loss: 0.6867 - val_dice_coef_liver: 0.9687 - val_dice_coef_tumor: 0.8921 - val_iou_liver: 0.9394 - val_iou_tumor: 0.8137 - val_sensitivity_liver: 0.9718 - val_sensitivity_tumor: 0.8837 - val_specificity_liver: 0.9979 - val_specificity_tumor: 0.9997 - lr: 1.0000e-04
#
# Epoch 21/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6856 - dice_coef_liver: 0.9686 - dice_coef_tumor: 0.9013 - iou_liver: 0.9391 - iou_tumor: 0.8257 - sensitivity_liver: 0.9713 - sensitivity_tumor: 0.8980 - specificity_liver: 0.9980 - specificity_tumor: 0.9997
#
# Epoch 21: val_loss improved from 0.68666 to 0.68657, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 537s 642ms/step - loss: 0.6856 - dice_coef_liver: 0.9686 - dice_coef_tumor: 0.9013 - iou_liver: 0.9391 - iou_tumor: 0.8257 - sensitivity_liver: 0.9713 - sensitivity_tumor: 0.8980 - specificity_liver: 0.9980 - specificity_tumor: 0.9997 - val_loss: 0.6866 - val_dice_coef_liver: 0.9681 - val_dice_coef_tumor: 0.8932 - val_iou_liver: 0.9381 - val_iou_tumor: 0.8138 - val_sensitivity_liver: 0.9756 - val_sensitivity_tumor: 0.8912 - val_specificity_liver: 0.9976 - val_specificity_tumor: 0.9997 - lr: 1.0000e-04
#
# Epoch 22/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6853 - dice_coef_liver: 0.9686 - dice_coef_tumor: 0.9039 - iou_liver: 0.9391 - iou_tumor: 0.8292 - sensitivity_liver: 0.9715 - sensitivity_tumor: 0.8993 - specificity_liver: 0.9980 - specificity_tumor: 0.9997
#
# Epoch 22: val_loss improved from 0.68657 to 0.68642, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 538s 643ms/step - loss: 0.6853 - dice_coef_liver: 0.9686 - dice_coef_tumor: 0.9039 - iou_liver: 0.9391 - iou_tumor: 0.8292 - sensitivity_liver: 0.9715 - sensitivity_tumor: 0.8993 - specificity_liver: 0.9980 - specificity_tumor: 0.9997 - val_loss: 0.6864 - val_dice_coef_liver: 0.9676 - val_dice_coef_tumor: 0.8958 - val_iou_liver: 0.9373 - val_iou_tumor: 0.8194 - val_sensitivity_liver: 0.9796 - val_sensitivity_tumor: 0.8912 - val_specificity_liver: 0.9971 - val_specificity_tumor: 0.9997 - lr: 1.0000e-04
#
# Epoch 23/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6846 - dice_coef_liver: 0.9697 - dice_coef_tumor: 0.9084 - iou_liver: 0.9412 - iou_tumor: 0.8357 - sensitivity_liver: 0.9726 - sensitivity_tumor: 0.9033 - specificity_liver: 0.9980 - specificity_tumor: 0.9997
#
# Epoch 23: val_loss improved from 0.68642 to 0.68598, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 539s 644ms/step - loss: 0.6846 - dice_coef_liver: 0.9697 - dice_coef_tumor: 0.9084 - iou_liver: 0.9412 - iou_tumor: 0.8357 - sensitivity_liver: 0.9726 - sensitivity_tumor: 0.9033 - specificity_liver: 0.9980 - specificity_tumor: 0.9997 - val_loss: 0.6860 - val_dice_coef_liver: 0.9687 - val_dice_coef_tumor: 0.8982 - val_iou_liver: 0.9393 - val_iou_tumor: 0.8209 - val_sensitivity_liver: 0.9793 - val_sensitivity_tumor: 0.9025 - val_specificity_liver: 0.9973 - val_specificity_tumor: 0.9997 - lr: 1.0000e-04
#
# Epoch 24/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6850 - dice_coef_liver: 0.9691 - dice_coef_tumor: 0.9057 - iou_liver: 0.9401 - iou_tumor: 0.8321 - sensitivity_liver: 0.9718 - sensitivity_tumor: 0.9022 - specificity_liver: 0.9980 - specificity_tumor: 0.9997
#
# Epoch 24: val_loss did not improve from 0.68598
#
# 836/836 [==============================] - 538s 643ms/step - loss: 0.6850 - dice_coef_liver: 0.9691 - dice_coef_tumor: 0.9057 - iou_liver: 0.9401 - iou_tumor: 0.8321 - sensitivity_liver: 0.9718 - sensitivity_tumor: 0.9022 - specificity_liver: 0.9980 - specificity_tumor: 0.9997 - val_loss: 0.6863 - val_dice_coef_liver: 0.9680 - val_dice_coef_tumor: 0.8968 - val_iou_liver: 0.9380 - val_iou_tumor: 0.8186 - val_sensitivity_liver: 0.9801 - val_sensitivity_tumor: 0.9011 - val_specificity_liver: 0.9972 - val_specificity_tumor: 0.9997 - lr: 1.0000e-04
#
# Epoch 25/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6851 - dice_coef_liver: 0.9695 - dice_coef_tumor: 0.9043 - iou_liver: 0.9409 - iou_tumor: 0.8309 - sensitivity_liver: 0.9723 - sensitivity_tumor: 0.9009 - specificity_liver: 0.9980 - specificity_tumor: 0.9997
#
# Epoch 25: val_loss did not improve from 0.68598
#
# 836/836 [==============================] - 537s 642ms/step - loss: 0.6851 - dice_coef_liver: 0.9695 - dice_coef_tumor: 0.9043 - iou_liver: 0.9409 - iou_tumor: 0.8309 - sensitivity_liver: 0.9723 - sensitivity_tumor: 0.9009 - specificity_liver: 0.9980 - specificity_tumor: 0.9997 - val_loss: 0.6864 - val_dice_coef_liver: 0.9689 - val_dice_coef_tumor: 0.8930 - val_iou_liver: 0.9398 - val_iou_tumor: 0.8151 - val_sensitivity_liver: 0.9775 - val_sensitivity_tumor: 0.8782 - val_specificity_liver: 0.9976 - val_specificity_tumor: 0.9997 - lr: 1.0000e-04
#
# Epoch 26/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6848 - dice_coef_liver: 0.9696 - dice_coef_tumor: 0.9074 - iou_liver: 0.9410 - iou_tumor: 0.8348 - sensitivity_liver: 0.9726 - sensitivity_tumor: 0.9023 - specificity_liver: 0.9980 - specificity_tumor: 0.9998
#
# Epoch 26: val_loss did not improve from 0.68598
#
#
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# 836/836 [==============================] - 543s 649ms/step - loss: 0.6848 - dice_coef_liver: 0.9696 - dice_coef_tumor: 0.9074 - iou_liver: 0.9410 - iou_tumor: 0.8348 - sensitivity_liver: 0.9726 - sensitivity_tumor: 0.9023 - specificity_liver: 0.9980 - specificity_tumor: 0.9998 - val_loss: 0.6873 - val_dice_coef_liver: 0.9650 - val_dice_coef_tumor: 0.8917 - val_iou_liver: 0.9323 - val_iou_tumor: 0.8124 - val_sensitivity_liver: 0.9832 - val_sensitivity_tumor: 0.8824 - val_specificity_liver: 0.9965 - val_specificity_tumor: 0.9997 - lr: 1.0000e-04
#
# Epoch 27/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6834 - dice_coef_liver: 0.9712 - dice_coef_tumor: 0.9171 - iou_liver: 0.9440 - iou_tumor: 0.8507 - sensitivity_liver: 0.9741 - sensitivity_tumor: 0.9133 - specificity_liver: 0.9981 - specificity_tumor: 0.9998
#
# Epoch 27: val_loss improved from 0.68598 to 0.68483, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 538s 643ms/step - loss: 0.6834 - dice_coef_liver: 0.9712 - dice_coef_tumor: 0.9171 - iou_liver: 0.9440 - iou_tumor: 0.8507 - sensitivity_liver: 0.9741 - sensitivity_tumor: 0.9133 - specificity_liver: 0.9981 - specificity_tumor: 0.9998 - val_loss: 0.6848 - val_dice_coef_liver: 0.9710 - val_dice_coef_tumor: 0.9052 - val_iou_liver: 0.9437 - val_iou_tumor: 0.8331 - val_sensitivity_liver: 0.9786 - val_sensitivity_tumor: 0.9052 - val_specificity_liver: 0.9977 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
#
# Epoch 28/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6828 - dice_coef_liver: 0.9720 - dice_coef_tumor: 0.9221 - iou_liver: 0.9456 - iou_tumor: 0.8581 - sensitivity_liver: 0.9749 - sensitivity_tumor: 0.9185 - specificity_liver: 0.9982 - specificity_tumor: 0.9998
#
# Epoch 28: val_loss improved from 0.68483 to 0.68481, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 538s 643ms/step - loss: 0.6828 - dice_coef_liver: 0.9720 - dice_coef_tumor: 0.9221 - iou_liver: 0.9456 - iou_tumor: 0.8581 - sensitivity_liver: 0.9749 - sensitivity_tumor: 0.9185 - specificity_liver: 0.9982 - specificity_tumor: 0.9998 - val_loss: 0.6848 - val_dice_coef_liver: 0.9714 - val_dice_coef_tumor: 0.9049 - val_iou_liver: 0.9445 - val_iou_tumor: 0.8334 - val_sensitivity_liver: 0.9773 - val_sensitivity_tumor: 0.9048 - val_specificity_liver: 0.9978 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
#
# Epoch 29/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6828 - dice_coef_liver: 0.9725 - dice_coef_tumor: 0.9212 - iou_liver: 0.9464 - iou_tumor: 0.8582 - sensitivity_liver: 0.9754 - sensitivity_tumor: 0.9165 - specificity_liver: 0.9982 - specificity_tumor: 0.9998
#
# Epoch 29: val_loss improved from 0.68481 to 0.68438, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 538s 643ms/step - loss: 0.6828 - dice_coef_liver: 0.9725 - dice_coef_tumor: 0.9212 - iou_liver: 0.9464 - iou_tumor: 0.8582 - sensitivity_liver: 0.9754 - sensitivity_tumor: 0.9165 - specificity_liver: 0.9982 - specificity_tumor: 0.9998 - val_loss: 0.6844 - val_dice_coef_liver: 0.9714 - val_dice_coef_tumor: 0.9086 - val_iou_liver: 0.9443 - val_iou_tumor: 0.8384 - val_sensitivity_liver: 0.9804 - val_sensitivity_tumor: 0.8981 - val_specificity_liver: 0.9976 - val_specificity_tumor: 0.9998 - lr: 3.0000e-05
#
# Epoch 30/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6823 - dice_coef_liver: 0.9727 - dice_coef_tumor: 0.9251 - iou_liver: 0.9468 - iou_tumor: 0.8638 - sensitivity_liver: 0.9754 - sensitivity_tumor: 0.9218 - specificity_liver: 0.9982 - specificity_tumor: 0.9998
#
# Epoch 30: val_loss improved from 0.68438 to 0.68414, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 539s 645ms/step - loss: 0.6823 - dice_coef_liver: 0.9727 - dice_coef_tumor: 0.9251 - iou_liver: 0.9468 - iou_tumor: 0.8638 - sensitivity_liver: 0.9754 - sensitivity_tumor: 0.9218 - specificity_liver: 0.9982 - specificity_tumor: 0.9998 - val_loss: 0.6841 - val_dice_coef_liver: 0.9715 - val_dice_coef_tumor: 0.9106 - val_iou_liver: 0.9446 - val_iou_tumor: 0.8414 - val_sensitivity_liver: 0.9795 - val_sensitivity_tumor: 0.9147 - val_specificity_liver: 0.9977 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
#
# Epoch 31/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6823 - dice_coef_liver: 0.9731 - dice_coef_tumor: 0.9247 - iou_liver: 0.9476 - iou_tumor: 0.8635 - sensitivity_liver: 0.9760 - sensitivity_tumor: 0.9215 - specificity_liver: 0.9982 - specificity_tumor: 0.9998
#
# Epoch 31: val_loss did not improve from 0.68414
#
# 836/836 [==============================] - 539s 644ms/step - loss: 0.6823 - dice_coef_liver: 0.9731 - dice_coef_tumor: 0.9247 - iou_liver: 0.9476 - iou_tumor: 0.8635 - sensitivity_liver: 0.9760 - sensitivity_tumor: 0.9215 - specificity_liver: 0.9982 - specificity_tumor: 0.9998 - val_loss: 0.6843 - val_dice_coef_liver: 0.9718 - val_dice_coef_tumor: 0.9088 - val_iou_liver: 0.9452 - val_iou_tumor: 0.8387 - val_sensitivity_liver: 0.9784 - val_sensitivity_tumor: 0.9183 - val_specificity_liver: 0.9978 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
#
# Epoch 32/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6824 - dice_coef_liver: 0.9733 - dice_coef_tumor: 0.9231 - iou_liver: 0.9481 - iou_tumor: 0.8629 - sensitivity_liver: 0.9761 - sensitivity_tumor: 0.9194 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
#
# Epoch 32: val_loss improved from 0.68414 to 0.68403, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 538s 643ms/step - loss: 0.6824 - dice_coef_liver: 0.9733 - dice_coef_tumor: 0.9231 - iou_liver: 0.9481 - iou_tumor: 0.8629 - sensitivity_liver: 0.9761 - sensitivity_tumor: 0.9194 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6840 - val_dice_coef_liver: 0.9726 - val_dice_coef_tumor: 0.9102 - val_iou_liver: 0.9466 - val_iou_tumor: 0.8418 - val_sensitivity_liver: 0.9779 - val_sensitivity_tumor: 0.9097 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
#
# Epoch 33/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6821 - dice_coef_liver: 0.9735 - dice_coef_tumor: 0.9257 - iou_liver: 0.9484 - iou_tumor: 0.8651 - sensitivity_liver: 0.9763 - sensitivity_tumor: 0.9223 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
#
# Epoch 33: val_loss improved from 0.68403 to 0.68382, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 537s 642ms/step - loss: 0.6821 - dice_coef_liver: 0.9735 - dice_coef_tumor: 0.9257 - iou_liver: 0.9484 - iou_tumor: 0.8651 - sensitivity_liver: 0.9763 - sensitivity_tumor: 0.9223 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6838 - val_dice_coef_liver: 0.9725 - val_dice_coef_tumor: 0.9122 - val_iou_liver: 0.9465 - val_iou_tumor: 0.8443 - val_sensitivity_liver: 0.9799 - val_sensitivity_tumor: 0.9078 - val_specificity_liver: 0.9978 - val_specificity_tumor: 0.9998 - lr: 3.0000e-05
#
# Epoch 34/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6817 - dice_coef_liver: 0.9737 - dice_coef_tumor: 0.9289 - iou_liver: 0.9488 - iou_tumor: 0.8703 - sensitivity_liver: 0.9764 - sensitivity_tumor: 0.9255 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
#
# Epoch 34: val_loss did not improve from 0.68382
#
# 836/836 [==============================] - 542s 648ms/step - loss: 0.6817 - dice_coef_liver: 0.9737 - dice_coef_tumor: 0.9289 - iou_liver: 0.9488 - iou_tumor: 0.8703 - sensitivity_liver: 0.9764 - sensitivity_tumor: 0.9255 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6839 - val_dice_coef_liver: 0.9724 - val_dice_coef_tumor: 0.9113 - val_iou_liver: 0.9463 - val_iou_tumor: 0.8423 - val_sensitivity_liver: 0.9777 - val_sensitivity_tumor: 0.9278 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
#
# Epoch 35/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6818 - dice_coef_liver: 0.9740 - dice_coef_tumor: 0.9279 - iou_liver: 0.9493 - iou_tumor: 0.8694 - sensitivity_liver: 0.9767 - sensitivity_tumor: 0.9249 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
#
# Epoch 35: val_loss improved from 0.68382 to 0.68380, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 539s 645ms/step - loss: 0.6818 - dice_coef_liver: 0.9740 - dice_coef_tumor: 0.9279 - iou_liver: 0.9493 - iou_tumor: 0.8694 - sensitivity_liver: 0.9767 - sensitivity_tumor: 0.9249 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6838 - val_dice_coef_liver: 0.9726 - val_dice_coef_tumor: 0.9124 - val_iou_liver: 0.9468 - val_iou_tumor: 0.8445 - val_sensitivity_liver: 0.9802 - val_sensitivity_tumor: 0.9032 - val_specificity_liver: 0.9978 - val_specificity_tumor: 0.9998 - lr: 3.0000e-05
#
# Epoch 36/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6815 - dice_coef_liver: 0.9742 - dice_coef_tumor: 0.9307 - iou_liver: 0.9497 - iou_tumor: 0.8738 - sensitivity_liver: 0.9769 - sensitivity_tumor: 0.9275 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
#
# Epoch 36: val_loss improved from 0.68380 to 0.68350, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 544s 650ms/step - loss: 0.6815 - dice_coef_liver: 0.9742 - dice_coef_tumor: 0.9307 - iou_liver: 0.9497 - iou_tumor: 0.8738 - sensitivity_liver: 0.9769 - sensitivity_tumor: 0.9275 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6835 - val_dice_coef_liver: 0.9728 - val_dice_coef_tumor: 0.9147 - val_iou_liver: 0.9471 - val_iou_tumor: 0.8478 - val_sensitivity_liver: 0.9802 - val_sensitivity_tumor: 0.9218 - val_specificity_liver: 0.9978 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
#
# Epoch 37/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6813 - dice_coef_liver: 0.9744 - dice_coef_tumor: 0.9318 - iou_liver: 0.9502 - iou_tumor: 0.8758 - sensitivity_liver: 0.9772 - sensitivity_tumor: 0.9280 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
#
# Epoch 37: val_loss improved from 0.68350 to 0.68345, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 540s 646ms/step - loss: 0.6813 - dice_coef_liver: 0.9744 - dice_coef_tumor: 0.9318 - iou_liver: 0.9502 - iou_tumor: 0.8758 - sensitivity_liver: 0.9772 - sensitivity_tumor: 0.9280 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6835 - val_dice_coef_liver: 0.9734 - val_dice_coef_tumor: 0.9141 - val_iou_liver: 0.9482 - val_iou_tumor: 0.8478 - val_sensitivity_liver: 0.9773 - val_sensitivity_tumor: 0.9148 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9998 - lr: 3.0000e-05
#
# Epoch 38/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6812 - dice_coef_liver: 0.9746 - dice_coef_tumor: 0.9323 - iou_liver: 0.9505 - iou_tumor: 0.8771 - sensitivity_liver: 0.9773 - sensitivity_tumor: 0.9288 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
#
# Epoch 38: val_loss improved from 0.68345 to 0.68332, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 539s 645ms/step - loss: 0.6812 - dice_coef_liver: 0.9746 - dice_coef_tumor: 0.9323 - iou_liver: 0.9505 - iou_tumor: 0.8771 - sensitivity_liver: 0.9773 - sensitivity_tumor: 0.9288 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6833 - val_dice_coef_liver: 0.9732 - val_dice_coef_tumor: 0.9157 - val_iou_liver: 0.9479 - val_iou_tumor: 0.8494 - val_sensitivity_liver: 0.9796 - val_sensitivity_tumor: 0.9207 - val_specificity_liver: 0.9979 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
#
# Epoch 39/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6810 - dice_coef_liver: 0.9748 - dice_coef_tumor: 0.9340 - iou_liver: 0.9508 - iou_tumor: 0.8786 - sensitivity_liver: 0.9775 - sensitivity_tumor: 0.9310 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
#
# Epoch 39: val_loss did not improve from 0.68332
#
# 836/836 [==============================] - 543s 649ms/step - loss: 0.6810 - dice_coef_liver: 0.9748 - dice_coef_tumor: 0.9340 - iou_liver: 0.9508 - iou_tumor: 0.8786 - sensitivity_liver: 0.9775 - sensitivity_tumor: 0.9310 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6834 - val_dice_coef_liver: 0.9731 - val_dice_coef_tumor: 0.9151 - val_iou_liver: 0.9477 - val_iou_tumor: 0.8479 - val_sensitivity_liver: 0.9789 - val_sensitivity_tumor: 0.9310 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
#
# Epoch 40/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6812 - dice_coef_liver: 0.9749 - dice_coef_tumor: 0.9320 - iou_liver: 0.9511 - iou_tumor: 0.8764 - sensitivity_liver: 0.9776 - sensitivity_tumor: 0.9289 - specificity_liver: 0.9984 - specificity_tumor: 0.9998
#
# Epoch 40: val_loss improved from 0.68332 to 0.68310, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 540s 646ms/step - loss: 0.6812 - dice_coef_liver: 0.9749 - dice_coef_tumor: 0.9320 - iou_liver: 0.9511 - iou_tumor: 0.8764 - sensitivity_liver: 0.9776 - sensitivity_tumor: 0.9289 - specificity_liver: 0.9984 - specificity_tumor: 0.9998 - val_loss: 0.6831 - val_dice_coef_liver: 0.9736 - val_dice_coef_tumor: 0.9171 - val_iou_liver: 0.9486 - val_iou_tumor: 0.8517 - val_sensitivity_liver: 0.9797 - val_sensitivity_tumor: 0.9149 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9998 - lr: 3.0000e-05
#
# Epoch 41/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6812 - dice_coef_liver: 0.9749 - dice_coef_tumor: 0.9322 - iou_liver: 0.9510 - iou_tumor: 0.8758 - sensitivity_liver: 0.9776 - sensitivity_tumor: 0.9288 - specificity_liver: 0.9984 - specificity_tumor: 0.9998
#
# Epoch 41: val_loss did not improve from 0.68310
#
# 836/836 [==============================] - 540s 645ms/step - loss: 0.6812 - dice_coef_liver: 0.9749 - dice_coef_tumor: 0.9322 - iou_liver: 0.9510 - iou_tumor: 0.8758 - sensitivity_liver: 0.9776 - sensitivity_tumor: 0.9288 - specificity_liver: 0.9984 - specificity_tumor: 0.9998 - val_loss: 0.6831 - val_dice_coef_liver: 0.9740 - val_dice_coef_tumor: 0.9166 - val_iou_liver: 0.9494 - val_iou_tumor: 0.8513 - val_sensitivity_liver: 0.9768 - val_sensitivity_tumor: 0.9193 - val_specificity_liver: 0.9982 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
#
# Epoch 42/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6811 - dice_coef_liver: 0.9751 - dice_coef_tumor: 0.9331 - iou_liver: 0.9515 - iou_tumor: 0.8787 - sensitivity_liver: 0.9778 - sensitivity_tumor: 0.9294 - specificity_liver: 0.9984 - specificity_tumor: 0.9998
#
# Epoch 42: val_loss did not improve from 0.68310
#
# 836/836 [==============================] - 541s 646ms/step - loss: 0.6811 - dice_coef_liver: 0.9751 - dice_coef_tumor: 0.9331 - iou_liver: 0.9515 - iou_tumor: 0.8787 - sensitivity_liver: 0.9778 - sensitivity_tumor: 0.9294 - specificity_liver: 0.9984 - specificity_tumor: 0.9998 - val_loss: 0.6831 - val_dice_coef_liver: 0.9738 - val_dice_coef_tumor: 0.9167 - val_iou_liver: 0.9491 - val_iou_tumor: 0.8512 - val_sensitivity_liver: 0.9788 - val_sensitivity_tumor: 0.9067 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9998 - lr: 3.0000e-05
#
# Epoch 43/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6807 - dice_coef_liver: 0.9754 - dice_coef_tumor: 0.9361 - iou_liver: 0.9520 - iou_tumor: 0.8821 - sensitivity_liver: 0.9781 - sensitivity_tumor: 0.9324 - specificity_liver: 0.9984 - specificity_tumor: 0.9998
#
# Epoch 43: val_loss improved from 0.68310 to 0.68305, saving model to /kaggle/working/WNet_Res50.h5
#
#
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# 836/836 [==============================] - 540s 646ms/step - loss: 0.6807 - dice_coef_liver: 0.9754 - dice_coef_tumor: 0.9361 - iou_liver: 0.9520 - iou_tumor: 0.8821 - sensitivity_liver: 0.9781 - sensitivity_tumor: 0.9324 - specificity_liver: 0.9984 - specificity_tumor: 0.9998 - val_loss: 0.6831 - val_dice_coef_liver: 0.9739 - val_dice_coef_tumor: 0.9175 - val_iou_liver: 0.9491 - val_iou_tumor: 0.8520 - val_sensitivity_liver: 0.9797 - val_sensitivity_tumor: 0.9272 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
#
# Epoch 44/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6808 - dice_coef_liver: 0.9757 - dice_coef_tumor: 0.9347 - iou_liver: 0.9526 - iou_tumor: 0.8810 - sensitivity_liver: 0.9784 - sensitivity_tumor: 0.9306 - specificity_liver: 0.9984 - specificity_tumor: 0.9998
#
# Epoch 44: val_loss improved from 0.68305 to 0.68282, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 540s 645ms/step - loss: 0.6808 - dice_coef_liver: 0.9757 - dice_coef_tumor: 0.9347 - iou_liver: 0.9526 - iou_tumor: 0.8810 - sensitivity_liver: 0.9784 - sensitivity_tumor: 0.9306 - specificity_liver: 0.9984 - specificity_tumor: 0.9998 - val_loss: 0.6828 - val_dice_coef_liver: 0.9742 - val_dice_coef_tumor: 0.9189 - val_iou_liver: 0.9497 - val_iou_tumor: 0.8548 - val_sensitivity_liver: 0.9794 - val_sensitivity_tumor: 0.9164 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9998 - lr: 9.0000e-06
#
# Epoch 45/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6801 - dice_coef_liver: 0.9758 - dice_coef_tumor: 0.9410 - iou_liver: 0.9528 - iou_tumor: 0.8899 - sensitivity_liver: 0.9784 - sensitivity_tumor: 0.9383 - specificity_liver: 0.9984 - specificity_tumor: 0.9998
#
# Epoch 45: val_loss improved from 0.68282 to 0.68265, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 541s 647ms/step - loss: 0.6801 - dice_coef_liver: 0.9758 - dice_coef_tumor: 0.9410 - iou_liver: 0.9528 - iou_tumor: 0.8899 - sensitivity_liver: 0.9784 - sensitivity_tumor: 0.9383 - specificity_liver: 0.9984 - specificity_tumor: 0.9998 - val_loss: 0.6826 - val_dice_coef_liver: 0.9743 - val_dice_coef_tumor: 0.9205 - val_iou_liver: 0.9499 - val_iou_tumor: 0.8572 - val_sensitivity_liver: 0.9810 - val_sensitivity_tumor: 0.9135 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9998 - lr: 9.0000e-06
#
# Epoch 46/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6801 - dice_coef_liver: 0.9760 - dice_coef_tumor: 0.9410 - iou_liver: 0.9531 - iou_tumor: 0.8908 - sensitivity_liver: 0.9787 - sensitivity_tumor: 0.9376 - specificity_liver: 0.9984 - specificity_tumor: 0.9998
#
# Epoch 46: val_loss did not improve from 0.68265
#
# 836/836 [==============================] - 541s 647ms/step - loss: 0.6801 - dice_coef_liver: 0.9760 - dice_coef_tumor: 0.9410 - iou_liver: 0.9531 - iou_tumor: 0.8908 - sensitivity_liver: 0.9787 - sensitivity_tumor: 0.9376 - specificity_liver: 0.9984 - specificity_tumor: 0.9998 - val_loss: 0.6827 - val_dice_coef_liver: 0.9744 - val_dice_coef_tumor: 0.9195 - val_iou_liver: 0.9502 - val_iou_tumor: 0.8561 - val_sensitivity_liver: 0.9801 - val_sensitivity_tumor: 0.9169 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9998 - lr: 9.0000e-06
#
# Epoch 47/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6803 - dice_coef_liver: 0.9761 - dice_coef_tumor: 0.9386 - iou_liver: 0.9533 - iou_tumor: 0.8865 - sensitivity_liver: 0.9787 - sensitivity_tumor: 0.9352 - specificity_liver: 0.9984 - specificity_tumor: 0.9998
#
# Epoch 47: val_loss did not improve from 0.68265
#
# 836/836 [==============================] - 540s 645ms/step - loss: 0.6803 - dice_coef_liver: 0.9761 - dice_coef_tumor: 0.9386 - iou_liver: 0.9533 - iou_tumor: 0.8865 - sensitivity_liver: 0.9787 - sensitivity_tumor: 0.9352 - specificity_liver: 0.9984 - specificity_tumor: 0.9998 - val_loss: 0.6828 - val_dice_coef_liver: 0.9744 - val_dice_coef_tumor: 0.9190 - val_iou_liver: 0.9501 - val_iou_tumor: 0.8552 - val_sensitivity_liver: 0.9800 - val_sensitivity_tumor: 0.9198 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9998 - lr: 9.0000e-06
#
# Epoch 48/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6799 - dice_coef_liver: 0.9761 - dice_coef_tumor: 0.9422 - iou_liver: 0.9533 - iou_tumor: 0.8926 - sensitivity_liver: 0.9787 - sensitivity_tumor: 0.9395 - specificity_liver: 0.9984 - specificity_tumor: 0.9998
#
# Epoch 48: val_loss improved from 0.68265 to 0.68250, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 542s 648ms/step - loss: 0.6799 - dice_coef_liver: 0.9761 - dice_coef_tumor: 0.9422 - iou_liver: 0.9533 - iou_tumor: 0.8926 - sensitivity_liver: 0.9787 - sensitivity_tumor: 0.9395 - specificity_liver: 0.9984 - specificity_tumor: 0.9998 - val_loss: 0.6825 - val_dice_coef_liver: 0.9745 - val_dice_coef_tumor: 0.9215 - val_iou_liver: 0.9504 - val_iou_tumor: 0.8590 - val_sensitivity_liver: 0.9799 - val_sensitivity_tumor: 0.9212 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9998 - lr: 9.0000e-06
#
# Epoch 49/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6799 - dice_coef_liver: 0.9762 - dice_coef_tumor: 0.9425 - iou_liver: 0.9536 - iou_tumor: 0.8930 - sensitivity_liver: 0.9789 - sensitivity_tumor: 0.9399 - specificity_liver: 0.9984 - specificity_tumor: 0.9998
#
# Epoch 49: val_loss did not improve from 0.68250
#
# 836/836 [==============================] - 542s 647ms/step - loss: 0.6799 - dice_coef_liver: 0.9762 - dice_coef_tumor: 0.9425 - iou_liver: 0.9536 - iou_tumor: 0.8930 - sensitivity_liver: 0.9789 - sensitivity_tumor: 0.9399 - specificity_liver: 0.9984 - specificity_tumor: 0.9998 - val_loss: 0.6827 - val_dice_coef_liver: 0.9747 - val_dice_coef_tumor: 0.9194 - val_iou_liver: 0.9507 - val_iou_tumor: 0.8560 - val_sensitivity_liver: 0.9810 - val_sensitivity_tumor: 0.9106 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9998 - lr: 9.0000e-06
#
# Epoch 50/50
#
# 836/836 [==============================] - ETA: 0s - loss: 0.6801 - dice_coef_liver: 0.9762 - dice_coef_tumor: 0.9404 - iou_liver: 0.9536 - iou_tumor: 0.8918 - sensitivity_liver: 0.9789 - sensitivity_tumor: 0.9371 - specificity_liver: 0.9984 - specificity_tumor: 0.9998
#
# Epoch 50: val_loss improved from 0.68250 to 0.68247, saving model to /kaggle/working/WNet_Res50.h5
#
# 836/836 [==============================] - 543s 649ms/step - loss: 0.6801 - dice_coef_liver: 0.9762 - dice_coef_tumor: 0.9404 - iou_liver: 0.9536 - iou_tumor: 0.8918 - sensitivity_liver: 0.9789 - sensitivity_tumor: 0.9371 - specificity_liver: 0.9984 - specificity_tumor: 0.9998 - val_loss: 0.6825 - val_dice_coef_liver: 0.9748 - val_dice_coef_tumor: 0.9215 - val_iou_liver: 0.9508 - val_iou_tumor: 0.8592 - val_sensitivity_liver: 0.9797 - val_sensitivity_tumor: 0.9151 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9998 - lr: 9.0000e-06

# %%
#im using the log files from the last commit
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/input/logs-wnetres50-lits/training_log_WNet_Res50 (1)', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score_tumor=history['iou_tumor']
val_iou_score_tumor=history['val_iou_tumor']

iou_score_liver=history['iou_liver']
val_iou_score_liver=history['val_iou_liver']

loss=history['loss']
val_loss=history['val_loss']

train_dice_tumor=history['dice_coef_tumor']
val_dice_tumor=history['val_dice_coef_tumor']

train_dice_liver=history['dice_coef_liver']
val_dice_liver=history['val_dice_coef_liver']


epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score_liver, 'b', label='Training IOU liver', linewidth=1.5)
axes[1].plot(epoch, val_iou_score_liver, 'b--', label='Val IOU Liver', linewidth=1.5)
axes[1].plot(epoch, iou_score_tumor, 'r', label='Training IOU tumor', linewidth=1.5)
axes[1].plot(epoch, val_iou_score_tumor, 'r--', label='Val IOU tumor', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice_liver, 'b', label='Training DC liver', linewidth=1.5)
axes[2].plot(epoch, val_dice_liver, 'b--', label='Val DC liver', linewidth=1.5)
axes[2].plot(epoch, train_dice_tumor, 'r', label='Training DC tumor', linewidth=1.5)
axes[2].plot(epoch, val_dice_tumor, 'r--', label='Val DC tumor', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()


# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Testing Model

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                #mask = mask.astype(np.int32)
    

            """augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])"""
            images.append(image)
            masks.append(mask)
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        #masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        masks = np.array(tf.one_hot(masks, 3, dtype = tf.float32))
        return  images, masks

# Example usage of the CustomDataGenerator
test_generator = CustomDataGenerator(df_test, batch_size=16, image_size=(256, 256), shuffle=True)

# %%
model = build_WNet((256,256,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 4s 0us/step

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001), loss=total_loss,
              metrics = {"output_1":[dice_coef_liver,dice_coef_tumor,iou_liver,iou_tumor,sensitivity_liver,sensitivity_tumor,specificity_liver,specificity_tumor]})

# %%
model.load_weights("/kaggle/input/logs-wnetres50-lits/WNet_Res50.h5")

# %%
results = model.evaluate(test_generator)
# Out:
# 216/216 [==============================] - 121s 506ms/step - loss: 0.6820 - dice_coef_liver: 0.9740 - dice_coef_tumor: 0.9238 - iou_liver: 0.9494 - iou_tumor: 0.8643 - sensitivity_liver: 0.9788 - sensitivity_tumor: 0.9193 - specificity_liver: 0.9981 - specificity_tumor: 0.9998

# %%
#!zip -r weights_WNet_Res50_AT_CL.zip /kaggle/working/WNet_maxpool.h5

# %%
#from IPython.display import FileLink
#FileLink(r'weights_WNet_Res50_AT_CL.zip')
