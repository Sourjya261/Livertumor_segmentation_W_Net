# %%
import os
import pandas as pd
from tqdm import tqdm

def read_slice_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image slice files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)
        mask_path = mask_path.split(".")[0] + ".tiff"

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask slice folders
image_slice_folder = "/kaggle/input/lits-slices/kaggle/working/images"
mask_slice_folder = "/kaggle/input/lits-slices/kaggle/working/masks"

# Read slice paths and create a DataFrame
df_slices = read_slice_paths(image_slice_folder, mask_slice_folder)
# Out:
# 100%|██████████| 19131/19131 [00:42<00:00, 452.28it/s]

# %%
df_slices.head(5)
# Out:
#                                                Image  \
# 0  /kaggle/input/lits-slices/kaggle/working/image...
# 1  /kaggle/input/lits-slices/kaggle/working/image...
# 2  /kaggle/input/lits-slices/kaggle/working/image...
# 3  /kaggle/input/lits-slices/kaggle/working/image...
# 4  /kaggle/input/lits-slices/kaggle/working/image...
#
#                                                 Mask
# 0  /kaggle/input/lits-slices/kaggle/working/masks...
# 1  /kaggle/input/lits-slices/kaggle/working/masks...
# 2  /kaggle/input/lits-slices/kaggle/working/masks...
# 3  /kaggle/input/lits-slices/kaggle/working/masks...
# 4  /kaggle/input/lits-slices/kaggle/working/masks...

# %%
#sanity check
print(df_slices["Image"][0])
print(df_slices["Mask"][0])
# Out:
# /kaggle/input/lits-slices/kaggle/working/images/volume-126_slice_228.jpg
# /kaggle/input/lits-slices/kaggle/working/masks/volume-126_slice_228.tiff

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                #mask = mask.astype(np.int32)
    

            augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        #masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        masks = np.array(tf.one_hot(masks, 3, dtype = tf.float32))
        return  images, masks

# Example usage of the CustomDataGenerator
train_generator = CustomDataGenerator(df_slices, batch_size=8, image_size=(256, 256), shuffle=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import matplotlib.pyplot as plt

# Load a single batch
batch = train_generator[0]  # Assuming you want to load the first batch

# Extract images and labels from the batch
images, masks = batch

# Display the images and masks
n_images_to_display = len(images)
fig, ax = plt.subplots(n_images_to_display, 2, figsize=(10, 20))

for i in range(n_images_to_display):
    ax[i, 0].imshow(images[i], cmap='bone')
    #print(np.max(images[i]))
    ax[i, 0].set_title('Image')
    ax[i, 1].imshow(masks[i], cmap='bone')
    #print(np.max(masks[i]))
    ax[i, 1].set_title('Mask')

    ax[i, 0].axis('off')
    ax[i, 1].axis('off')
plt.show()

# %%
import cv2
import pandas as pd

# Assuming df_slices is your DataFrame with "Image" and "Mask" columns
# Add the "Num_Classes" column with default value 0
df_slices["Num_Classes"] = 0

# Function to read the mask using cv2 and return the number of unique classes
def read_mask_and_count_classes(mask_path):
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    mask = mask.astype(np.int32)
    val, counts = np.unique(mask, return_counts=True)
    return len(counts)

# Apply the function to each row in the DataFrame
tqdm.pandas(desc="Processing Masks", unit="mask")
df_slices["Num_Classes"] = df_slices["Mask"].progress_apply(read_mask_and_count_classes)
# Out:
# Processing Masks: 100%|██████████| 19131/19131 [04:18<00:00, 73.88mask/s]

# %%
df_slices.head(5)
# Out:
#                                                Image  \
# 0  /kaggle/input/lits-slices/kaggle/working/image...
# 1  /kaggle/input/lits-slices/kaggle/working/image...
# 2  /kaggle/input/lits-slices/kaggle/working/image...
# 3  /kaggle/input/lits-slices/kaggle/working/image...
# 4  /kaggle/input/lits-slices/kaggle/working/image...
#
#                                                 Mask  Num_Classes
# 0  /kaggle/input/lits-slices/kaggle/working/masks...            3
# 1  /kaggle/input/lits-slices/kaggle/working/masks...            3
# 2  /kaggle/input/lits-slices/kaggle/working/masks...            2
# 3  /kaggle/input/lits-slices/kaggle/working/masks...            3
# 4  /kaggle/input/lits-slices/kaggle/working/masks...            2

# %%
from sklearn.model_selection import train_test_split

df_shuffled = df_slices.sample(frac=1, random_state=42)

df_train, df_temp = train_test_split(df_shuffled, test_size=0.30, stratify=df_shuffled["Num_Classes"], random_state=42)
df_val, df_test = train_test_split(df_temp, test_size=0.6, stratify=df_temp["Num_Classes"], random_state=42)

# %%
unique_values = df_slices['Num_Classes'].unique()
print("Unique values in 'Num_Classes' column:", unique_values)
value_counts = df_slices['Num_Classes'].value_counts(normalize=True)
print("\nRatio of each unique value in 'num_classes' column:",value_counts)
# Out:
# Unique values in 'Num_Classes' column: [3 2]
#
# Ratio of each unique value in 'num_classes' column: Num_Classes
# 2    0.624536
# 3    0.375464
# Name: proportion, dtype: float64

# %%
unique_values = df_train['Num_Classes'].unique()
print("Unique values in 'Num_Classes' column:", unique_values)
value_counts = df_train['Num_Classes'].value_counts(normalize=True)
print("\nRatio of each unique value in 'num_classes' column:",value_counts)
# Out:
# Unique values in 'Num_Classes' column: [2 3]
#
# Ratio of each unique value in 'num_classes' column: Num_Classes
# 2    0.624524
# 3    0.375476
# Name: proportion, dtype: float64

# %%
unique_values = df_val['Num_Classes'].unique()
print("Unique values in 'Num_Classes' column:", unique_values)
value_counts = df_val['Num_Classes'].value_counts(normalize=True)
print("\nRatio of each unique value in 'num_classes' column:",value_counts)
# Out:
# Unique values in 'Num_Classes' column: [2 3]
#
# Ratio of each unique value in 'num_classes' column: Num_Classes
# 2    0.624564
# 3    0.375436
# Name: proportion, dtype: float64

# %%
unique_values = df_test['Num_Classes'].unique()
print("Unique values in 'Num_Classes' column:", unique_values)
value_counts = df_test['Num_Classes'].value_counts(normalize=True)
print("\nRatio of each unique value in 'num_classes' column:",value_counts)
# Out:
# Unique values in 'Num_Classes' column: [3 2]
#
# Ratio of each unique value in 'num_classes' column: Num_Classes
# 2    0.624564
# 3    0.375436
# Name: proportion, dtype: float64

# %%
# bar plot
from matplotlib import pyplot as plt
sizes = [len(df_train), len(df_val), len(df_test)]
labels = ['Train', 'Validation', 'Test']

plt.bar(labels, sizes, color=['blue', 'orange', 'green'])
plt.xlabel('Data Split')
plt.ylabel('Number of Samples')
plt.title('Dataset Split: Train, Validation')
plt.show()

# %% [markdown]
# # Model Architecture and Helper blocks

# %%
#GCSE Block...from the GCSER UNET (Mukherjee et al.)
def GCSE(input_tensor, ratio=16):


    # Compute the global statistics (mean and std deviation) along the channel axis.
    mean = tf.reduce_mean(input_tensor, axis=[1, 2], keepdims=True)
    std = tf.math.reduce_std(input_tensor, axis=[1, 2], keepdims=True)

    # Compute channel-wise attention using a convolutional neural network.
    attn_channel = tf.concat([mean, std], axis=-1)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1] // ratio, kernel_size=(1, 1), activation='relu')(attn_channel)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1], kernel_size=(1, 1), activation='sigmoid')(attn_channel)

    # Compute spatial attention using global information from the input tensor.
    global_info = tf.reduce_mean(input_tensor, axis=-1, keepdims=True)
    attn_spatial = tf.keras.layers.Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(global_info)

    # Combine channel-wise and spatial attention.
    attn = tf.keras.layers.Multiply()([attn_channel,attn_spatial])

    # Multiply the input tensor by the learned attention weights.
    output_tensor = tf.keras.layers.Multiply()([input_tensor,attn])

    return output_tensor

# %%
def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=3, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=5, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=7, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
from tensorflow.keras.applications import ResNet50
def build_encoder2(inputs):

    s=[]
    """ Pre-trained ResNet50 Model """
    resnet50= ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
    for layer in resnet50.layers:
        layer.trainable = True


    """ Encoder """
    s1 = resnet50.get_layer("model_input").output    
    s.append(s1)
    s2 = resnet50.get_layer("conv1_relu").output   
    s.append(s2)
    s3 = resnet50.get_layer("conv2_block3_out").output  
    s.append(s3)
    s4 = resnet50.get_layer("conv3_block4_out").output  
    s.append(s4)

    """ Bridge """
    #b1 = resnet50.get_layer("conv4_block6_out").output 
    b = resnet50.get_layer("conv4_block2_out").output 
    b = ASPP(b,128)
    
    encoder2 = Model(inputs,outputs=[s,b],name = "encoder2")

    return encoder2

# %% [markdown]
# # Asymmetric architecture

# %%
# Code for W-Net

from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D,Conv2DTranspose, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input, ZeroPadding2D,Dropout,Dense,MaxPooling2D,Reshape,Multiply,GlobalAveragePooling2D,AveragePooling2D
from tensorflow.keras.models import Model


"""def complementary_loss(y_true, y_pred):
    mse_loss = tf.reduce_mean(tf.square(y_true - y_pred))
    return tf.math.sigmoid(mse_loss)"""
def complementary_loss(feature_map1,feature_map2):
    # Normalize the feature maps to [0, 1]
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    m1 = tf.reduce_mean(feature_map1)
    m2  = tf.reduce_mean(feature_map2)

    return tf.math.sigmoid(tf.abs(m1-m2))


def batchnorm_relu(inputs):
    x = BatchNormalization()(inputs)
    #x = Activation("relu")(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    return x

def residual_block(inputs, num_filters):
    """ Convolutional Layer """
    x = batchnorm_relu(inputs)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
    x = Dropout(0.1)(x)
    x = batchnorm_relu(x)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)


    """ Shortcut Connection """
    s = Conv2D(num_filters, 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = x + s
    return x

def decoder_block(inputs, s1,s2, num_filters):
    x = Conv2DTranspose(num_filters,2, strides=(2,2), kernel_initializer="he_normal",padding = "same")(inputs)
    x = Concatenate()([x,s1,s2])
    x = residual_block(x, num_filters)
    x = GCSE(x)
    return x
def build_encoder1(inputs,f):
    
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = batchnorm_relu(x)
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(x)
    s = Conv2D(f[0], 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)

    c1 = x + s
    c1 = GCSE(c1)
    p1 = MaxPooling2D((2,2))(c1)
    s1 = c1

    c2 = residual_block(p1, f[1])
    c2 = GCSE(c2)
    p2 = MaxPooling2D((2,2))(c2)
    s2 = c2

    c3 = residual_block(p2, f[2])
    c3 = GCSE(c3)
    p3 = MaxPooling2D((2,2))(c3)
    s3 = c3

    c4 = residual_block(p3, f[3])
    c4 = GCSE(c4)
    p4 = MaxPooling2D((2,2))(c4)
    s4 = c4
    
    s_ = [s1,s2,s3,s4]
    """ Bridge """
    b = ASPP(p4,128)
    encoder1 = Model(inputs,outputs=[s_,b],name="encoder1")
    return encoder1

    
    

def build_WNet(input_shape):
    f = [16,32,64,128]

    inputs = Input(input_shape,name="model_input")
    encoder1 = build_encoder1(inputs,f)
    encoder2 = build_encoder2(inputs)
    s1,b1 = encoder1(inputs)
    s2,b2 = encoder2(inputs)

    b = Concatenate()([b1,b2])

    """ Decoder 1, 2, 3 """
    d1 = decoder_block(b, s2[3],s1[3], f[3]+512)
    d2 = decoder_block(d1, s2[2],s1[2], f[2]+256)
    d3 = decoder_block(d2, s2[1],s1[1], f[1]+64)
    d4 = decoder_block(d3, s2[0],s1[0],f[0]+3)
    
    comp1 = complementary_loss(s2[0], s1[0])
    comp2 = complementary_loss(s2[1], s1[1])
    comp3 = complementary_loss(s2[2], s1[2])
    comp4 = complementary_loss(s2[3], s1[3])

    

    output_2 = tf.keras.layers.Add(name='output_2')([comp1/4.0,comp2/4.0,comp3/4.0,comp4/4.0])

    """ Classifier """
    output_1 = Conv2D(3, (1,1) , activation="softmax",name='output_1')(d4)

    """ Model """
    model = Model(inputs,outputs=[output_1,output_2])
    return model

# %% [markdown]
# # Evaluation Metrics

# %%
from keras import backend as K
def iou_liver(targets, inputs, smooth=1e-6):
    
    #flatten label and prediction tensors
    targets_f = K.flatten(targets[:,:,:,1])
    inputs_f = K.flatten(inputs[:,:,:,1])
    
    
    intersection = K.sum((targets_f*inputs_f))
    total = K.sum(targets_f) + K.sum(inputs_f)
    union = total - intersection
    
    IoU = (intersection + smooth) / (union + smooth)
    return IoU

def iou_tumor(targets, inputs, smooth=1e-6):
    
    #flatten label and prediction tensors
    targets_f = K.flatten(targets[:,:,:,2])
    inputs_f = K.flatten(inputs[:,:,:,2])
    
    intersection = K.sum((targets_f * inputs_f))
    total = K.sum(targets_f) + K.sum(inputs_f)
    union = total - intersection
    
    IoU = (intersection + smooth) / (union + smooth)
    return IoU

def iou(targets, inputs, smooth=1e-6):
    
    #flatten label and prediction tensors
    class_num = 3
    for i in range(class_num):
        targets_f= K.flatten(targets[:,:,:,i])
        inputs_f = K.flatten(inputs[:,:,:,i])
       

        intersection = K.sum((targets_f*inputs_f))
        total = K.sum(targets_f) + K.sum(inputs_f)
        union = total - intersection
        loss = (intersection + smooth) / (union + smooth)
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss
def dice_coef(y_true, y_pred, smooth=1e-5):
    class_num = 3
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
   #     K.print_tensor(loss, message='loss value for class {} : '.format(SEGMENT_CLASSES[i]))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
#    K.print_tensor(total_loss, message=' total dice coef: ')
    return total_loss
def dice_coef_liver(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true[:,:,:,1])
    y_pred_f = K.flatten(y_pred[:,:,:,1])
    intersection = K.sum(y_true_f * y_pred_f)
    loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
    return loss

def dice_coef_tumor(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true[:,:,:,2])
    y_pred_f = K.flatten(y_pred[:,:,:,2])
    intersection = K.sum(y_true_f * y_pred_f)
    loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
    return loss

# Computing Sensitivity      
def sensitivity_liver(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true[:,:,:,1] * y_pred[:,:,:,1], 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true[:,:,:,1], 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def sensitivity_tumor(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true[:,:,:,2] * y_pred[:,:,:,2], 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true[:,:,:,2], 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


# Computing Specificity
def specificity_liver(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true[:,:,:,1]) * (1-y_pred[:,:,:,1]), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true[:,:,:,1], 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())
def specificity_tumor(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true[:,:,:,2]) * (1-y_pred[:,:,:,2]), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true[:,:,:,2], 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def tversky(y_true, y_pred):
    smooth=1
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return (3 - tversky(y_true[:,:,:,0],y_pred[:,:,:,0])-tversky(y_true[:,:,:,1],y_pred[:,:,:,1])-tversky(y_true[:,:,:,2],y_pred[:,:,:,2]))

def focal_tversky_loss(y_true,y_pred):
    pt_1 = tversky(y_true[:,:,:,0],y_pred[:,:,:,0])
    pt_2 = tversky(y_true[:,:,:,1],y_pred[:,:,:,1])
    pt_3 = tversky(y_true[:,:,:,2],y_pred[:,:,:,2])
    
    gamma = 0.75
    return K.pow((3-pt_1-pt_2-pt_3), gamma)

# %%
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

# %%
# !pip install -U segmentation-models
#%env SM_FRAMEWORK=tf.keras
# Out:
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.0 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation-models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from efficientnet==1.0.0->segmentation-models) (0.21.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.10/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.24.3)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.9.0)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (9.5.0)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.8.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (21.3)
# Requirement already satisfied: lazy_loader>=0.2 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image->efficientnet==1.0.0->segmentation-models) (3.0.9)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1

# %%
import segmentation_models as sm
dice_loss = sm.losses.DiceLoss(class_weights = [0.33,0.33,0.33]) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from keras.callbacks import CSVLogger
model = build_WNet((256,256,3))
adam = tf.keras.optimizers.Adam(learning_rate = 0.0001)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  model_input (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#  encoder1 (Functional)       [[(None, 256, 256, 16),      870567    ['model_input[0][0]']
#                               (None, 128, 128, 32),
#                               (None, 64, 64, 64),
#                               (None, 32, 32, 128)],
#                               (None, 16, 16, 128)]
#
#  encoder2 (Functional)       [[(None, 256, 256, 3),       7988224   ['model_input[0][0]']
#                               (None, 128, 128, 64),
#                               (None, 64, 64, 256),
#                               (None, 32, 32, 512)],
#                               (None, 16, 16, 128)]
#
#  concatenate_2 (Concatenate  (None, 16, 16, 256)          0         ['encoder1[0][4]',
#  )                                                                   'encoder2[0][4]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 640)          656000    ['concatenate_2[0][0]']
#  anspose)
#
#  concatenate_3 (Concatenate  (None, 32, 32, 1280)         0         ['conv2d_transpose[0][0]',
#  )                                                                   'encoder2[0][3]',
#                                                                      'encoder1[0][3]']
#
#  batch_normalization_19 (Ba  (None, 32, 32, 1280)         5120      ['concatenate_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 32, 1280)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 32, 32, 640)          7373440   ['leaky_re_lu_7[0][0]']
#
#  dropout_3 (Dropout)         (None, 32, 32, 640)          0         ['conv2d_36[0][0]']
#
#  batch_normalization_20 (Ba  (None, 32, 32, 640)          2560      ['dropout_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 32, 32, 640)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 640)          3687040   ['leaky_re_lu_8[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 32, 32, 640)          819840    ['concatenate_3[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 32, 32, 640)          0         ['conv2d_37[0][0]',
#  OpLambda)                                                           'conv2d_38[0][0]']
#
#  tf.math.reduce_mean_8 (TFO  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  tf.math.reduce_std_4 (TFOp  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_4 (TFOpLambda)    (None, 1, 1, 1280)           0         ['tf.math.reduce_mean_8[0][0]'
#                                                                     , 'tf.math.reduce_std_4[0][0]'
#                                                                     ]
#
#  conv2d_39 (Conv2D)          (None, 1, 1, 40)             51240     ['tf.concat_4[0][0]']
#
#  tf.math.reduce_mean_9 (TFO  (None, 32, 32, 1)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  conv2d_40 (Conv2D)          (None, 1, 1, 640)            26240     ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 1)            2         ['tf.math.reduce_mean_9[0][0]'
#                                                                     ]
#
#  multiply_8 (Multiply)       (None, 32, 32, 640)          0         ['conv2d_40[0][0]',
#                                                                      'conv2d_41[0][0]']
#
#  multiply_9 (Multiply)       (None, 32, 32, 640)          0         ['tf.__operators__.add_4[0][0]
#                                                                     ',
#                                                                      'multiply_8[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 320)          819520    ['multiply_9[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 64, 64, 640)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'encoder2[0][2]',
#                                                                      'encoder1[0][2]']
#
#  batch_normalization_21 (Ba  (None, 64, 64, 640)          2560      ['concatenate_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 64, 64, 640)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 320)          1843520   ['leaky_re_lu_9[0][0]']
#
#  dropout_4 (Dropout)         (None, 64, 64, 320)          0         ['conv2d_42[0][0]']
#
#  batch_normalization_22 (Ba  (None, 64, 64, 320)          1280      ['dropout_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 64, 320)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 320)          921920    ['leaky_re_lu_10[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 320)          205120    ['concatenate_4[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 64, 64, 320)          0         ['conv2d_43[0][0]',
#  OpLambda)                                                           'conv2d_44[0][0]']
#
#  tf.math.reduce_mean_10 (TF  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_5 (TFOp  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_5 (TFOpLambda)    (None, 1, 1, 640)            0         ['tf.math.reduce_mean_10[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_5[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 1, 1, 20)             12820     ['tf.concat_5[0][0]']
#
#  tf.math.reduce_mean_11 (TF  (None, 64, 64, 1)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_46 (Conv2D)          (None, 1, 1, 320)            6720      ['conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 1)            2         ['tf.math.reduce_mean_11[0][0]
#                                                                     ']
#
#  multiply_10 (Multiply)      (None, 64, 64, 320)          0         ['conv2d_46[0][0]',
#                                                                      'conv2d_47[0][0]']
#
#  multiply_11 (Multiply)      (None, 64, 64, 320)          0         ['tf.__operators__.add_5[0][0]
#                                                                     ',
#                                                                      'multiply_10[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 96)         122976    ['multiply_11[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 128, 128, 192)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'encoder2[0][1]',
#                                                                      'encoder1[0][1]']
#
#  batch_normalization_23 (Ba  (None, 128, 128, 192)        768       ['concatenate_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128, 128, 192)        0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 128, 128, 96)         165984    ['leaky_re_lu_11[0][0]']
#
#  dropout_5 (Dropout)         (None, 128, 128, 96)         0         ['conv2d_48[0][0]']
#
#  batch_normalization_24 (Ba  (None, 128, 128, 96)         384       ['dropout_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 128, 128, 96)         0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 96)         83040     ['leaky_re_lu_12[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 128, 128, 96)         18528     ['concatenate_5[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 128, 128, 96)         0         ['conv2d_49[0][0]',
#  OpLambda)                                                           'conv2d_50[0][0]']
#
#  tf.math.reduce_mean_12 (TF  (None, 1, 1, 96)             0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_6 (TFOp  (None, 1, 1, 96)             0         ['tf.__operators__.add_6[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_6 (TFOpLambda)    (None, 1, 1, 192)            0         ['tf.math.reduce_mean_12[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_6[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 1, 1, 6)              1158      ['tf.concat_6[0][0]']
#
#  tf.math.reduce_mean_13 (TF  (None, 128, 128, 1)          0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_52 (Conv2D)          (None, 1, 1, 96)             672       ['conv2d_51[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 128, 128, 1)          2         ['tf.math.reduce_mean_13[0][0]
#                                                                     ']
#
#  multiply_12 (Multiply)      (None, 128, 128, 96)         0         ['conv2d_52[0][0]',
#                                                                      'conv2d_53[0][0]']
#
#  multiply_13 (Multiply)      (None, 128, 128, 96)         0         ['tf.__operators__.add_6[0][0]
#                                                                     ',
#                                                                      'multiply_12[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 19)         7315      ['multiply_13[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 256, 256, 38)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'encoder2[0][0]',
#                                                                      'encoder1[0][0]']
#
#  batch_normalization_25 (Ba  (None, 256, 256, 38)         152       ['concatenate_6[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 256, 256, 38)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 256, 256, 19)         6517      ['leaky_re_lu_13[0][0]']
#
#  dropout_6 (Dropout)         (None, 256, 256, 19)         0         ['conv2d_54[0][0]']
#
#  batch_normalization_26 (Ba  (None, 256, 256, 19)         76        ['dropout_6[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 256, 256, 19)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 256, 256, 19)         3268      ['leaky_re_lu_14[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 256, 256, 19)         741       ['concatenate_6[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 256, 256, 19)         0         ['conv2d_55[0][0]',
#  OpLambda)                                                           'conv2d_56[0][0]']
#
#  tf.math.reduce_max (TFOpLa  ()                           0         ['encoder2[0][0]']
#  mbda)
#
#  tf.math.reduce_max_1 (TFOp  ()                           0         ['encoder1[0][0]']
#  Lambda)
#
#  tf.math.reduce_max_2 (TFOp  ()                           0         ['encoder2[0][1]']
#  Lambda)
#
#  tf.math.reduce_max_3 (TFOp  ()                           0         ['encoder1[0][1]']
#  Lambda)
#
#  tf.math.reduce_max_4 (TFOp  ()                           0         ['encoder2[0][2]']
#  Lambda)
#
#  tf.math.reduce_max_5 (TFOp  ()                           0         ['encoder1[0][2]']
#  Lambda)
#
#  tf.math.reduce_max_6 (TFOp  ()                           0         ['encoder2[0][3]']
#  Lambda)
#
#  tf.math.reduce_max_7 (TFOp  ()                           0         ['encoder1[0][3]']
#  Lambda)
#
#  tf.math.reduce_mean_14 (TF  (None, 1, 1, 19)             0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_7 (TFOp  (None, 1, 1, 19)             0         ['tf.__operators__.add_7[0][0]
#  Lambda)                                                            ']
#
#  tf.math.truediv (TFOpLambd  (None, 256, 256, 3)          0         ['encoder2[0][0]',
#  a)                                                                  'tf.math.reduce_max[0][0]']
#
#  tf.math.truediv_1 (TFOpLam  (None, 256, 256, 16)         0         ['encoder1[0][0]',
#  bda)                                                                'tf.math.reduce_max_1[0][0]']
#
#  tf.math.truediv_2 (TFOpLam  (None, 128, 128, 64)         0         ['encoder2[0][1]',
#  bda)                                                                'tf.math.reduce_max_2[0][0]']
#
#  tf.math.truediv_3 (TFOpLam  (None, 128, 128, 32)         0         ['encoder1[0][1]',
#  bda)                                                                'tf.math.reduce_max_3[0][0]']
#
#  tf.math.truediv_4 (TFOpLam  (None, 64, 64, 256)          0         ['encoder2[0][2]',
#  bda)                                                                'tf.math.reduce_max_4[0][0]']
#
#  tf.math.truediv_5 (TFOpLam  (None, 64, 64, 64)           0         ['encoder1[0][2]',
#  bda)                                                                'tf.math.reduce_max_5[0][0]']
#
#  tf.math.truediv_6 (TFOpLam  (None, 32, 32, 512)          0         ['encoder2[0][3]',
#  bda)                                                                'tf.math.reduce_max_6[0][0]']
#
#  tf.math.truediv_7 (TFOpLam  (None, 32, 32, 128)          0         ['encoder1[0][3]',
#  bda)                                                                'tf.math.reduce_max_7[0][0]']
#
#  tf.concat_7 (TFOpLambda)    (None, 1, 1, 38)             0         ['tf.math.reduce_mean_14[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_7[0][0]']
#
#  tf.math.reduce_mean_16 (TF  ()                           0         ['tf.math.truediv[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_17 (TF  ()                           0         ['tf.math.truediv_1[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_18 (TF  ()                           0         ['tf.math.truediv_2[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_19 (TF  ()                           0         ['tf.math.truediv_3[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_20 (TF  ()                           0         ['tf.math.truediv_4[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_21 (TF  ()                           0         ['tf.math.truediv_5[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_22 (TF  ()                           0         ['tf.math.truediv_6[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_23 (TF  ()                           0         ['tf.math.truediv_7[0][0]']
#  OpLambda)
#
#  conv2d_57 (Conv2D)          (None, 1, 1, 1)              39        ['tf.concat_7[0][0]']
#
#  tf.math.reduce_mean_15 (TF  (None, 256, 256, 1)          0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.subtract (TFOpLamb  ()                           0         ['tf.math.reduce_mean_16[0][0]
#  da)                                                                ',
#                                                                      'tf.math.reduce_mean_17[0][0]
#                                                                     ']
#
#  tf.math.subtract_1 (TFOpLa  ()                           0         ['tf.math.reduce_mean_18[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.reduce_mean_19[0][0]
#                                                                     ']
#
#  tf.math.subtract_2 (TFOpLa  ()                           0         ['tf.math.reduce_mean_20[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.reduce_mean_21[0][0]
#                                                                     ']
#
#  tf.math.subtract_3 (TFOpLa  ()                           0         ['tf.math.reduce_mean_22[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.reduce_mean_23[0][0]
#                                                                     ']
#
#  conv2d_58 (Conv2D)          (None, 1, 1, 19)             38        ['conv2d_57[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 256, 256, 1)          2         ['tf.math.reduce_mean_15[0][0]
#                                                                     ']
#
#  tf.math.abs (TFOpLambda)    ()                           0         ['tf.math.subtract[0][0]']
#
#  tf.math.abs_1 (TFOpLambda)  ()                           0         ['tf.math.subtract_1[0][0]']
#
#  tf.math.abs_2 (TFOpLambda)  ()                           0         ['tf.math.subtract_2[0][0]']
#
#  tf.math.abs_3 (TFOpLambda)  ()                           0         ['tf.math.subtract_3[0][0]']
#
#  multiply_14 (Multiply)      (None, 256, 256, 19)         0         ['conv2d_58[0][0]',
#                                                                      'conv2d_59[0][0]']
#
#  tf.math.sigmoid (TFOpLambd  ()                           0         ['tf.math.abs[0][0]']
#  a)
#
#  tf.math.sigmoid_1 (TFOpLam  ()                           0         ['tf.math.abs_1[0][0]']
#  bda)
#
#  tf.math.sigmoid_2 (TFOpLam  ()                           0         ['tf.math.abs_2[0][0]']
#  bda)
#
#  tf.math.sigmoid_3 (TFOpLam  ()                           0         ['tf.math.abs_3[0][0]']
#  bda)
#
#  multiply_15 (Multiply)      (None, 256, 256, 19)         0         ['tf.__operators__.add_7[0][0]
#                                                                     ',
#                                                                      'multiply_14[0][0]']
#
#  tf.math.truediv_8 (TFOpLam  ()                           0         ['tf.math.sigmoid[0][0]']
#  bda)
#
#  tf.math.truediv_9 (TFOpLam  ()                           0         ['tf.math.sigmoid_1[0][0]']
#  bda)
#
#  tf.math.truediv_10 (TFOpLa  ()                           0         ['tf.math.sigmoid_2[0][0]']
#  mbda)
#
#  tf.math.truediv_11 (TFOpLa  ()                           0         ['tf.math.sigmoid_3[0][0]']
#  mbda)
#
#  output_1 (Conv2D)           (None, 256, 256, 3)          60        ['multiply_15[0][0]']
#
#  output_2 (Add)              ()                           0         ['tf.math.truediv_8[0][0]',
#                                                                      'tf.math.truediv_9[0][0]',
#                                                                      'tf.math.truediv_10[0][0]',
#                                                                      'tf.math.truediv_11[0][0]']
#
# ==================================================================================================
# Total params: 25705455 (98.06 MB)
# Trainable params: 25676925 (97.95 MB)
# Non-trainable params: 28530 (111.45 KB)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001), loss={'output_1':total_loss, 'output_2':lambda y_true, y_pred: y_pred},
              loss_weights = {'output_1':1, 'output_2':-0.05},
              metrics = {"output_1":[dice_coef_liver,dice_coef_tumor,iou_liver,iou_tumor,sensitivity_liver,sensitivity_tumor,specificity_liver,specificity_tumor]})

#callbacks
csv_logger = CSVLogger('/kaggle/working/training_log_WNet_Res50_AT_CL', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min', 
                              verbose=1, 
                              patience=9
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_Res50_AT_CL.h5", 
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=4, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, earlystopping, reduce_lr, csv_logger]

# %% [markdown]
# # Iterative Training Scheme
# # Two losses are used:
# * for segmentation: $Dice Loss + Focal Loss$
# * $Complementary~Loss$: to ensure that both models do not learn the same features

# %%
batch_size = 16
N = 256
train_generator = CustomDataGenerator(df_train, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(df_val, batch_size=batch_size, image_size=(N,N), shuffle=False)
num_epochs = 50
for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}/{num_epochs}")

    # Set the training status for encoder1 and encoder2
    if epoch % 2 == 0:
        model.get_layer('encoder1').trainable = True
        model.get_layer('encoder2').trainable = False
    else:
        model.get_layer('encoder1').trainable = False
        model.get_layer('encoder2').trainable = True

    # Train the model for one epoch
    history = model.fit(train_generator, steps_per_epoch=len(df_train) // batch_size,
                    validation_data=val_generator, validation_steps=len(df_val) // batch_size,
                    epochs=1,callbacks=callbacks)

# Save the final trained model
model.save('final_model.h5')
# Out:
# Epoch 1/50
# 2024-01-21 09:32:05.118070: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/encoder1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 836/836 [==============================] - ETA: 0s - loss: 0.7007 - output_1_loss: 0.7300 - output_2_loss: 0.5863 - output_1_dice_coef_liver: 0.8952 - output_1_dice_coef_tumor: 0.6192 - output_1_iou_liver: 0.8266 - output_1_iou_tumor: 0.4867 - output_1_sensitivity_liver: 0.9071 - output_1_sensitivity_tumor: 0.6075 - output_1_specificity_liver: 0.9941 - output_1_specificity_tumor: 0.9972
# Epoch 1: val_loss improved from inf to 0.74930, saving model to /kaggle/working/WNet_Res50_AT_CL.h5
# 836/836 [==============================] -
- val_output_1_specificity_tumor: 0.9996 - lr: 1.0000e-04
# Epoch 4/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6505 - output_1_loss: 0.6961 - output_2_loss: 0.9113 - output_1_dice_coef_liver: 0.9534 - output_1_dice_coef_tumor: 0.8291 - output_1_iou_liver: 0.9110 - output_1_iou_tumor: 0.7205 - output_1_sensitivity_liver: 0.9570 - output_1_sensitivity_tumor: 0.8176 - output_1_specificity_liver: 0.9971 - output_1_specificity_tumor: 0.9996
# Epoch 1: val_loss improved from 0.65679 to 0.65158, saving model to /kaggle/working/WNet_Res50_AT_CL.h5
# 836/836 [==============================] - 558s 667ms/step - loss: 0.6505 - output_1_loss: 0.6961 - output_2_loss: 0.9113 - output_1_dice_coef_liver: 0.9534 - output_1_dice_coef_tumor: 0.8291 - output_1_iou_liver: 0.9110 - output_1_iou_tumor: 0.7205 - output_1_sensitivity_liver: 0.9570 - output_1_sensitivity_tumor: 0.8176 - output_1_specificity_liver: 0.9971 - output_1_specificity_tumor: 0.9996 - val_loss: 0.6516 - val_output_1_loss: 0.6980 - val_output_2_loss: 0.9286 - val_output_1_dice_coef_liver: 0.9540 - val_output_1_dice_coef_tumor: 0.8110 - val_output_1_iou_liver: 0.9121 - val_output_1_iou_tumor: 0.7003 - val_output_1_sensitivity_liver: 0.9435 - val_output_1_sensitivity_tumor: 0.8105 - val_output_1_specificity_liver: 0.9982 - val_output_1_specificity_tumor: 0.9995 - lr: 1.0000e-04
# Epoch 5/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6460 - output_1_loss: 0.6946 - output_2_loss: 0.9718 - output_1_dice_coef_liver: 0.9566 - output_1_dice_coef_tumor: 0.8379 - output_1_iou_liver: 0.9169 - output_1_iou_tumor: 0.7326 - output_1_sensitivity_liver: 0.9602 - output_1_sensitivity_tumor: 0.8248 - output_1_specificity_liver: 0.9973 - output_1_specificity_tumor: 0.9996
# Epoch 1: val_loss improved from 0.65158 to 0.64850, saving model to /kaggle/working/WNet_Res50_AT_CL.h5
# 836/836 [==============================] - 559s 668ms/step - loss: 0.6460 - output_1_loss: 0.6946 - output_2_loss: 0.9718 - output_1_dice_coef_liver: 0.9566 - output_1_dice_coef_tumor: 0.8379 - output_1_iou_liver: 0.9169 - output_1_iou_tumor: 0.7326 - output_1_sensitivity_liver: 0.9602 - output_1_sensitivity_tumor: 0.8248 - output_1_specificity_liver: 0.9973 - output_1_specificity_tumor: 0.9996 - val_loss: 0.6485 - val_output_1_loss: 0.6985 - val_output_2_loss: 0.9993 - val_output_1_dice_coef_liver: 0.9506 - val_output_1_dice_coef_tumor: 0.8122 - val_output_1_iou_liver: 0.9060 - val_output_1_iou_tumor: 0.6988 - val_output_1_sensitivity_liver: 0.9345 - val_output_1_sensitivity_tumor: 0.8806 - val_output_1_specificity_liver: 0.9984 - val_output_1_specificity_tumor: 0.9992 - lr: 1.0000e-04
# Epoch 6/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6440 - output_1_loss: 0.6940 - output_2_loss: 0.9997 - output_1_dice_coef_liver: 0.9579 - output_1_dice_coef_tumor: 0.8415 - output_1_iou_liver: 0.9193 - output_1_iou_tumor: 0.7388 - output_1_sensitivity_liver: 0.9611 - output_1_sensitivity_tumor: 0.8337 - output_1_specificity_liver: 0.9974 - output_1_specificity_tumor: 0.9996
# Epoch 1: val_loss improved from 0.64850 to 0.64501, saving model to /kaggle/working/WNet_Res50_AT_CL.h5
# 836/836 [==============================] -
50
# 836/836 [==============================] - ETA: 0s - loss: 0.6377 - output_1_loss: 0.6877 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9675 - output_1_dice_coef_tumor: 0.8845 - output_1_iou_liver: 0.9371 - output_1_iou_tumor: 0.8008 - output_1_sensitivity_liver: 0.9705 - output_1_sensitivity_tumor: 0.8739 - output_1_specificity_liver: 0.9979 - output_1_specificity_tumor: 0.9997
# Epoch 1: val_loss did not improve from 0.63923
# 836/836 [==============================] - 558s 667ms/step - loss: 0.6377 - output_1_loss: 0.6877 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9675 - output_1_dice_coef_tumor: 0.8845 - output_1_iou_liver: 0.9371 - output_1_iou_tumor: 0.8008 - output_1_sensitivity_liver: 0.9705 - output_1_sensitivity_tumor: 0.8739 - output_1_specificity_liver: 0.9979 - output_1_specificity_tumor: 0.9997 - val_loss: 0.6410 - val_output_1_loss: 0.6910 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9639 - val_output_1_dice_coef_tumor: 0.8610 - val_output_1_iou_liver: 0.9304 - val_output_1_iou_tumor: 0.7695 - val_output_1_sensitivity_liver: 0.9775 - val_output_1_sensitivity_tumor: 0.8830 - val_output_1_specificity_liver: 0.9969 - val_output_1_specificity_tumor: 0.9995 - lr: 1.0000e-04
# Epoch 19/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6372 - output_1_loss: 0.6872 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9675 - output_1_dice_coef_tumor: 0.8889 - output_1_iou_liver: 0.9371 - output_1_iou_tumor: 0.8081 - output_1_sensitivity_liver: 0.9705 - output_1_sensitivity_tumor: 0.8808 - output_1_specificity_liver: 0.9979 - output_1_specificity_tumor: 0.9997
# Epoch 1: val_loss did not improve from 0.63923
# 836/836 [==============================] - 557s 666ms/step - loss: 0.6372 - output_1_loss: 0.6872 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9675 - output_1_dice_coef_tumor: 0.8889 - output_1_iou_liver: 0.9371 - output_1_iou_tumor: 0.8081 - output_1_sensitivity_liver: 0.9705 - output_1_sensitivity_tumor: 0.8808 - output_1_specificity_liver: 0.9979 - output_1_specificity_tumor: 0.9997 - val_loss: 0.6399 - val_output_1_loss: 0.6899 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9676 - val_output_1_dice_coef_tumor: 0.8652 - val_output_1_iou_liver: 0.9373 - val_output_1_iou_tumor: 0.7772 - val_output_1_sensitivity_liver: 0.9734 - val_output_1_sensitivity_tumor: 0.8252 - val_output_1_specificity_liver: 0.9977 - val_output_1_specificity_tumor: 0.9998 - lr: 1.0000e-04
# Epoch 20/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6376 - output_1_loss: 0.6876 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9683 - output_1_dice_coef_tumor: 0.8843 - output_1_iou_liver: 0.9385 - output_1_iou_tumor: 0.8044 - output_1_sensitivity_liver: 0.9712 - output_1_sensitivity_tumor: 0.8767 - output_1_specificity_liver: 0.9980 - output_1_specificity_tumor: 0.9997
# Epoch 1: val_loss did not improve from 0.63923
# 836/836 [==============================] - 557s 666ms/step - loss: 0.6376 - output_1_loss: 0.6876 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9683 - output_1_dice_coef_tumor: 0.8843 - output_1_iou_liver: 0.9385 - output_1_iou_tumor: 0.8044 - output_1_sensitivity_liver: 0.9712 - output_1_sensitivity_tumor: 0.8767 - output_1_specificity_liver: 0.9980 - output_1_specificity_tumor: 0.9997 - val_loss: 0.6401 - val_output_1_loss: 0.6901 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9661 - val_output_1_dice_coef_tumor: 0.8654 - val_output_1_iou_liver: 0.9345 - val_output_1_iou_tumor: 0.7764 - val_output_1_sensitivity_liver: 0.9690 - val_output_1_sensitivity_tumor: 0.8757 - val_output_1_specificity_liver: 0.9978 - val_output_1_specificity_tumor: 0.9996 - lr: 1.0000e-04
# Epoch 21/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6375 - output_1_loss: 0.6875 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.
- val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-04
# Epoch 38/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6334 - output_1_loss: 0.6834 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9724 - output_1_dice_coef_tumor: 0.9157 - output_1_iou_liver: 0.9463 - output_1_iou_tumor: 0.8492 - output_1_sensitivity_liver: 0.9753 - output_1_sensitivity_tumor: 0.9126 - output_1_specificity_liver: 0.9982 - output_1_specificity_tumor: 0.9998
# Epoch 1: val_loss did not improve from 0.63472
# ...
# Epoch 39/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6329 - output_1_loss: 0.6829 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9728 - output_1_dice_coef_tumor: 0.9201 - output_1_iou_liver: 0.9471 - output_1_iou_tumor: 0.8550 - output_1_sensitivity_liver: 0.9758 - output_1_sensitivity_tumor: 0.9165 - output_1_specificity_liver: 0.9982 - output_1_specificity_tumor: 0.9998
# Epoch 1: val_loss improved from 0.63472 to 0.63451, saving model to /kaggle/working/WNet_Res50_AT_CL.h5
# 836/836 [==============================] - 556s 664ms/step - loss: 0.6329 - output_1_loss: 0.6829 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9728 - output_1_dice_coef_tumor: 0.9201 - output_1_iou_liver: 0.9471 - output_1_iou_tumor: 0.8550 - output_1_sensitivity_liver: 0.9758 - output_1_sensitivity_tumor: 0.9165 - output_1_specificity_liver: 0.9982 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6345 - val_output_1_loss: 0.6845 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9722 - val_output_1_dice_coef_tumor: 0.9070 - val_output_1_iou_liver: 0.9460 - val_output_1_iou_tumor: 0.8349 - val_output_1_sensitivity_liver: 0.9765 - val_output_1_sensitivity_tumor: 0.9279 - val_output_1_specificity_liver: 0.9980 - val_output_1_specificity_tumor: 0.9996 - lr: 1.0000e-04
# Epoch 40/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6331 - output_1_loss: 0.6831 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9728 - output_1_dice_coef_tumor: 0.9183 - output_1_iou_liver: 0.9470 - output_1_iou_tumor: 0.8538 - output_1_sensitivity_liver: 0.9757 - output_1_sensitivity_tumor: 0.9152 - output_1_specificity_liver: 0.9982 - output_1_specificity_tumor: 0.9998
# Epoch 1: val_loss did not improve from 0.63451
# 836/836 [==============================] - 555s 664ms/step - loss: 0.6331 - output_1_loss: 0.6831 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9728 - output_1_dice_coef_tumor: 0.9183 - output_1_iou_liver: 0.9470 - output_1_iou_tumor: 0.8538 - output_1_sensitivity_liver: 0.9757 - output_1_sensitivity_tumor: 0.9152 - output_1_specificity_liver: 0.9982 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6352 - val_output_1_loss: 0.6852 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9707 - val_output_1_dice_coef_tumor: 0.9032 - val_output_1_iou_liver: 0.9431 - val_output_1_iou_tumor: 0.8295 - val_output_1_sensitivity_liver: 0.9668 - val_output_1_sensitivity_tumor: 0.9106 - val_output_1_specificity_liver: 0.9985 - val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-04
# Epoch 41/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6329 - output_1_loss: 0.6829 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9732 - output_1_dice_coef_tumor: 0.9188 - output_1_iou_liver: 0.9478 - output_1_iou_tumor: 0.8551 - output_1_sensitivity_liver: 0.9761 - output_1_sensitivity_tumor: 0.9168 - output_1_specificity_liver: 0.9982 - output_1_specificity_tumor: 0.9998
# Epoch 1: val_loss did not improve from 0.63451
# 836/836 [==============================] - 556s 664ms/step - loss: 0.6329 - output_1_loss: 0.6829 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9732 - output_1_dice_coef_tumor: 0.9188 - output_1_iou_liver: 0.9478 - output_1_iou_tumor: 0.8551 - output_1_sensitivity_liver: 0.9761 - output_1_sensitivity_tumor: 0.9168 - output_1_specificity_liver: 0.9982 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6370 - val_output_1_loss: 0.6870 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9691 - val_output_1_dice_coef_tumor: 0.8888 - val_output_1_iou_liver: 0.9400 - val_output_1_iou_tumor: 0.8079 - val_output_1_sensitivity_liver: 0.9772 - val_output_1_sensitivity_tumor: 0.8925 - val_output_1_specificity_liver: 0.9975 - val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-04
# Epoch 42/50
# 836/836 [==============================] - ETA: 0s - loss: 0.
- output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9738 - output_1_dice_coef_tumor: 0.9218 - output_1_iou_liver: 0.9489 - output_1_iou_tumor: 0.8603 - output_1_sensitivity_liver: 0.9766 - output_1_sensitivity_tumor: 0.9193 - output_1_specificity_liver: 0.9983 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6343 - val_output_1_loss: 0.6843 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9727 - val_output_1_dice_coef_tumor: 0.9076 - val_output_1_iou_liver: 0.9469 - val_output_1_iou_tumor: 0.8370 - val_output_1_sensitivity_liver: 0.9724 - val_output_1_sensitivity_tumor: 0.8964 - val_output_1_specificity_liver: 0.9984 - val_output_1_specificity_tumor: 0.9998 - lr: 1.0000e-04
# Epoch 46/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6329 - output_1_loss: 0.6829 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9730 - output_1_dice_coef_tumor: 0.9199 - output_1_iou_liver: 0.9475 - output_1_iou_tumor: 0.8556 - output_1_sensitivity_liver: 0.9759 - output_1_sensitivity_tumor: 0.9164 - output_1_specificity_liver: 0.9982 - output_1_specificity_tumor: 0.9998
# Epoch 1: val_loss did not improve from 0.63413
# 836/836 [==============================] - 553s 661ms/step - loss: 0.6329 - output_1_loss: 0.6829 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9730 - output_1_dice_coef_tumor: 0.9199 - output_1_iou_liver: 0.9475 - output_1_iou_tumor: 0.8556 - output_1_sensitivity_liver: 0.9759 - output_1_sensitivity_tumor: 0.9164 - output_1_specificity_liver: 0.9982 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6345 - val_output_1_loss: 0.6845 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9728 - val_output_1_dice_coef_tumor: 0.9061 - val_output_1_iou_liver: 0.9470 - val_output_1_iou_tumor: 0.8341 - val_output_1_sensitivity_liver: 0.9781 - val_output_1_sensitivity_tumor: 0.9248 - val_output_1_specificity_liver: 0.9980 - val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-04
# Epoch 47/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6320 - output_1_loss: 0.6820 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9740 - output_1_dice_coef_tumor: 0.9260 - output_1_iou_liver: 0.9494 - output_1_iou_tumor: 0.8645 - output_1_sensitivity_liver: 0.9769 - output_1_sensitivity_tumor: 0.9223 - output_1_specificity_liver: 0.9983 - output_1_specificity_tumor: 0.9998
# Epoch 1: val_loss did not improve from 0.63413
# 836/836 [==============================] - 553s 661ms/step - loss: 0.6320 - output_1_loss: 0.6820 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9740 - output_1_dice_coef_tumor: 0.9260 - output_1_iou_liver: 0.9494 - output_1_iou_tumor: 0.8645 - output_1_sensitivity_liver: 0.9769 - output_1_sensitivity_tumor: 0.9223 - output_1_specificity_liver: 0.9983 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6348 - val_output_1_loss: 0.6848 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9713 - val_output_1_dice_coef_tumor: 0.9050 - val_output_1_iou_liver: 0.9443 - val_output_1_iou_tumor: 0.8329 - val_output_1_sensitivity_liver: 0.9733 - val_output_1_sensitivity_tumor: 0.9101 - val_output_1_specificity_liver: 0.9982 - val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-04
# Epoch 48/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6320 - output_1_loss: 0.6820 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9739 - output_1_dice_coef_tumor: 0.9264 - output_1_iou_liver: 0.9491 - output_1_iou_tumor: 0.8660 - output_1_sensitivity_liver: 0.9768 - output_1_sensitivity_tumor: 0.9235 - output_1_specificity_liver: 0.9983 - output_1_specificity_tumor: 0.9998
# Epoch 1: val_loss improved from 0.63413 to 0.63349, saving model to /kaggle/working/WNet_Res50_AT_CL.h5
# 836/836 [==============================] - 554s 663ms/step - loss: 0.6320 - output_1_loss: 0.6820 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9739 - output_1_dice_coef_tumor: 0.9264 - output_1_iou_liver: 0.9491 - output_1_iou_tumor: 0.8660 - output_1_sensitivity_liver: 0.9768 - output_1_sensitivity_tumor: 0.9235 - output_1_specificity_liver: 0.9983 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6335 - val_output_1_loss: 0.6835 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9738 - val_output_1_dice_coef_tumor: 0.9135 - val_output_1_iou_liver: 0.9490 - val_output_1_iou_tumor: 0.8454 - val_output_1_sensitivity_liver: 0.9773 - val_output_1_sensitivity_tumor: 0.9145 - val_output_1_specificity_liver: 0.9982 - val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-04
# Epoch 49/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6320 - output_1_loss: 0.6820 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9741 - output_1_dice_coef_tumor: 0.9257 - output_1_iou_liver: 0.9496 - output_1_iou_tumor: 0.8651 - output_1_sensitivity_liver: 0.9769 - output_1_sensitivity_tumor: 0.9230 - output_1_specificity_liver: 0.9983 - output_1_specificity_tumor: 0.9998
# Epoch 1: val_loss did not improve from 0.63349
# 836/836 [==============================] - 554s 663ms/step - loss: 0.6320 - output_1_loss: 0.6820 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9741 - output_1_dice_coef_tumor: 0.9257 - output_1_iou_liver: 0.9496 - output_1_iou_tumor: 0.8651 - output_1_sensitivity_liver: 0.9769 - output_1_sensitivity_tumor: 0.9230 - output_1_specificity_liver: 0.9983 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6361 - val_output_1_loss: 0.6861 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9679 - val_output_1_dice_coef_tumor: 0.8979 - val_output_1_iou_liver: 0.9378 - val_output_1_iou_tumor: 0.8209 - val_output_1_sensitivity_liver: 0.9791 - val_output_1_sensitivity_tumor: 0.8886 - val_output_1_specificity_liver: 0.9973 - val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-04
# Epoch 50/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6321 - output_1_loss: 0.6821 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9740 - output_1_dice_coef_tumor: 0.9249 - output_1_iou_liver: 0.9494 - output_1_iou_tumor: 0.8641 - output_1_sensitivity_liver: 0.9770 - output_1_sensitivity_tumor: 0.9218 - output_1_specificity_liver: 0.9983 - output_1_specificity_tumor: 0.9998
# Epoch 1: val_loss did not improve from 0.63349
# 836/836 [==============================] - 553s 661ms/step - loss: 0.6321 - output_1_loss: 0.6821 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9740 - output_1_dice_coef_tumor: 0.9249 - output_1_iou_liver: 0.9494 - output_1_iou_tumor: 0.8641 - output_1_sensitivity_liver: 0.9770 - output_1_sensitivity_tumor: 0.9218 - output_1_specificity_liver: 0.9983 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6340 - val_output_1_loss: 0.6840 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9732 - val_output_1_dice_coef_tumor: 0.9101 - val_output_1_iou_liver: 0.9478 - val_output_1_iou_tumor: 0.8412 - val_output_1_sensitivity_liver: 0.9766 - val_output_1_sensitivity_tumor: 0.9088 - val_output_1_specificity_liver: 0.9981 - val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-04
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'output_1_loss', 'output_2_loss', 'output_1_dice_coef_liver', 'output_1_dice_coef_tumor', 'output_1_iou_liver', 'output_1_iou_tumor', 'output_1_sensitivity_liver', 'output_1_sensitivity_tumor', 'output_1_specificity_liver', 'output_1_specificity_tumor', 'val_loss', 'val_output_1_loss', 'val_output_2_loss', 'val_output_1_dice_coef_liver', 'val_output_1_dice_coef_tumor', 'val_output_1_iou_liver', 'val_output_1_iou_tumor', 'val_output_1_sensitivity_liver', 'val_output_1_sensitivity_tumor', 'val_output_1_specificity_liver', 'val_output_1_specificity_tumor', 'lr'])

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WNet_Res50_AT_CL', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score_tumor=history['output_1_iou_tumor']
val_iou_score_tumor=history['val_output_1_iou_tumor']

iou_score_liver=history['output_1_iou_liver']
val_iou_score_liver=history['val_output_1_iou_liver']

loss=history['output_1_loss']
val_loss=history['val_output_1_loss']

train_dice_tumor=history['output_1_dice_coef_tumor']
val_dice_tumor=history['val_output_1_dice_coef_tumor']

train_dice_liver=history['output_1_dice_coef_liver']
val_dice_liver=history['val_output_1_dice_coef_liver']

train_cl = history['output_2_loss']
train_cl = train_cl-np.min(train_cl)
val_cl = history['val_output_2_loss']
val_cl = val_cl-np.min(val_cl)

epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 4, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score_liver, 'b', label='Training IOU liver', linewidth=1.5)
axes[1].plot(epoch, val_iou_score_liver, 'b--', label='Val IOU Liver', linewidth=1.5)
axes[1].plot(epoch, iou_score_tumor, 'r', label='Training IOU tumor', linewidth=1.5)
axes[1].plot(epoch, val_iou_score_tumor, 'r--', label='Val IOU tumor', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice_liver, 'b', label='Training DC liver', linewidth=1.5)
axes[2].plot(epoch, val_dice_liver, 'b--', label='Val DC tumor', linewidth=1.5)
axes[2].plot(epoch, train_dice_liver, 'r', label='Training DC liver', linewidth=1.5)
axes[2].plot(epoch, val_dice_liver, 'r--', label='Val DC tumor', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()

# Plot 3: Dice Coefficients
axes[3].plot(epoch, train_cl, 'b', label='Training Comp_loss', linewidth=1.5)
axes[3].plot(epoch, val_cl, 'r', label='Validation Comp_loss', linewidth=1.5)
axes[3].set_xlabel('Epochs')
axes[3].set_ylabel('Complementary loss')
axes[3].set_title('Training and Validation Complementary Loss')
axes[3].legend()

# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Fine-tuning Joint updation

# %% [markdown]
# Im going for this method instead...more efficient

# %%
model = build_WNet((256,256,3))

# %%
model.load_weights("/kaggle/working/WNet_Res50_AT_CL.h5")
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.00001), loss={'output_1':total_loss, 'output_2':lambda y_true, y_pred: y_pred},
              loss_weights = {'output_1':1, 'output_2':-0.05},
              metrics = {"output_1":[dice_coef_liver,dice_coef_tumor,iou_liver,iou_tumor,sensitivity_liver,sensitivity_tumor,specificity_liver,specificity_tumor]})

# %%
model.get_layer("encoder1").trainable = True
model.get_layer("encoder2").trainable = True

# %%
csv_logger = CSVLogger('/kaggle/working/training_log_WNet_Res50_AT_CL', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min', 
                              verbose=1, 
                              patience=3
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_Res50_AT_CL_fine_tuned.h5", 
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_output_1_loss', factor=0.3, patience=3, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, reduce_lr, csv_logger]

# %%
batch_size = 16
N = 256
train_generator = CustomDataGenerator(df_train, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(df_val, batch_size=batch_size, image_size=(N,N), shuffle=False)
history_ = model.fit(train_generator, steps_per_epoch=len(df_train) // batch_size,
                    validation_data=val_generator, validation_steps=len(df_val) // batch_size,
                    epochs=10,callbacks=callbacks)
# Out:
# Epoch 1/10
# 2024-01-21 17:19:17.828231: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/encoder1/dropout_7/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 836/836 [==============================] - ETA: 0s - loss: 0.6312 - output_1_loss: 0.6812 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9753 - output_1_dice_coef_tumor: 0.9313 - output_1_iou_liver: 0.9519 - output_1_iou_tumor: 0.8742 - output_1_sensitivity_liver: 0.9782 - output_1_sensitivity_tumor: 0.9286 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998
# Epoch 1: val_loss improved from inf to 0.63331, saving model to /kaggle/working/WNet_Res50_AT_CL_fine_tuned.h5
# 836/836 [==============================] - 608s 664ms/step - loss: 0.6312 - output_1_loss: 0.6812 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9753 - output_1_dice_coef_tumor: 0.9313 - output_1_iou_liver: 0.9519 - output_1_iou_tumor: 0.8742 - output_1_sensitivity_liver: 0.9782 - output_1_sensitivity_tumor: 0.9286 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6333 - val_output_1_loss: 0.6833 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9745 - val_output_1_dice_coef_tumor: 0.9143 - val_output_1_iou_liver: 0.9502 - val_output_1_iou_tumor: 0.8475 - val_output_1_sensitivity_liver: 0.9786 - val_output_1_sensitivity_tumor: 0.9174 - val_output_1_specificity_liver: 0.9982 - val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-05
# Epoch 2/10
# 836/836 [==============================] - ETA: 0s - loss: 0.6306 - output_1_loss: 0.6806 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9757 - output_1_dice_coef_tumor: 0.9365 - output_1_iou_liver: 0.9525 - output_1_iou_tumor: 0.8821 - output_1_sensitivity_liver: 0.9785 - output_1_sensitivity_tumor: 0.9338 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998
# Epoch 2: val_loss improved from 0.63331 to 0.63302, saving model to /kaggle/working/WNet_Res50_AT_CL_fine_tuned.h5
# 836/836 [==============================] - 554s 662ms/step - loss: 0.6306 - output_1_loss: 0.6806 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9757 - output_1_dice_coef_tumor: 0.9365 - output_1_iou_liver: 0.9525 - output_1_iou_tumor: 0.8821 - output_1_sensitivity_liver: 0.9785 - output_1_sensitivity_tumor: 0.9338 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6330 - val_output_1_loss: 0.6830 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9747 - val_output_1_dice_coef_tumor: 0.9168 - val_output_1_iou_liver: 0.9508 - val_output_1_iou_tumor: 0.8514 - val_output_1_sensitivity_liver: 0.9778 - val_output_1_sensitivity_tumor: 0.9198 - val_output_1_specificity_liver: 0.9983 - val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-05
# Epoch 3/10
# 836/836 [==============================] - ETA: 0s - loss: 0.6307 - output_1_loss: 0.6807 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9758 - output_1_dice_coef_tumor: 0.9356 - output_1_iou_liver: 0.9528 - output_1_iou_tumor: 0.8817 - output_1_sensitivity_liver: 0.9785 - output_1_sensitivity_tumor: 0.9322 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998
# Epoch 3: val_loss did not improve from 0.63302
# 836/836 [==============================] - 555s 663ms/step - loss: 0.6307 - output_1_loss: 0.6807 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9758 - output_1_dice_coef_tumor: 0.9356 - output_1_iou_liver: 0.9528 - output_1_iou_tumor: 0.8817 - output_1_sensitivity_liver: 0.9785 - output_1_sensitivity_tumor: 0.9322 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6332 - val_output_1_loss: 0.6832 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9747 - val_output_1_dice_coef_tumor: 0.9155 - val_output_1_iou_liver: 0.9507 - val_output_1_iou_tumor: 0.8497 - val_output_1_sensitivity_liver: 0.9794 - val_output_1_sensitivity_tumor: 0.9196 - val_output_1_specificity_liver: 0.9981 - val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-05
# Epoch 4/10
# 836/836 [==============================] - ETA: 0s - loss: 0.6304 - output_1_loss: 0.6804 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9760 - output_1_dice_coef_tumor: 0.9377 - output_1_iou_liver: 0.9532 - output_1_iou_tumor: 0.8845 - output_1_sensitivity_liver: 0.9787 - output_1_sensitivity_tumor: 0.9342 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998
# Epoch 4: val_loss did not improve from 0.63302
# 836/836 [==============================] - 554s 663ms/step - loss: 0.6304 - output_1_loss: 0.6804 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9760 - output_1_dice_coef_tumor: 0.9377 - output_1_iou_liver: 0.9532 - output_1_iou_tumor: 0.8845 - output_1_sensitivity_liver: 0.9787 - output_1_sensitivity_tumor: 0.9342 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6330 - val_output_1_loss: 0.6830 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9748 - val_output_1_dice_coef_tumor: 0.9167 - val_output_1_iou_liver: 0.9508 - val_output_1_iou_tumor: 0.8516 - val_output_1_sensitivity_liver: 0.9795 - val_output_1_sensitivity_tumor: 0.9211 - val_output_1_specificity_liver: 0.9981 - val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-05
# Epoch 5/10
# 836/836 [==============================] - ETA: 0s - loss: 0.6304 - output_1_loss: 0.6804 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9761 - output_1_dice_coef_tumor: 0.9378 - output_1_iou_liver: 0.9534 - output_1_iou_tumor: 0.8844 - output_1_sensitivity_liver: 0.9790 - output_1_sensitivity_tumor: 0.9347 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998
# Epoch 5: val_loss improved from 0.63302 to 0.63286, saving model to /kaggle/working/WNet_Res50_AT_CL_fine_tuned.h5
# 836/836 [==============================] - 554s 662ms/step - loss: 0.6304 - output_1_loss: 0.6804 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9761 - output_1_dice_coef_tumor: 0.9378 - output_1_iou_liver: 0.9534 - output_1_iou_tumor: 0.8844 - output_1_sensitivity_liver: 0.9790 - output_1_sensitivity_tumor: 0.9347 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6329 - val_output_1_loss: 0.6829 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9750 - val_output_1_dice_coef_tumor: 0.9178 - val_output_1_iou_liver: 0.9513 - val_output_1_iou_tumor: 0.8534 - val_output_1_sensitivity_liver: 0.9797 - val_output_1_sensitivity_tumor: 0.9133 - val_output_1_specificity_liver: 0.9982 - val_output_1_specificity_tumor: 0.9998 - lr: 1.0000e-05
# Epoch 6/10
# 836/836 [==============================] - ETA: 0s - loss: 0.6304 - output_1_loss: 0.6804 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9763 - output_1_dice_coef_tumor: 0.9379 - output_1_iou_liver: 0.9537 - output_1_iou_tumor: 0.8857 - output_1_sensitivity_liver: 0.9790 - output_1_sensitivity_tumor: 0.9349 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998
# Epoch 6: val_loss improved from 0.63286 to 0.63281, saving model to /kaggle/working/WNet_Res50_AT_CL_fine_tuned.h5
# 836/836 [==============================] - 555s 664ms/step - loss: 0.6304 - output_1_loss: 0.6804 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9763 - output_1_dice_coef_tumor: 0.9379 - output_1_iou_liver: 0.9537 - output_1_iou_tumor: 0.8857 - output_1_sensitivity_liver: 0.9790 - output_1_sensitivity_tumor: 0.9349 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6328 - val_output_1_loss: 0.6828 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9752 - val_output_1_dice_coef_tumor: 0.9180 - val_output_1_iou_liver: 0.9515 - val_output_1_iou_tumor: 0.8541 - val_output_1_sensitivity_liver: 0.9773 - val_output_1_sensitivity_tumor: 0.9242 - val_output_1_specificity_liver: 0.9984 - val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-05
# Epoch 7/10
# 836/836 [==============================] - ETA: 0s - loss: 0.6306 - output_1_loss: 0.6806 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9764 - output_1_dice_coef_tumor: 0.9358 - output_1_iou_liver: 0.9538 - output_1_iou_tumor: 0.8845 - output_1_sensitivity_liver: 0.9790 - output_1_sensitivity_tumor: 0.9326 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998
# Epoch 7: val_loss improved from 0.63281 to 0.63267, saving model to /kaggle/working/WNet_Res50_AT_CL_fine_tuned.h5
# 836/836 [==============================] - 556s 664ms/step - loss: 0.6306 - output_1_loss: 0.6806 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9764 - output_1_dice_coef_tumor: 0.9358 - output_1_iou_liver: 0.9538 - output_1_iou_tumor: 0.8845 - output_1_sensitivity_liver: 0.9790 - output_1_sensitivity_tumor: 0.9326 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6327 - val_output_1_loss: 0.6827 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9752 - val_output_1_dice_coef_tumor: 0.9192 - val_output_1_iou_liver: 0.9517 - val_output_1_iou_tumor: 0.8549 - val_output_1_sensitivity_liver: 0.9787 - val_output_1_sensitivity_tumor: 0.9213 - val_output_1_specificity_liver: 0.9983 - val_output_1_specificity_tumor: 0.9998 - lr: 1.0000e-05
# Epoch 8/10
# 836/836 [==============================] - ETA: 0s - loss: 0.6303 - output_1_loss: 0.6803 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9764 - output_1_dice_coef_tumor: 0.9379 - output_1_iou_liver: 0.9540 - output_1_iou_tumor: 0.8866 - output_1_sensitivity_liver: 0.9792 - output_1_sensitivity_tumor: 0.9345 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998
# Epoch 8: val_loss did not improve from 0.63267
# 836/836 [==============================] - 554s 662ms/step - loss: 0.6303 - output_1_loss: 0.6803 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9764 - output_1_dice_coef_tumor: 0.9379 - output_1_iou_liver: 0.9540 - output_1_iou_tumor: 0.8866 - output_1_sensitivity_liver: 0.9792 - output_1_sensitivity_tumor: 0.9345 - output_1_specificity_liver: 0.9984 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6328 - val_output_1_loss: 0.6828 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9752 - val_output_1_dice_coef_tumor: 0.9184 - val_output_1_iou_liver: 0.9516 - val_output_1_iou_tumor: 0.8546 - val_output_1_sensitivity_liver: 0.9787 - val_output_1_sensitivity_tumor: 0.9218 - val_output_1_specificity_liver: 0.9983 - val_output_1_specificity_tumor: 0.9997 - lr: 1.0000e-05
# Epoch 9/10
# 836/836 [==============================] - ETA: 0s - loss: 0.6304 - output_1_loss: 0.6804 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9766 - output_1_dice_coef_tumor: 0.9368 - output_1_iou_liver: 0.9543 - output_1_iou_tumor: 0.8857 - output_1_sensitivity_liver: 0.9793 - output_1_sensitivity_tumor: 0.9326 - output_1_specificity_liver: 0.9985 - output_1_specificity_tumor: 0.9998
# Epoch 9: val_loss did not improve from 0.63267
# 836/836 [==============================] - 553s 661ms/step - loss: 0.6304 - output_1_loss: 0.6804 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9766 - output_1_dice_coef_tumor: 0.9368 - output_1_iou_liver: 0.9543 - output_1_iou_tumor: 0.8857 - output_1_sensitivity_liver: 0.9793 - output_1_sensitivity_tumor: 0.9326 - output_1_specificity_liver: 0.9985 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6327 - val_output_1_loss: 0.6827 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9753 - val_output_1_dice_coef_tumor: 0.9191 - val_output_1_iou_liver: 0.9517 - val_output_1_iou_tumor: 0.8550 - val_output_1_sensitivity_liver: 0.9791 - val_output_1_sensitivity_tumor: 0.9203 - val_output_1_specificity_liver: 0.9982 - val_output_1_specificity_tumor: 0.9998 - lr: 1.0000e-05
# Epoch 10/10
# 836/836 [==============================] - ETA: 0s - loss: 0.6300 - output_1_loss: 0.6800 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9766 - output_1_dice_coef_tumor: 0.9404 - output_1_iou_liver: 0.9544 - output_1_iou_tumor: 0.8894 - output_1_sensitivity_liver: 0.9794 - output_1_sensitivity_tumor: 0.9368 - output_1_specificity_liver: 0.9985 - output_1_specificity_tumor: 0.9998
# Epoch 10: val_loss improved from 0.63267 to 0.63250, saving model to /kaggle/working/WNet_Res50_AT_CL_fine_tuned.h5
# 836/836 [==============================] - 554s 663ms/step - loss: 0.6300 - output_1_loss: 0.6800 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9766 - output_1_dice_coef_tumor: 0.9404 - output_1_iou_liver: 0.9544 - output_1_iou_tumor: 0.8894 - output_1_sensitivity_liver: 0.9794 - output_1_sensitivity_tumor: 0.9368 - output_1_specificity_liver: 0.9985 - output_1_specificity_tumor: 0.9998 - val_loss: 0.6325 - val_output_1_loss: 0.6825 - val_output_2_loss: 1.0000 - val_output_1_dice_coef_liver: 0.9754 - val_output_1_dice_coef_tumor: 0.9206 - val_output_1_iou_liver: 0.9520 - val_output_1_iou_tumor: 0.8577 - val_output_1_sensitivity_liver: 0.9781 - val_output_1_sensitivity_tumor: 0.9217 - val_output_1_specificity_liver: 0.9983 - val_output_1_specificity_tumor: 0.9998 - lr: 1.0000e-05

# %%
# Save the final trained model
model.save('final_model_WNet_Res50_AT_CL_fine_tuned.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WNet_Res50_AT_CL', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score_tumor=history['output_1_iou_tumor']
val_iou_score_tumor=history['val_output_1_iou_tumor']

iou_score_liver=history['output_1_iou_liver']
val_iou_score_liver=history['val_output_1_iou_liver']

loss=history['output_1_loss']
val_loss=history['val_output_1_loss']

train_dice_tumor=history['output_1_dice_coef_tumor']
val_dice_tumor=history['val_output_1_dice_coef_tumor']

train_dice_liver=history['output_1_dice_coef_liver']
val_dice_liver=history['val_output_1_dice_coef_liver']

train_cl = history['output_2_loss']
train_cl = train_cl-np.min(train_cl)
val_cl = history['val_output_2_loss']
val_cl = val_cl-np.min(val_cl)

epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 4, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score_liver, 'b', label='Training IOU liver', linewidth=1.5)
axes[1].plot(epoch, val_iou_score_liver, 'b--', label='Val IOU Liver', linewidth=1.5)
axes[1].plot(epoch, iou_score_tumor, 'r', label='Training IOU tumor', linewidth=1.5)
axes[1].plot(epoch, val_iou_score_tumor, 'r--', label='Val IOU tumor', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice_liver, 'b', label='Training DC liver', linewidth=1.5)
axes[2].plot(epoch, val_dice_liver, 'b--', label='Val DC tumor', linewidth=1.5)
axes[2].plot(epoch, train_dice_liver, 'r', label='Training DC liver', linewidth=1.5)
axes[2].plot(epoch, val_dice_liver, 'r--', label='Val DC tumor', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()

# Plot 3: Dice Coefficients
axes[3].plot(epoch, train_cl, 'b', label='Training Comp_loss', linewidth=1.5)
axes[3].plot(epoch, val_cl, 'r', label='Validation Comp_loss', linewidth=1.5)
axes[3].set_xlabel('Epochs')
axes[3].set_ylabel('Complementary loss')
axes[3].set_title('Training and Validation Complementary Loss')
axes[3].legend()

# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Testing Model

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                #mask = mask.astype(np.int32)
    

            """augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])"""
            images.append(image)
            masks.append(mask)
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        #masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        masks = np.array(tf.one_hot(masks, 3, dtype = tf.float32))
        return  images, masks

# Example usage of the CustomDataGenerator
test_generator = CustomDataGenerator(df_test, batch_size=16, image_size=(256, 256), shuffle=True)

# %%
results = model.evaluate(test_generator)
# Out:
# 216/216 [==============================] - 111s 513ms/step - loss: 0.6326 - output_1_loss: 0.6826 - output_2_loss: 1.0000 - output_1_dice_coef_liver: 0.9750 - output_1_dice_coef_tumor: 0.9202 - output_1_iou_liver: 0.9512 - output_1_iou_tumor: 0.8582 - output_1_sensitivity_liver: 0.9772 - output_1_sensitivity_tumor: 0.9201 - output_1_specificity_liver: 0.9983 - output_1_specificity_tumor: 0.9998

# %%
#!zip -r weights_WNet_Res50_AT_CL.zip /kaggle/working/WNet_maxpool.h5

# %%
#from IPython.display import FileLink
#FileLink(r'weights_WNet_Res50_AT_CL.zip')
