# %%
import os
import pandas as pd
from tqdm import tqdm

def read_slice_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image slice files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)
        mask_path = mask_path.split(".")[0] + ".tiff"

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask slice folders
image_slice_folder = "/kaggle/input/lits-slices/kaggle/working/images"
mask_slice_folder = "/kaggle/input/lits-slices/kaggle/working/masks"

# Read slice paths and create a DataFrame
df_slices = read_slice_paths(image_slice_folder, mask_slice_folder)
# Out:
# 100%|██████████| 19131/19131 [00:51<00:00, 370.62it/s]

# %%
df_slices.head(5)
# Out:
#                                                Image  \
# 0  /kaggle/input/lits-slices/kaggle/working/image...
# 1  /kaggle/input/lits-slices/kaggle/working/image...
# 2  /kaggle/input/lits-slices/kaggle/working/image...
# 3  /kaggle/input/lits-slices/kaggle/working/image...
# 4  /kaggle/input/lits-slices/kaggle/working/image...
#
#                                                 Mask
# 0  /kaggle/input/lits-slices/kaggle/working/masks...
# 1  /kaggle/input/lits-slices/kaggle/working/masks...
# 2  /kaggle/input/lits-slices/kaggle/working/masks...
# 3  /kaggle/input/lits-slices/kaggle/working/masks...
# 4  /kaggle/input/lits-slices/kaggle/working/masks...

# %%
#df_slices = df_slices.iloc[:100]

# %%
#sanity check
print(df_slices["Image"][0])
print(df_slices["Mask"][0])
# Out:
# /kaggle/input/lits-slices/kaggle/working/images/volume-126_slice_228.jpg
# /kaggle/input/lits-slices/kaggle/working/masks/volume-126_slice_228.tiff

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                #mask = mask.astype(np.int32)
    

            augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        #masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        masks = np.array(tf.one_hot(masks, 3, dtype = tf.float32))
        return  images, masks

# Example usage of the CustomDataGenerator
train_generator = CustomDataGenerator(df_slices, batch_size=8, image_size=(256, 256), shuffle=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import matplotlib.pyplot as plt

# Load a single batch
batch = train_generator[0]  # Assuming you want to load the first batch

# Extract images and labels from the batch
images, masks = batch

# Display the images and masks
n_images_to_display = len(images)
fig, ax = plt.subplots(n_images_to_display, 2, figsize=(10, 20))

for i in range(n_images_to_display):
    ax[i, 0].imshow(images[i], cmap='bone')
    #print(np.max(images[i]))
    ax[i, 0].set_title('Image')
    ax[i, 1].imshow(masks[i], cmap='bone')
    #print(np.max(masks[i]))
    ax[i, 1].set_title('Mask')

    ax[i, 0].axis('off')
    ax[i, 1].axis('off')
plt.show()

# %%
import cv2
import pandas as pd

# Assuming df_slices is your DataFrame with "Image" and "Mask" columns
# Add the "Num_Classes" column with default value 0
df_slices["Num_Classes"] = 0

# Function to read the mask using cv2 and return the number of unique classes
def read_mask_and_count_classes(mask_path):
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    mask = mask.astype(np.int32)
    val, counts = np.unique(mask, return_counts=True)
    return len(counts)

# Apply the function to each row in the DataFrame
tqdm.pandas(desc="Processing Masks", unit="mask")
df_slices["Num_Classes"] = df_slices["Mask"].progress_apply(read_mask_and_count_classes)
# Out:
# Processing Masks: 100%|██████████| 19131/19131 [04:28<00:00, 71.18mask/s]

# %%
df_slices.head(5)
# Out:
#                                                Image  \
# 0  /kaggle/input/lits-slices/kaggle/working/image...
# 1  /kaggle/input/lits-slices/kaggle/working/image...
# 2  /kaggle/input/lits-slices/kaggle/working/image...
# 3  /kaggle/input/lits-slices/kaggle/working/image...
# 4  /kaggle/input/lits-slices/kaggle/working/image...
#
#                                                 Mask  Num_Classes
# 0  /kaggle/input/lits-slices/kaggle/working/masks...            3
# 1  /kaggle/input/lits-slices/kaggle/working/masks...            3
# 2  /kaggle/input/lits-slices/kaggle/working/masks...            2
# 3  /kaggle/input/lits-slices/kaggle/working/masks...            3
# 4  /kaggle/input/lits-slices/kaggle/working/masks...            2

# %%
from sklearn.model_selection import train_test_split

df_shuffled = df_slices.sample(frac=1, random_state=42)

df_train, df_temp = train_test_split(df_shuffled, test_size=0.30, stratify=df_shuffled["Num_Classes"], random_state=42)
df_val, df_test = train_test_split(df_temp, test_size=0.6, stratify=df_temp["Num_Classes"], random_state=42)

# %%
unique_values = df_slices['Num_Classes'].unique()
print("Unique values in 'Num_Classes' column:", unique_values)
value_counts = df_slices['Num_Classes'].value_counts(normalize=True)
print("\nRatio of each unique value in 'num_classes' column:",value_counts)
# Out:
# Unique values in 'Num_Classes' column: [3 2]
#
# Ratio of each unique value in 'num_classes' column: Num_Classes
# 2    0.624536
# 3    0.375464
# Name: proportion, dtype: float64

# %%
unique_values = df_train['Num_Classes'].unique()
print("Unique values in 'Num_Classes' column:", unique_values)
value_counts = df_train['Num_Classes'].value_counts(normalize=True)
print("\nRatio of each unique value in 'num_classes' column:",value_counts)
# Out:
# Unique values in 'Num_Classes' column: [2 3]
#
# Ratio of each unique value in 'num_classes' column: Num_Classes
# 2    0.624524
# 3    0.375476
# Name: proportion, dtype: float64

# %%
unique_values = df_val['Num_Classes'].unique()
print("Unique values in 'Num_Classes' column:", unique_values)
value_counts = df_val['Num_Classes'].value_counts(normalize=True)
print("\nRatio of each unique value in 'num_classes' column:",value_counts)
# Out:
# Unique values in 'Num_Classes' column: [2 3]
#
# Ratio of each unique value in 'num_classes' column: Num_Classes
# 2    0.624564
# 3    0.375436
# Name: proportion, dtype: float64

# %%
unique_values = df_test['Num_Classes'].unique()
print("Unique values in 'Num_Classes' column:", unique_values)
value_counts = df_test['Num_Classes'].value_counts(normalize=True)
print("\nRatio of each unique value in 'num_classes' column:",value_counts)
# Out:
# Unique values in 'Num_Classes' column: [3 2]
#
# Ratio of each unique value in 'num_classes' column: Num_Classes
# 2    0.624564
# 3    0.375436
# Name: proportion, dtype: float64

# %%
# bar plot
from matplotlib import pyplot as plt
sizes = [len(df_train), len(df_val), len(df_test)]
labels = ['Train', 'Validation', 'Test']

plt.bar(labels, sizes, color=['blue', 'orange', 'green'])
plt.xlabel('Data Split')
plt.ylabel('Number of Samples')
plt.title('Dataset Split: Train, Validation')
plt.show()

# %% [markdown]
# # Model Architecture and Helper blocks

# %%
#GCSE Block...from the GCSER UNET (Mukherjee et al.)
def GCSE(input_tensor, ratio=16):


    # Compute the global statistics (mean and std deviation) along the channel axis.
    mean = tf.reduce_mean(input_tensor, axis=[1, 2], keepdims=True)
    std = tf.math.reduce_std(input_tensor, axis=[1, 2], keepdims=True)

    # Compute channel-wise attention using a convolutional neural network.
    attn_channel = tf.concat([mean, std], axis=-1)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1] // ratio, kernel_size=(1, 1), activation='relu')(attn_channel)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1], kernel_size=(1, 1), activation='sigmoid')(attn_channel)

    # Compute spatial attention using global information from the input tensor.
    global_info = tf.reduce_mean(input_tensor, axis=-1, keepdims=True)
    attn_spatial = tf.keras.layers.Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(global_info)

    # Combine channel-wise and spatial attention.
    attn = tf.keras.layers.Multiply()([attn_channel,attn_spatial])

    # Multiply the input tensor by the learned attention weights.
    output_tensor = tf.keras.layers.Multiply()([input_tensor,attn])

    return output_tensor

# %%
def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=3, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=5, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=7, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
from tensorflow.keras.applications import ResNet50
def build_encoder2(inputs):

    s=[]
    """ Pre-trained ResNet50 Model """
    resnet50= ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
    for layer in resnet50.layers:
        layer.trainable = True


    """ Encoder """
    s1 = resnet50.get_layer("model_input").output    
    s.append(s1)
    s2 = resnet50.get_layer("conv1_relu").output   
    s.append(s2)
    s3 = resnet50.get_layer("conv2_block3_out").output  
    s.append(s3)
    s4 = resnet50.get_layer("conv3_block4_out").output  
    s.append(s4)

    """ Bridge """
    #b1 = resnet50.get_layer("conv4_block6_out").output 
    b = resnet50.get_layer("conv4_block2_out").output 
    b = ASPP(b,128)
    
    encoder2 = Model(inputs,outputs=[s,b],name = "encoder2")

    return encoder2

# %% [markdown]
# # Model Architecture

# %%
# Code for Net2-Res50

from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D,Conv2DTranspose, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input, ZeroPadding2D,Dropout,Dense,MaxPooling2D,Reshape,Multiply,GlobalAveragePooling2D,AveragePooling2D
from tensorflow.keras.models import Model


"""def complementary_loss(y_true, y_pred):
    mse_loss = tf.reduce_mean(tf.square(y_true - y_pred))
    return tf.math.sigmoid(mse_loss)"""
def complementary_loss(feature_map1,feature_map2):
    # Normalize the feature maps to [0, 1]
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    m1 = tf.reduce_mean(feature_map1)
    m2  = tf.reduce_mean(feature_map2)

    return tf.math.sigmoid(tf.abs(m1-m2))


def batchnorm_relu(inputs):
    x = BatchNormalization()(inputs)
    #x = Activation("relu")(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    return x

def residual_block(inputs, num_filters):
    """ Convolutional Layer """
    x = batchnorm_relu(inputs)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
    x = Dropout(0.1)(x)
    x = batchnorm_relu(x)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)


    """ Shortcut Connection """
    s = Conv2D(num_filters, 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = x + s
    return x

def decoder_block(inputs, s1, num_filters):
    x = Conv2DTranspose(num_filters,2, strides=(2,2), kernel_initializer="he_normal",padding = "same")(inputs)
    x = Concatenate()([x,s1])
    x = residual_block(x, num_filters)
    x = GCSE(x)
    return x
def build_encoder1(inputs,f):
    
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = batchnorm_relu(x)
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(x)
    s = Conv2D(f[0], 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)

    c1 = x + s
    c1 = GCSE(c1)
    p1 = MaxPooling2D((2,2))(c1)
    s1 = c1

    c2 = residual_block(p1, f[1])
    c2 = GCSE(c2)
    p2 = MaxPooling2D((2,2))(c2)
    s2 = c2

    c3 = residual_block(p2, f[2])
    c3 = GCSE(c3)
    p3 = MaxPooling2D((2,2))(c3)
    s3 = c3

    c4 = residual_block(p3, f[3])
    c4 = GCSE(c4)
    p4 = MaxPooling2D((2,2))(c4)
    s4 = c4
    
    s_ = [s1,s2,s3,s4]
    """ Bridge """
    b = ASPP(p4,128)
    encoder1 = Model(inputs,outputs=[s_,b],name="encoder1")
    return encoder1

    
    

def build_WNet(input_shape):
    f = [16,32,64,128]

    inputs = Input(input_shape,name="model_input")
    encoder1 = build_encoder1(inputs,f)
    encoder2 = build_encoder2(inputs)
    s1,b1 = encoder1(inputs)
    s2,b2 = encoder2(inputs)

    b = Concatenate()([b1,b2])

    """ Decoder 1, 2, 3 """
    d1 = decoder_block(b, s2[3],s1[3], f[3]+512)
    d2 = decoder_block(d1, s2[2],s1[2], f[2]+256)
    d3 = decoder_block(d2, s2[1],s1[1], f[1]+64)
    d4 = decoder_block(d3, s2[0],s1[0],f[0]+3)
    
    """ comp1 = complementary_loss(s2[0], s1[0])
    comp2 = complementary_loss(s2[1], s1[1])
    comp3 = complementary_loss(s2[2], s1[2])
    comp4 = complementary_loss(s2[3], s1[3])
    comp5 = complementary_loss(b1, b2)
    

    output_2 = tf.keras.layers.Add(name='output_2')([comp1,comp2,comp3,comp4,comp5])
    """
    """ Classifier """
    output_1 = Conv2D(1, (1,1) , activation="sigmoid",name='output_1')(d4)

    """ Model """
    #model = Model(inputs,outputs=[output_1,output_2])
    model = Model(inputs,outputs=output_1)
    
    return model
def build_Net2(input_shape):
    inputs = Input(input_shape,name="model_input")
    encoder2 = build_encoder2(inputs)
    s2,b2 = encoder2(inputs)
    b = b2
    d1 = decoder_block(b, s2[3], 512)
    d2 = decoder_block(d1, s2[2], 256)
    d3 = decoder_block(d2, s2[1], 128)
    d4 = decoder_block(d3, s2[0], 64)
    
    output_1 = Conv2D(3, (1,1) , activation="softmax",name='output_1')(d4)

    """ Model """
    #model = Model(inputs,outputs=[output_1,output_2])
    model = Model(inputs,outputs=output_1)
    return model

# %% [markdown]
# # Evaluation Metrics

# %%
from keras import backend as K
def iou_liver(targets, inputs, smooth=1e-6):
    
    #flatten label and prediction tensors
    targets_f = K.flatten(targets[:,:,:,1])
    inputs_f = K.flatten(inputs[:,:,:,1])
    
    
    intersection = K.sum((targets_f*inputs_f))
    total = K.sum(targets_f) + K.sum(inputs_f)
    union = total - intersection
    
    IoU = (intersection + smooth) / (union + smooth)
    return IoU

def iou_tumor(targets, inputs, smooth=1e-6):
    
    #flatten label and prediction tensors
    targets_f = K.flatten(targets[:,:,:,2])
    inputs_f = K.flatten(inputs[:,:,:,2])
    
    intersection = K.sum((targets_f * inputs_f))
    total = K.sum(targets_f) + K.sum(inputs_f)
    union = total - intersection
    
    IoU = (intersection + smooth) / (union + smooth)
    return IoU

def iou(targets, inputs, smooth=1e-6):
    
    #flatten label and prediction tensors
    class_num = 3
    for i in range(class_num):
        targets_f= K.flatten(targets[:,:,:,i])
        inputs_f = K.flatten(inputs[:,:,:,i])
       

        intersection = K.sum((targets_f*inputs_f))
        total = K.sum(targets_f) + K.sum(inputs_f)
        union = total - intersection
        loss = (intersection + smooth) / (union + smooth)
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss
def dice_coef(y_true, y_pred, smooth=1e-5):
    class_num = 3
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
   #     K.print_tensor(loss, message='loss value for class {} : '.format(SEGMENT_CLASSES[i]))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
#    K.print_tensor(total_loss, message=' total dice coef: ')
    return total_loss
def dice_coef_liver(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true[:,:,:,1])
    y_pred_f = K.flatten(y_pred[:,:,:,1])
    intersection = K.sum(y_true_f * y_pred_f)
    loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
    return loss

def dice_coef_tumor(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true[:,:,:,2])
    y_pred_f = K.flatten(y_pred[:,:,:,2])
    intersection = K.sum(y_true_f * y_pred_f)
    loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
    return loss

# Computing Sensitivity      
def sensitivity_liver(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true[:,:,:,1] * y_pred[:,:,:,1], 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true[:,:,:,1], 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def sensitivity_tumor(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true[:,:,:,2] * y_pred[:,:,:,2], 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true[:,:,:,2], 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


# Computing Specificity
def specificity_liver(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true[:,:,:,1]) * (1-y_pred[:,:,:,1]), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true[:,:,:,1], 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())
def specificity_tumor(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true[:,:,:,2]) * (1-y_pred[:,:,:,2]), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true[:,:,:,2], 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def tversky(y_true, y_pred):
    smooth=1
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return (3 - tversky(y_true[:,:,:,0],y_pred[:,:,:,0])-tversky(y_true[:,:,:,1],y_pred[:,:,:,1])-tversky(y_true[:,:,:,2],y_pred[:,:,:,2]))

def focal_tversky_loss(y_true,y_pred):
    pt_1 = tversky(y_true[:,:,:,0],y_pred[:,:,:,0])
    pt_2 = tversky(y_true[:,:,:,1],y_pred[:,:,:,1])
    pt_3 = tversky(y_true[:,:,:,2],y_pred[:,:,:,2])
    
    gamma = 0.75
    return K.pow((3-pt_1-pt_2-pt_3), gamma)

# %%
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

# %%
# !pip install -U segmentation-models
#%env SM_FRAMEWORK=tf.keras
# Out:
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.9 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation-models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from efficientnet==1.0.0->segmentation-models) (0.21.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.10/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.24.3)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.9.0)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (9.5.0)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.8.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (21.3)
# Requirement already satisfied: lazy_loader>=0.2 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image->efficientnet==1.0.0->segmentation-models) (3.0.9)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1

# %%
import segmentation_models as sm
dice_loss = sm.losses.DiceLoss(class_weights = [0.33,0.33,0.33]) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from keras.callbacks import CSVLogger
model = build_Net2((256,256,3))
adam = tf.keras.optimizers.Adam(learning_rate = 0.0001)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  model_input (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#  encoder2 (Functional)       [[(None, 256, 256, 3),       7988224   ['model_input[0][0]']
#                               (None, 128, 128, 64),
#                               (None, 64, 64, 256),
#                               (None, 32, 32, 512)],
#                               (None, 16, 16, 128)]
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 512)          262656    ['encoder2[0][4]']
#  anspose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 1024)         0         ['conv2d_transpose[0][0]',
#  )                                                                   'encoder2[0][3]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 1024)         4096      ['concatenate_1[0][0]']
#  chNormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 32, 32, 1024)         0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 512)          4719104   ['leaky_re_lu[0][0]']
#
#  dropout (Dropout)           (None, 32, 32, 512)          0         ['conv2d_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 512)          2048      ['dropout[0][0]']
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 32, 32, 512)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 512)          2359808   ['leaky_re_lu_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 512)          524800    ['concatenate_1[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 32, 32, 512)          0         ['conv2d_7[0][0]',
#  Lambda)                                                             'conv2d_8[0][0]']
#
#  tf.math.reduce_mean (TFOpL  (None, 1, 1, 512)            0         ['tf.__operators__.add[0][0]']
#  ambda)
#
#  tf.math.reduce_std (TFOpLa  (None, 1, 1, 512)            0         ['tf.__operators__.add[0][0]']
#  mbda)
#
#  tf.concat (TFOpLambda)      (None, 1, 1, 1024)           0         ['tf.math.reduce_mean[0][0]',
#                                                                      'tf.math.reduce_std[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 1, 1, 32)             32800     ['tf.concat[0][0]']
#
#  tf.math.reduce_mean_1 (TFO  (None, 32, 32, 1)            0         ['tf.__operators__.add[0][0]']
#  pLambda)
#
#  conv2d_10 (Conv2D)          (None, 1, 1, 512)            16896     ['conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 1)            2         ['tf.math.reduce_mean_1[0][0]'
#                                                                     ]
#
#  multiply (Multiply)         (None, 32, 32, 512)          0         ['conv2d_10[0][0]',
#                                                                      'conv2d_11[0][0]']
#
#  multiply_1 (Multiply)       (None, 32, 32, 512)          0         ['tf.__operators__.add[0][0]',
#                                                                      'multiply[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 256)          524544    ['multiply_1[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 512)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'encoder2[0][2]']
#
#  batch_normalization_8 (Bat  (None, 64, 64, 512)          2048      ['concatenate_2[0][0]']
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 64, 64, 512)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 256)          1179904   ['leaky_re_lu_2[0][0]']
#
#  dropout_1 (Dropout)         (None, 64, 64, 256)          0         ['conv2d_12[0][0]']
#
#  batch_normalization_9 (Bat  (None, 64, 64, 256)          1024      ['dropout_1[0][0]']
#  chNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 64, 64, 256)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 256)          590080    ['leaky_re_lu_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 256)          131328    ['concatenate_2[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 64, 64, 256)          0         ['conv2d_13[0][0]',
#  OpLambda)                                                           'conv2d_14[0][0]']
#
#  tf.math.reduce_mean_2 (TFO  (None, 1, 1, 256)            0         ['tf.__operators__.add_1[0][0]
#  pLambda)                                                           ']
#
#  tf.math.reduce_std_1 (TFOp  (None, 1, 1, 256)            0         ['tf.__operators__.add_1[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_1 (TFOpLambda)    (None, 1, 1, 512)            0         ['tf.math.reduce_mean_2[0][0]'
#                                                                     , 'tf.math.reduce_std_1[0][0]'
#                                                                     ]
#
#  conv2d_15 (Conv2D)          (None, 1, 1, 16)             8208      ['tf.concat_1[0][0]']
#
#  tf.math.reduce_mean_3 (TFO  (None, 64, 64, 1)            0         ['tf.__operators__.add_1[0][0]
#  pLambda)                                                           ']
#
#  conv2d_16 (Conv2D)          (None, 1, 1, 256)            4352      ['conv2d_15[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 1)            2         ['tf.math.reduce_mean_3[0][0]'
#                                                                     ]
#
#  multiply_2 (Multiply)       (None, 64, 64, 256)          0         ['conv2d_16[0][0]',
#                                                                      'conv2d_17[0][0]']
#
#  multiply_3 (Multiply)       (None, 64, 64, 256)          0         ['tf.__operators__.add_1[0][0]
#                                                                     ',
#                                                                      'multiply_2[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 128)        131200    ['multiply_3[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 192)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'encoder2[0][1]']
#
#  batch_normalization_10 (Ba  (None, 128, 128, 192)        768       ['concatenate_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 128, 128, 192)        0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 128, 128, 128)        221312    ['leaky_re_lu_4[0][0]']
#
#  dropout_2 (Dropout)         (None, 128, 128, 128)        0         ['conv2d_18[0][0]']
#
#  batch_normalization_11 (Ba  (None, 128, 128, 128)        512       ['dropout_2[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 128, 128, 128)        0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 128, 128, 128)        147584    ['leaky_re_lu_5[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 128, 128, 128)        24704     ['concatenate_3[0][0]']
#
#  tf.__operators__.add_2 (TF  (None, 128, 128, 128)        0         ['conv2d_19[0][0]',
#  OpLambda)                                                           'conv2d_20[0][0]']
#
#  tf.math.reduce_mean_4 (TFO  (None, 1, 1, 128)            0         ['tf.__operators__.add_2[0][0]
#  pLambda)                                                           ']
#
#  tf.math.reduce_std_2 (TFOp  (None, 1, 1, 128)            0         ['tf.__operators__.add_2[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_2 (TFOpLambda)    (None, 1, 1, 256)            0         ['tf.math.reduce_mean_4[0][0]'
#                                                                     , 'tf.math.reduce_std_2[0][0]'
#                                                                     ]
#
#  conv2d_21 (Conv2D)          (None, 1, 1, 8)              2056      ['tf.concat_2[0][0]']
#
#  tf.math.reduce_mean_5 (TFO  (None, 128, 128, 1)          0         ['tf.__operators__.add_2[0][0]
#  pLambda)                                                           ']
#
#  conv2d_22 (Conv2D)          (None, 1, 1, 128)            1152      ['conv2d_21[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 128, 128, 1)          2         ['tf.math.reduce_mean_5[0][0]'
#                                                                     ]
#
#  multiply_4 (Multiply)       (None, 128, 128, 128)        0         ['conv2d_22[0][0]',
#                                                                      'conv2d_23[0][0]']
#
#  multiply_5 (Multiply)       (None, 128, 128, 128)        0         ['tf.__operators__.add_2[0][0]
#                                                                     ',
#                                                                      'multiply_4[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 64)         32832     ['multiply_5[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 256, 256, 67)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'encoder2[0][0]']
#
#  batch_normalization_12 (Ba  (None, 256, 256, 67)         268       ['concatenate_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 256, 256, 67)         0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 256, 256, 64)         38656     ['leaky_re_lu_6[0][0]']
#
#  dropout_3 (Dropout)         (None, 256, 256, 64)         0         ['conv2d_24[0][0]']
#
#  batch_normalization_13 (Ba  (None, 256, 256, 64)         256       ['dropout_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 256, 256, 64)         0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 256, 256, 64)         36928     ['leaky_re_lu_7[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 256, 256, 64)         4352      ['concatenate_4[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 256, 256, 64)         0         ['conv2d_25[0][0]',
#  OpLambda)                                                           'conv2d_26[0][0]']
#
#  tf.math.reduce_mean_6 (TFO  (None, 1, 1, 64)             0         ['tf.__operators__.add_3[0][0]
#  pLambda)                                                           ']
#
#  tf.math.reduce_std_3 (TFOp  (None, 1, 1, 64)             0         ['tf.__operators__.add_3[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_3 (TFOpLambda)    (None, 1, 1, 128)            0         ['tf.math.reduce_mean_6[0][0]'
#                                                                     , 'tf.math.reduce_std_3[0][0]'
#                                                                     ]
#
#  conv2d_27 (Conv2D)          (None, 1, 1, 4)              516       ['tf.concat_3[0][0]']
#
#  tf.math.reduce_mean_7 (TFO  (None, 256, 256, 1)          0         ['tf.__operators__.add_3[0][0]
#  pLambda)                                                           ']
#
#  conv2d_28 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_27[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 256, 256, 1)          2         ['tf.math.reduce_mean_7[0][0]'
#                                                                     ]
#
#  multiply_6 (Multiply)       (None, 256, 256, 64)         0         ['conv2d_28[0][0]',
#                                                                      'conv2d_29[0][0]']
#
#  multiply_7 (Multiply)       (None, 256, 256, 64)         0         ['tf.__operators__.add_3[0][0]
#                                                                     ',
#                                                                      'multiply_6[0][0]']
#
#  output_1 (Conv2D)           (None, 256, 256, 3)          195       ['multiply_7[0][0]']
#
# ==================================================================================================
# Total params: 18995539 (72.46 MB)
# Trainable params: 18970189 (72.37 MB)
# Non-trainable params: 25350 (99.02 KB)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001), loss=total_loss,
              metrics = {"output_1":[dice_coef_liver,dice_coef_tumor,iou_liver,iou_tumor,sensitivity_liver,sensitivity_tumor,specificity_liver,specificity_tumor]})

#callbacks
csv_logger = CSVLogger('/kaggle/working/training_log_WNet_Res50', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min', 
                              verbose=1, 
                              patience=6
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_Res50.h5", 
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, earlystopping, reduce_lr, csv_logger]

# %%
batch_size = 16
N = 256
epochs = 50
train_generator = CustomDataGenerator(df_train, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(df_val, batch_size=batch_size, image_size=(N,N), shuffle=False)
history = model.fit(train_generator, steps_per_epoch=len(df_train) // batch_size,
                    validation_data=val_generator, validation_steps=len(df_val) // batch_size,
                    epochs=epochs,callbacks=callbacks)
# Out:
# Epoch 1/50
# 2024-01-21 10:58:00.684244: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 836/836 [==============================] - ETA: 0s - loss: 0.7262 - dice_coef_liver: 0.8954 - dice_coef_tumor: 0.6395 - iou_liver: 0.8253 - iou_tumor: 0.5073 - sensitivity_liver: 0.9079 - sensitivity_tumor: 0.6330 - specificity_liver: 0.9937 - specificity_tumor: 0.9993
# Epoch 1: val_loss improved from inf to 0.75016, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 592s 648ms/step - loss: 0.7262 - dice_coef_liver: 0.8954 - dice_coef_tumor: 0.6395 - iou_liver: 0.8253 - iou_tumor: 0.5073 - sensitivity_liver: 0.9079 - sensitivity_tumor: 0.6330 - specificity_liver: 0.9937 - specificity_tumor: 0.9993 - val_loss: 0.7502 - val_dice_coef_liver: 0.8449 - val_dice_coef_tumor: 0.4744 - val_iou_liver: 0.7324 - val_iou_tumor: 0.3303 - val_sensitivity_liver: 0.8196 - val_sensitivity_tumor: 0.6832 - val_specificity_liver: 0.9961 - val_specificity_tumor: 0.9965 - lr: 1.0000e-04
# Epoch 2/50
# 836/836 [==============================] - ETA: 0s - loss: 0.7040 - dice_coef_liver: 0.9437 - dice_coef_tumor: 0.7721 - iou_liver: 0.8937 - iou_tumor: 0.6467 - sensitivity_liver: 0.9464 - sensitivity_tumor: 0.7607 - specificity_liver: 0.9967 - specificity_tumor: 0.9995
# Epoch 2: val_loss improved from 0.75016 to 0.70245, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 519s 620ms/step - loss: 0.7040 - dice_coef_liver: 0.9437 - dice_coef_tumor: 0.7721 - iou_liver: 0.8937 - iou_tumor: 0.6467 - sensitivity_liver: 0.9464 - sensitivity_tumor: 0.7607 - specificity_liver: 0.9967 - specificity_tumor: 0.9995 - val_loss: 0.7025 - val_dice_coef_liver: 0.9469 - val_dice_coef_tumor: 0.7843 - val_iou_liver: 0.8994 - val_iou_tumor: 0.6634 - val_sensitivity_liver: 0.9452 - val_sensitivity_tumor: 0.7985 - val_specificity_liver: 0.9969 - val_specificity_tumor: 0.9994 - lr: 1.0000e-04
# Epoch 3/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6979 - dice_coef_liver: 0.9519 - dice_coef_tumor: 0.8149 - iou_liver: 0.9084 - iou_tumor: 0.7001 - sensitivity_liver: 0.9545 - sensitivity_tumor: 0.8013 - specificity_liver: 0.9971 - specificity_tumor: 0.9996
# Epoch 3: val_loss improved from 0.70245 to 0.69731, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 523s 625ms/step - loss: 0.6979 - dice_coef_liver: 0.9519 - dice_coef_tumor: 0.8149 - iou_liver: 0.9084 - iou_tumor: 0.7001 - sensitivity_liver: 0.9545 - sensitivity_tumor: 0.8013 - specificity_liver: 0.9971 - specificity_tumor: 0.9996 - val_loss: 0.6973 - val_dice_coef_liver: 0.9540 - val_dice_coef_tumor: 0.8183 - val_iou_liver: 0.9121 - val_iou_tumor: 0.7114 - val_sensitivity_liver: 0.9688 - val_sensitivity_tumor: 0.8368 - val_specificity_liver: 0.9962 - val_specificity_tumor: 0.9995 - lr: 1.0000e-04
# Epoch 4/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6954 - dice_coef_liver: 0.9546 - dice_coef_tumor: 0.8335 - iou_liver: 0.9132 - iou_tumor: 0.7258 - sensitivity_liver: 0.9574 - sensitivity_tumor: 0.8209 - specificity_liver: 0.9972 - specificity_tumor: 0.9996
# Epoch 4: val_loss did not improve from 0.69731
# 836/836 [==============================] - 518s 619ms/step - loss: 0.6954 - dice_coef_liver: 0.9546 - dice_coef_tumor: 0.8335 - iou_liver: 0.9132 - iou_tumor: 0.7258 - sensitivity_liver: 0.9574 - sensitivity_tumor: 0.8209 - specificity_liver: 0.9972 - specificity_tumor: 0.9996 - val_loss: 0.6986 - val_dice_coef_liver: 0.9469 - val_dice_coef_tumor: 0.8182 - val_iou_liver: 0.8992 - val_iou_tumor: 0.7128 - val_sensitivity_liver: 0.9796 - val_sensitivity_tumor: 0.7938 - val_specificity_liver: 0.9944 - val_specificity_tumor: 0.9996 - lr: 1.0000e-04
# Epoch 5/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6947 - dice_coef_liver: 0.9570 - dice_coef_tumor: 0.8364 - iou_liver: 0.9177 - iou_tumor: 0.7315 - sensitivity_liver: 0.9599 - sensitivity_tumor: 0.8245 - specificity_liver: 0.9973 - specificity_tumor: 0.9996
# Epoch 5: val_loss improved from 0.69731 to 0.69562, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 519s 621ms/step - loss: 0.6947 - dice_coef_liver: 0.9570 - dice_coef_tumor: 0.8364 - iou_liver: 0.9177 - iou_tumor: 0.7315 - sensitivity_liver: 0.9599 - sensitivity_tumor: 0.8245 - specificity_liver: 0.9973 - specificity_tumor: 0.9996 - val_loss: 0.6956 - val_dice_coef_liver: 0.9555 - val_dice_coef_tumor: 0.8316 - val_iou_liver: 0.9150 - val_iou_tumor: 0.7289 - val_sensitivity_liver: 0.9693 - val_sensitivity_tumor: 0.8067 - val_specificity_liver: 0.9963 - val_specificity_tumor: 0.9996 - lr: 1.0000e-04
# Epoch 6/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6939 - dice_coef_liver: 0.9581 - dice_coef_tumor: 0.8420 - iou_liver: 0.9197 - iou_tumor: 0.7401 - sensitivity_liver: 0.9612 - sensitivity_tumor: 0.8298 - specificity_liver: 0.9974 - specificity_tumor: 0.9996
# Epoch 6: val_loss improved from 0.69562 to 0.69511, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 519s 621ms/step - loss: 0.6939 - dice_coef_liver: 0.9581 - dice_coef_tumor: 0.8420 - iou_liver: 0.9197 - iou_tumor: 0.7401 - sensitivity_liver: 0.9612 - sensitivity_tumor: 0.8298 - specificity_liver: 0.9974 - specificity_tumor: 0.9996 - val_loss: 0.6951 - val_dice_coef_liver: 0.9581 - val_dice_coef_tumor: 0.8318 - val_iou_liver: 0.9197 - val_iou_tumor: 0.7281 - val_sensitivity_liver: 0.9713 - val_sensitivity_tumor: 0.8532 - val_specificity_liver: 0.9965 - val_specificity_tumor: 0.9995 - lr: 1.0000e-04
# Epoch 7/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6926 - dice_coef_liver: 0.9597 - dice_coef_tumor: 0.8518 - iou_liver: 0.9225 - iou_tumor: 0.7531 - sensitivity_liver: 0.9624 - sensitivity_tumor: 0.8424 - specificity_liver: 0.9975 - specificity_tumor: 0.9996
# Epoch 7: val_loss improved from 0.69511 to 0.69377, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 519s 620ms/step - loss: 0.6926 - dice_coef_liver: 0.9597 - dice_coef_tumor: 0.8518 - iou_liver: 0.9225 - iou_tumor: 0.7531 - sensitivity_liver: 0.9624 - sensitivity_tumor: 0.8424 - specificity_liver: 0.9975 - specificity_tumor: 0.9996 - val_loss: 0.6938 - val_dice_coef_liver: 0.9594 - val_dice_coef_tumor: 0.8432 - val_iou_liver: 0.9221 - val_iou_tumor: 0.7439 - val_sensitivity_liver: 0.9541 - val_sensitivity_tumor: 0.8736 - val_specificity_liver: 0.9979 - val_specificity_tumor: 0.9994 - lr: 1.0000e-04
# Epoch 8/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6906 - dice_coef_liver: 0.9615 - dice_coef_tumor: 0.8664 - iou_liver: 0.9260 - iou_tumor: 0.7720 - sensitivity_liver: 0.9645 - sensitivity_tumor: 0.8557 - specificity_liver: 0.9976 - specificity_tumor: 0.9997
# Epoch 8: val_loss improved from 0.69377 to 0.69265, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 518s 619ms/step - loss: 0.6906 - dice_coef_liver: 0.9615 - dice_coef_tumor: 0.8664 - iou_liver: 0.9260 - iou_tumor: 0.7720 - sensitivity_liver: 0.9645 - sensitivity_tumor: 0.8557 - specificity_liver: 0.9976 - specificity_tumor: 0.9997 - val_loss: 0.6926 - val_dice_coef_liver: 0.9633 - val_dice_coef_tumor: 0.8476 - val_iou_liver: 0.9293 - val_iou_tumor: 0.7492 - val_sensitivity_liver: 0.9655 - val_sensitivity_tumor: 0.8871 - val_specificity_liver: 0.9976 - val_specificity_tumor: 0.9994 - lr: 1.0000e-04
# Epoch 9/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6907 - dice_coef_liver: 0.9630 - dice_coef_tumor: 0.8637 - iou_liver: 0.9287 - iou_tumor: 0.7710 - sensitivity_liver: 0.9660 - sensitivity_tumor: 0.8526 - specificity_liver: 0.9977 - specificity_tumor: 0.9997
# Epoch 9: val_loss did not improve from 0.69265
# 836/836 [==============================] - 525s 628ms/step - loss: 0.6907 - dice_coef_liver: 0.9630 - dice_coef_tumor: 0.8637 - iou_liver: 0.9287 - iou_tumor: 0.7710 - sensitivity_liver: 0.9660 - sensitivity_tumor: 0.8526 - specificity_liver: 0.9977 - specificity_tumor: 0.9997 - val_loss: 0.6943 - val_dice_coef_liver: 0.9630 - val_dice_coef_tumor: 0.8329 - val_iou_liver: 0.9288 - val_iou_tumor: 0.7300 - val_sensitivity_liver: 0.9700 - val_sensitivity_tumor: 0.8817 - val_specificity_liver: 0.9972 - val_specificity_tumor: 0.9994 - lr: 1.0000e-04
# Epoch 10/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6899 - dice_coef_liver: 0.9631 - dice_coef_tumor: 0.8707 - iou_liver: 0.9289 - iou_tumor: 0.7780 - sensitivity_liver: 0.9664 - sensitivity_tumor: 0.8599 - specificity_liver: 0.9976 - specificity_tumor: 0.9997
# Epoch 10: val_loss did not improve from 0.69265
# 836/836 [==============================] - 521s 623ms/step - loss: 0.6899 - dice_coef_liver: 0.9631 - dice_coef_tumor: 0.8707 - iou_liver: 0.9289 - iou_tumor: 0.7780 - sensitivity_liver: 0.9664 - sensitivity_tumor: 0.8599 - specificity_liver: 0.9976 - specificity_tumor: 0.9997 - val_loss: 0.7019 - val_dice_coef_liver: 0.9531 - val_dice_coef_tumor: 0.7809 - val_iou_liver: 0.9105 - val_iou_tumor: 0.6591 - val_sensitivity_liver: 0.9746 - val_sensitivity_tumor: 0.8315 - val_specificity_liver: 0.9957 - val_specificity_tumor: 0.9991 - lr: 1.0000e-04
# Epoch 11/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6897 - dice_coef_liver: 0.9634 - dice_coef_tumor: 0.8721 - iou_liver: 0.9295 - iou_tumor: 0.7806 - sensitivity_liver: 0.9666 - sensitivity_tumor: 0.8607 - specificity_liver: 0.9977 - specificity_tumor: 0.9997
# Epoch 11: val_loss did not improve from 0.69265
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 836/836 [==============================] - 521s 623ms/step - loss: 0.6897 - dice_coef_liver: 0.9634 - dice_coef_tumor: 0.8721 - iou_liver: 0.9295 - iou_tumor: 0.7806 - sensitivity_liver: 0.9666 - sensitivity_tumor: 0.8607 - specificity_liver: 0.9977 - specificity_tumor: 0.9997 - val_loss: 0.6928 - val_dice_coef_liver: 0.9629 - val_dice_coef_tumor: 0.8455 - val_iou_liver: 0.9285 - val_iou_tumor: 0.7453 - val_sensitivity_liver: 0.9630 - val_sensitivity_tumor: 0.8990 - val_specificity_liver: 0.9978 - val_specificity_tumor: 0.9994 - lr: 1.0000e-04
# Epoch 12/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6885 - dice_coef_liver: 0.9659 - dice_coef_tumor: 0.8794 - iou_liver: 0.9342 - iou_tumor: 0.7948 - sensitivity_liver: 0.9689 - sensitivity_tumor: 0.8711 - specificity_liver: 0.9978 - specificity_tumor: 0.9997
# Epoch 12: val_loss improved from 0.69265 to 0.69083, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 520s 622ms/step - loss: 0.6885 - dice_coef_liver: 0.9659 - dice_coef_tumor: 0.8794 - iou_liver: 0.9342 - iou_tumor: 0.7948 - sensitivity_liver: 0.9689 - sensitivity_tumor: 0.8711 - specificity_liver: 0.9978 - specificity_tumor: 0.9997 - val_loss: 0.6908 - val_dice_coef_liver: 0.9646 - val_dice_coef_tumor: 0.8620 - val_iou_liver: 0.9317 - val_iou_tumor: 0.7714 - val_sensitivity_liver: 0.9768 - val_sensitivity_tumor: 0.8837 - val_specificity_liver: 0.9969 - val_specificity_tumor: 0.9995 - lr: 3.0000e-05
# Epoch 13/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6872 - dice_coef_liver: 0.9672 - dice_coef_tumor: 0.8888 - iou_liver: 0.9365 - iou_tumor: 0.8074 - sensitivity_liver: 0.9703 - sensitivity_tumor: 0.8796 - specificity_liver: 0.9979 - specificity_tumor: 0.9997
# Epoch 13: val_loss did not improve from 0.69083
# 836/836 [==============================] - 518s 619ms/step - loss: 0.6872 - dice_coef_liver: 0.9672 - dice_coef_tumor: 0.8888 - iou_liver: 0.9365 - iou_tumor: 0.8074 - sensitivity_liver: 0.9703 - sensitivity_tumor: 0.8796 - specificity_liver: 0.9979 - specificity_tumor: 0.9997 - val_loss: 0.6935 - val_dice_coef_liver: 0.9641 - val_dice_coef_tumor: 0.8381 - val_iou_liver: 0.9308 - val_iou_tumor: 0.7346 - val_sensitivity_liver: 0.9683 - val_sensitivity_tumor: 0.9181 - val_specificity_liver: 0.9975 - val_specificity_tumor: 0.9992 - lr: 3.0000e-05
# Epoch 14/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6875 - dice_coef_liver: 0.9674 - dice_coef_tumor: 0.8857 - iou_liver: 0.9370 - iou_tumor: 0.8062 - sensitivity_liver: 0.9707 - sensitivity_tumor: 0.8750 - specificity_liver: 0.9979 - specificity_tumor: 0.9997
# Epoch 14: val_loss improved from 0.69083 to 0.68971, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 518s 620ms/step - loss: 0.6875 - dice_coef_liver: 0.9674 - dice_coef_tumor: 0.8857 - iou_liver: 0.9370 - iou_tumor: 0.8062 - sensitivity_liver: 0.9707 - sensitivity_tumor: 0.8750 - specificity_liver: 0.9979 - specificity_tumor: 0.9997 - val_loss: 0.6897 - val_dice_coef_liver: 0.9672 - val_dice_coef_tumor: 0.8675 - val_iou_liver: 0.9365 - val_iou_tumor: 0.7785 - val_sensitivity_liver: 0.9730 - val_sensitivity_tumor: 0.8891 - val_specificity_liver: 0.9976 - val_specificity_tumor: 0.9995 - lr: 3.0000e-05
# Epoch 15/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6872 - dice_coef_liver: 0.9674 - dice_coef_tumor: 0.8891 - iou_liver: 0.9369 - iou_tumor: 0.8096 - sensitivity_liver: 0.9708 - sensitivity_tumor: 0.8798 - specificity_liver: 0.9979 - specificity_tumor: 0.9997
# Epoch 15: val_loss improved from 0.68971 to 0.68857, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 519s 620ms/step - loss: 0.6872 - dice_coef_liver: 0.9674 - dice_coef_tumor: 0.8891 - iou_liver: 0.9369 - iou_tumor: 0.8096 - sensitivity_liver: 0.9708 - sensitivity_tumor: 0.8798 - specificity_liver: 0.9979 - specificity_tumor: 0.9997 - val_loss: 0.6886 - val_dice_coef_liver: 0.9677 - val_dice_coef_tumor: 0.8767 - val_iou_liver: 0.9374 - val_iou_tumor: 0.7927 - val_sensitivity_liver: 0.9755 - val_sensitivity_tumor: 0.8847 - val_specificity_liver: 0.9975 - val_specificity_tumor: 0.9996 - lr: 3.0000e-05
# Epoch 16/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6866 - dice_coef_liver: 0.9683 - dice_coef_tumor: 0.8932 - iou_liver: 0.9386 - iou_tumor: 0.8163 - sensitivity_liver: 0.9716 - sensitivity_tumor: 0.8829 - specificity_liver: 0.9979 - specificity_tumor: 0.9997
# Epoch 16: val_loss did not improve from 0.68857
# 836/836 [==============================] - 519s 620ms/step - loss: 0.6866 - dice_coef_liver: 0.9683 - dice_coef_tumor: 0.8932 - iou_liver: 0.9386 - iou_tumor: 0.8163 - sensitivity_liver: 0.9716 - sensitivity_tumor: 0.8829 - specificity_liver: 0.9979 - specificity_tumor: 0.9997 - val_loss: 0.6888 - val_dice_coef_liver: 0.9668 - val_dice_coef_tumor: 0.8755 - val_iou_liver: 0.9358 - val_iou_tumor: 0.7920 - val_sensitivity_liver: 0.9779 - val_sensitivity_tumor: 0.8903 - val_specificity_liver: 0.9972 - val_specificity_tumor: 0.9996 - lr: 3.0000e-05
# Epoch 17/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6848 - dice_coef_liver: 0.9686 - dice_coef_tumor: 0.9079 - iou_liver: 0.9392 - iou_tumor: 0.8345 - sensitivity_liver: 0.9719 - sensitivity_tumor: 0.9018 - specificity_liver: 0.9980 - specificity_tumor: 0.9997
# Epoch 17: val_loss did not improve from 0.68857
# 836/836 [==============================] - 517s 618ms/step - loss: 0.6848 - dice_coef_liver: 0.9686 - dice_coef_tumor: 0.9079 - iou_liver: 0.9392 - iou_tumor: 0.8345 - sensitivity_liver: 0.9719 - sensitivity_tumor: 0.9018 - specificity_liver: 0.9980 - specificity_tumor: 0.9997 - val_loss: 0.6976 - val_dice_coef_liver: 0.9683 - val_dice_coef_tumor: 0.7941 - val_iou_liver: 0.9386 - val_iou_tumor: 0.6810 - val_sensitivity_liver: 0.9714 - val_sensitivity_tumor: 0.9115 - val_specificity_liver: 0.9979 - val_specificity_tumor: 0.9991 - lr: 3.0000e-05
# Epoch 18/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6851 - dice_coef_liver: 0.9689 - dice_coef_tumor: 0.9056 - iou_liver: 0.9398 - iou_tumor: 0.8329 - sensitivity_liver: 0.9722 - sensitivity_tumor: 0.9019 - specificity_liver: 0.9980 - specificity_tumor: 0.9997
# Epoch 18: val_loss improved from 0.68857 to 0.68692, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 520s 622ms/step - loss: 0.6851 - dice_coef_liver: 0.9689 - dice_coef_tumor: 0.9056 - iou_liver: 0.9398 - iou_tumor: 0.8329 - sensitivity_liver: 0.9722 - sensitivity_tumor: 0.9019 - specificity_liver: 0.9980 - specificity_tumor: 0.9997 - val_loss: 0.6869 - val_dice_coef_liver: 0.9685 - val_dice_coef_tumor: 0.8905 - val_iou_liver: 0.9390 - val_iou_tumor: 0.8129 - val_sensitivity_liver: 0.9734 - val_sensitivity_tumor: 0.8960 - val_specificity_liver: 0.9977 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
# Epoch 19/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6848 - dice_coef_liver: 0.9692 - dice_coef_tumor: 0.9078 - iou_liver: 0.9403 - iou_tumor: 0.8363 - sensitivity_liver: 0.9726 - sensitivity_tumor: 0.9028 - specificity_liver: 0.9980 - specificity_tumor: 0.9998
# Epoch 19: val_loss improved from 0.68692 to 0.68626, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 519s 620ms/step - loss: 0.6848 - dice_coef_liver: 0.9692 - dice_coef_tumor: 0.9078 - iou_liver: 0.9403 - iou_tumor: 0.8363 - sensitivity_liver: 0.9726 - sensitivity_tumor: 0.9028 - specificity_liver: 0.9980 - specificity_tumor: 0.9998 - val_loss: 0.6863 - val_dice_coef_liver: 0.9688 - val_dice_coef_tumor: 0.8960 - val_iou_liver: 0.9396 - val_iou_tumor: 0.8180 - val_sensitivity_liver: 0.9753 - val_sensitivity_tumor: 0.9144 - val_specificity_liver: 0.9976 - val_specificity_tumor: 0.9996 - lr: 3.0000e-05
# Epoch 20/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6840 - dice_coef_liver: 0.9699 - dice_coef_tumor: 0.9139 - iou_liver: 0.9416 - iou_tumor: 0.8447 - sensitivity_liver: 0.9733 - sensitivity_tumor: 0.9092 - specificity_liver: 0.9980 - specificity_tumor: 0.9998
# Epoch 20: val_loss improved from 0.68626 to 0.68613, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 520s 622ms/step - loss: 0.6840 - dice_coef_liver: 0.9699 - dice_coef_tumor: 0.9139 - iou_liver: 0.9416 - iou_tumor: 0.8447 - sensitivity_liver: 0.9733 - sensitivity_tumor: 0.9092 - specificity_liver: 0.9980 - specificity_tumor: 0.9998 - val_loss: 0.6861 - val_dice_coef_liver: 0.9692 - val_dice_coef_tumor: 0.8964 - val_iou_liver: 0.9404 - val_iou_tumor: 0.8193 - val_sensitivity_liver: 0.9767 - val_sensitivity_tumor: 0.9083 - val_specificity_liver: 0.9976 - val_specificity_tumor: 0.9996 - lr: 3.0000e-05
# Epoch 21/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6841 - dice_coef_liver: 0.9697 - dice_coef_tumor: 0.9130 - iou_liver: 0.9411 - iou_tumor: 0.8432 - sensitivity_liver: 0.9730 - sensitivity_tumor: 0.9093 - specificity_liver: 0.9980 - specificity_tumor: 0.9998
# Epoch 21: val_loss improved from 0.68613 to 0.68576, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 520s 621ms/step - loss: 0.6841 - dice_coef_liver: 0.9697 - dice_coef_tumor: 0.9130 - iou_liver: 0.9411 - iou_tumor: 0.8432 - sensitivity_liver: 0.9730 - sensitivity_tumor: 0.9093 - specificity_liver: 0.9980 - specificity_tumor: 0.9998 - val_loss: 0.6858 - val_dice_coef_liver: 0.9689 - val_dice_coef_tumor: 0.8998 - val_iou_liver: 0.9397 - val_iou_tumor: 0.8242 - val_sensitivity_liver: 0.9730 - val_sensitivity_tumor: 0.9145 - val_specificity_liver: 0.9979 - val_specificity_tumor: 0.9996 - lr: 3.0000e-05
# Epoch 22/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6842 - dice_coef_liver: 0.9701 - dice_coef_tumor: 0.9114 - iou_liver: 0.9420 - iou_tumor: 0.8435 - sensitivity_liver: 0.9735 - sensitivity_tumor: 0.9067 - specificity_liver: 0.9980 - specificity_tumor: 0.9998
# Epoch 22: val_loss improved from 0.68576 to 0.68550, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 522s 624ms/step - loss: 0.6842 - dice_coef_liver: 0.9701 - dice_coef_tumor: 0.9114 - iou_liver: 0.9420 - iou_tumor: 0.8435 - sensitivity_liver: 0.9735 - sensitivity_tumor: 0.9067 - specificity_liver: 0.9980 - specificity_tumor: 0.9998 - val_loss: 0.6855 - val_dice_coef_liver: 0.9696 - val_dice_coef_tumor: 0.9016 - val_iou_liver: 0.9410 - val_iou_tumor: 0.8269 - val_sensitivity_liver: 0.9771 - val_sensitivity_tumor: 0.9202 - val_specificity_liver: 0.9976 - val_specificity_tumor: 0.9996 - lr: 3.0000e-05
# Epoch 23/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6835 - dice_coef_liver: 0.9706 - dice_coef_tumor: 0.9177 - iou_liver: 0.9430 - iou_tumor: 0.8511 - sensitivity_liver: 0.9739 - sensitivity_tumor: 0.9134 - specificity_liver: 0.9981 - specificity_tumor: 0.9998
# Epoch 23: val_loss did not improve from 0.68550
# 836/836 [==============================] - 523s 625ms/step - loss: 0.6835 - dice_coef_liver: 0.9706 - dice_coef_tumor: 0.9177 - iou_liver: 0.9430 - iou_tumor: 0.8511 - sensitivity_liver: 0.9739 - sensitivity_tumor: 0.9134 - specificity_liver: 0.9981 - specificity_tumor: 0.9998 - val_loss: 0.6858 - val_dice_coef_liver: 0.9700 - val_dice_coef_tumor: 0.8986 - val_iou_liver: 0.9419 - val_iou_tumor: 0.8231 - val_sensitivity_liver: 0.9730 - val_sensitivity_tumor: 0.9148 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9996 - lr: 3.0000e-05
# Epoch 24/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6837 - dice_coef_liver: 0.9709 - dice_coef_tumor: 0.9151 - iou_liver: 0.9435 - iou_tumor: 0.8481 - sensitivity_liver: 0.9742 - sensitivity_tumor: 0.9112 - specificity_liver: 0.9981 - specificity_tumor: 0.9998
# Epoch 24: val_loss did not improve from 0.68550
# 836/836 [==============================] - 522s 624ms/step - loss: 0.6837 - dice_coef_liver: 0.9709 - dice_coef_tumor: 0.9151 - iou_liver: 0.9435 - iou_tumor: 0.8481 - sensitivity_liver: 0.9742 - sensitivity_tumor: 0.9112 - specificity_liver: 0.9981 - specificity_tumor: 0.9998 - val_loss: 0.6859 - val_dice_coef_liver: 0.9705 - val_dice_coef_tumor: 0.8969 - val_iou_liver: 0.9427 - val_iou_tumor: 0.8201 - val_sensitivity_liver: 0.9726 - val_sensitivity_tumor: 0.9254 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9996 - lr: 3.0000e-05
# Epoch 25/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6833 - dice_coef_liver: 0.9714 - dice_coef_tumor: 0.9179 - iou_liver: 0.9443 - iou_tumor: 0.8523 - sensitivity_liver: 0.9745 - sensitivity_tumor: 0.9137 - specificity_liver: 0.9981 - specificity_tumor: 0.9998
# Epoch 25: val_loss improved from 0.68550 to 0.68514, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 524s 626ms/step - loss: 0.6833 - dice_coef_liver: 0.9714 - dice_coef_tumor: 0.9179 - iou_liver: 0.9443 - iou_tumor: 0.8523 - sensitivity_liver: 0.9745 - sensitivity_tumor: 0.9137 - specificity_liver: 0.9981 - specificity_tumor: 0.9998 - val_loss: 0.6851 - val_dice_coef_liver: 0.9705 - val_dice_coef_tumor: 0.9032 - val_iou_liver: 0.9428 - val_iou_tumor: 0.8298 - val_sensitivity_liver: 0.9774 - val_sensitivity_tumor: 0.9068 - val_specificity_liver: 0.9977 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
# Epoch 26/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6833 - dice_coef_liver: 0.9713 - dice_coef_tumor: 0.9179 - iou_liver: 0.9442 - iou_tumor: 0.8515 - sensitivity_liver: 0.9745 - sensitivity_tumor: 0.9138 - specificity_liver: 0.9981 - specificity_tumor: 0.9998
# Epoch 26: val_loss did not improve from 0.68514
# 836/836 [==============================] - 519s 621ms/step - loss: 0.6833 - dice_coef_liver: 0.9713 - dice_coef_tumor: 0.9179 - iou_liver: 0.9442 - iou_tumor: 0.8515 - sensitivity_liver: 0.9745 - sensitivity_tumor: 0.9138 - specificity_liver: 0.9981 - specificity_tumor: 0.9998 - val_loss: 0.6858 - val_dice_coef_liver: 0.9688 - val_dice_coef_tumor: 0.8994 - val_iou_liver: 0.9395 - val_iou_tumor: 0.8252 - val_sensitivity_liver: 0.9722 - val_sensitivity_tumor: 0.9027 - val_specificity_liver: 0.9979 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
# Epoch 27/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6832 - dice_coef_liver: 0.9714 - dice_coef_tumor: 0.9190 - iou_liver: 0.9443 - iou_tumor: 0.8536 - sensitivity_liver: 0.9746 - sensitivity_tumor: 0.9153 - specificity_liver: 0.9981 - specificity_tumor: 0.9998
# Epoch 27: val_loss improved from 0.68514 to 0.68473, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 520s 621ms/step - loss: 0.6832 - dice_coef_liver: 0.9714 - dice_coef_tumor: 0.9190 - iou_liver: 0.9443 - iou_tumor: 0.8536 - sensitivity_liver: 0.9746 - sensitivity_tumor: 0.9153 - specificity_liver: 0.9981 - specificity_tumor: 0.9998 - val_loss: 0.6847 - val_dice_coef_liver: 0.9708 - val_dice_coef_tumor: 0.9067 - val_iou_liver: 0.9433 - val_iou_tumor: 0.8350 - val_sensitivity_liver: 0.9779 - val_sensitivity_tumor: 0.9147 - val_specificity_liver: 0.9977 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
# Epoch 28/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6826 - dice_coef_liver: 0.9720 - dice_coef_tumor: 0.9233 - iou_liver: 0.9455 - iou_tumor: 0.8606 - sensitivity_liver: 0.9752 - sensitivity_tumor: 0.9194 - specificity_liver: 0.9982 - specificity_tumor: 0.9998
# Epoch 28: val_loss did not improve from 0.68473
# 836/836 [==============================] - 519s 620ms/step - loss: 0.6826 - dice_coef_liver: 0.9720 - dice_coef_tumor: 0.9233 - iou_liver: 0.9455 - iou_tumor: 0.8606 - sensitivity_liver: 0.9752 - sensitivity_tumor: 0.9194 - specificity_liver: 0.9982 - specificity_tumor: 0.9998 - val_loss: 0.6848 - val_dice_coef_liver: 0.9711 - val_dice_coef_tumor: 0.9056 - val_iou_liver: 0.9439 - val_iou_tumor: 0.8326 - val_sensitivity_liver: 0.9758 - val_sensitivity_tumor: 0.9266 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9996 - lr: 3.0000e-05
# Epoch 29/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6824 - dice_coef_liver: 0.9723 - dice_coef_tumor: 0.9252 - iou_liver: 0.9460 - iou_tumor: 0.8633 - sensitivity_liver: 0.9754 - sensitivity_tumor: 0.9213 - specificity_liver: 0.9982 - specificity_tumor: 0.9998
# Epoch 29: val_loss improved from 0.68473 to 0.68439, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 520s 621ms/step - loss: 0.6824 - dice_coef_liver: 0.9723 - dice_coef_tumor: 0.9252 - iou_liver: 0.9460 - iou_tumor: 0.8633 - sensitivity_liver: 0.9754 - sensitivity_tumor: 0.9213 - specificity_liver: 0.9982 - specificity_tumor: 0.9998 - val_loss: 0.6844 - val_dice_coef_liver: 0.9716 - val_dice_coef_tumor: 0.9086 - val_iou_liver: 0.9448 - val_iou_tumor: 0.8381 - val_sensitivity_liver: 0.9764 - val_sensitivity_tumor: 0.9148 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
# Epoch 30/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6826 - dice_coef_liver: 0.9725 - dice_coef_tumor: 0.9232 - iou_liver: 0.9465 - iou_tumor: 0.8607 - sensitivity_liver: 0.9756 - sensitivity_tumor: 0.9202 - specificity_liver: 0.9982 - specificity_tumor: 0.9998
# Epoch 30: val_loss did not improve from 0.68439
# 836/836 [==============================] - 521s 622ms/step - loss: 0.6826 - dice_coef_liver: 0.9725 - dice_coef_tumor: 0.9232 - iou_liver: 0.9465 - iou_tumor: 0.8607 - sensitivity_liver: 0.9756 - sensitivity_tumor: 0.9202 - specificity_liver: 0.9982 - specificity_tumor: 0.9998 - val_loss: 0.6849 - val_dice_coef_liver: 0.9711 - val_dice_coef_tumor: 0.9045 - val_iou_liver: 0.9438 - val_iou_tumor: 0.8318 - val_sensitivity_liver: 0.9775 - val_sensitivity_tumor: 0.9183 - val_specificity_liver: 0.9978 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
# Epoch 31/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6823 - dice_coef_liver: 0.9726 - dice_coef_tumor: 0.9258 - iou_liver: 0.9466 - iou_tumor: 0.8645 - sensitivity_liver: 0.9757 - sensitivity_tumor: 0.9218 - specificity_liver: 0.9982 - specificity_tumor: 0.9998
# Epoch 31: val_loss did not improve from 0.68439
# 836/836 [==============================] - 519s 620ms/step - loss: 0.6823 - dice_coef_liver: 0.9726 - dice_coef_tumor: 0.9258 - iou_liver: 0.9466 - iou_tumor: 0.8645 - sensitivity_liver: 0.9757 - sensitivity_tumor: 0.9218 - specificity_liver: 0.9982 - specificity_tumor: 0.9998 - val_loss: 0.6851 - val_dice_coef_liver: 0.9681 - val_dice_coef_tumor: 0.9073 - val_iou_liver: 0.9383 - val_iou_tumor: 0.8365 - val_sensitivity_liver: 0.9833 - val_sensitivity_tumor: 0.9190 - val_specificity_liver: 0.9970 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
# Epoch 32/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6831 - dice_coef_liver: 0.9723 - dice_coef_tumor: 0.9190 - iou_liver: 0.9461 - iou_tumor: 0.8544 - sensitivity_liver: 0.9755 - sensitivity_tumor: 0.9126 - specificity_liver: 0.9982 - specificity_tumor: 0.9998
# Epoch 32: val_loss did not improve from 0.68439
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 836/836 [==============================] - 519s 621ms/step - loss: 0.6831 - dice_coef_liver: 0.9723 - dice_coef_tumor: 0.9190 - iou_liver: 0.9461 - iou_tumor: 0.8544 - sensitivity_liver: 0.9755 - sensitivity_tumor: 0.9126 - specificity_liver: 0.9982 - specificity_tumor: 0.9998 - val_loss: 0.6852 - val_dice_coef_liver: 0.9709 - val_dice_coef_tumor: 0.9022 - val_iou_liver: 0.9435 - val_iou_tumor: 0.8300 - val_sensitivity_liver: 0.9785 - val_sensitivity_tumor: 0.9108 - val_specificity_liver: 0.9977 - val_specificity_tumor: 0.9997 - lr: 3.0000e-05
# Epoch 33/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6821 - dice_coef_liver: 0.9728 - dice_coef_tumor: 0.9266 - iou_liver: 0.9471 - iou_tumor: 0.8667 - sensitivity_liver: 0.9759 - sensitivity_tumor: 0.9221 - specificity_liver: 0.9982 - specificity_tumor: 0.9998
# Epoch 33: val_loss improved from 0.68439 to 0.68429, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 522s 624ms/step - loss: 0.6821 - dice_coef_liver: 0.9728 - dice_coef_tumor: 0.9266 - iou_liver: 0.9471 - iou_tumor: 0.8667 - sensitivity_liver: 0.9759 - sensitivity_tumor: 0.9221 - specificity_liver: 0.9982 - specificity_tumor: 0.9998 - val_loss: 0.6843 - val_dice_coef_liver: 0.9721 - val_dice_coef_tumor: 0.9089 - val_iou_liver: 0.9457 - val_iou_tumor: 0.8404 - val_sensitivity_liver: 0.9765 - val_sensitivity_tumor: 0.9142 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9997 - lr: 9.0000e-06
# Epoch 34/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6817 - dice_coef_liver: 0.9731 - dice_coef_tumor: 0.9303 - iou_liver: 0.9477 - iou_tumor: 0.8716 - sensitivity_liver: 0.9762 - sensitivity_tumor: 0.9266 - specificity_liver: 0.9982 - specificity_tumor: 0.9998
# Epoch 34: val_loss improved from 0.68429 to 0.68408, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 521s 622ms/step - loss: 0.6817 - dice_coef_liver: 0.9731 - dice_coef_tumor: 0.9303 - iou_liver: 0.9477 - iou_tumor: 0.8716 - sensitivity_liver: 0.9762 - sensitivity_tumor: 0.9266 - specificity_liver: 0.9982 - specificity_tumor: 0.9998 - val_loss: 0.6841 - val_dice_coef_liver: 0.9724 - val_dice_coef_tumor: 0.9104 - val_iou_liver: 0.9463 - val_iou_tumor: 0.8413 - val_sensitivity_liver: 0.9756 - val_sensitivity_tumor: 0.9231 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9997 - lr: 9.0000e-06
# Epoch 35/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6816 - dice_coef_liver: 0.9734 - dice_coef_tumor: 0.9305 - iou_liver: 0.9483 - iou_tumor: 0.8724 - sensitivity_liver: 0.9766 - sensitivity_tumor: 0.9261 - specificity_liver: 0.9982 - specificity_tumor: 0.9998
# Epoch 35: val_loss did not improve from 0.68408
# 836/836 [==============================] - 519s 621ms/step - loss: 0.6816 - dice_coef_liver: 0.9734 - dice_coef_tumor: 0.9305 - iou_liver: 0.9483 - iou_tumor: 0.8724 - sensitivity_liver: 0.9766 - sensitivity_tumor: 0.9261 - specificity_liver: 0.9982 - specificity_tumor: 0.9998 - val_loss: 0.6842 - val_dice_coef_liver: 0.9721 - val_dice_coef_tumor: 0.9101 - val_iou_liver: 0.9458 - val_iou_tumor: 0.8410 - val_sensitivity_liver: 0.9791 - val_sensitivity_tumor: 0.9203 - val_specificity_liver: 0.9978 - val_specificity_tumor: 0.9997 - lr: 9.0000e-06
# Epoch 36/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6816 - dice_coef_liver: 0.9736 - dice_coef_tumor: 0.9302 - iou_liver: 0.9486 - iou_tumor: 0.8729 - sensitivity_liver: 0.9766 - sensitivity_tumor: 0.9265 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 36: val_loss improved from 0.68408 to 0.68386, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 520s 622ms/step - loss: 0.6816 - dice_coef_liver: 0.9736 - dice_coef_tumor: 0.9302 - iou_liver: 0.9486 - iou_tumor: 0.8729 - sensitivity_liver: 0.9766 - sensitivity_tumor: 0.9265 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6839 - val_dice_coef_liver: 0.9726 - val_dice_coef_tumor: 0.9121 - val_iou_liver: 0.9466 - val_iou_tumor: 0.8436 - val_sensitivity_liver: 0.9756 - val_sensitivity_tumor: 0.9245 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9997 - lr: 9.0000e-06
# Epoch 37/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6813 - dice_coef_liver: 0.9737 - dice_coef_tumor: 0.9331 - iou_liver: 0.9487 - iou_tumor: 0.8763 - sensitivity_liver: 0.9767 - sensitivity_tumor: 0.9296 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 37: val_loss improved from 0.68386 to 0.68380, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 520s 621ms/step - loss: 0.6813 - dice_coef_liver: 0.9737 - dice_coef_tumor: 0.9331 - iou_liver: 0.9487 - iou_tumor: 0.8763 - sensitivity_liver: 0.9767 - sensitivity_tumor: 0.9296 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6838 - val_dice_coef_liver: 0.9727 - val_dice_coef_tumor: 0.9126 - val_iou_liver: 0.9468 - val_iou_tumor: 0.8448 - val_sensitivity_liver: 0.9769 - val_sensitivity_tumor: 0.9227 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9997 - lr: 9.0000e-06
# Epoch 38/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6815 - dice_coef_liver: 0.9738 - dice_coef_tumor: 0.9307 - iou_liver: 0.9490 - iou_tumor: 0.8734 - sensitivity_liver: 0.9769 - sensitivity_tumor: 0.9266 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 38: val_loss did not improve from 0.68380
# 836/836 [==============================] - 519s 620ms/step - loss: 0.6815 - dice_coef_liver: 0.9738 - dice_coef_tumor: 0.9307 - iou_liver: 0.9490 - iou_tumor: 0.8734 - sensitivity_liver: 0.9769 - sensitivity_tumor: 0.9266 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6839 - val_dice_coef_liver: 0.9725 - val_dice_coef_tumor: 0.9124 - val_iou_liver: 0.9465 - val_iou_tumor: 0.8442 - val_sensitivity_liver: 0.9781 - val_sensitivity_tumor: 0.9277 - val_specificity_liver: 0.9979 - val_specificity_tumor: 0.9997 - lr: 9.0000e-06
# Epoch 39/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6813 - dice_coef_liver: 0.9739 - dice_coef_tumor: 0.9321 - iou_liver: 0.9491 - iou_tumor: 0.8764 - sensitivity_liver: 0.9770 - sensitivity_tumor: 0.9280 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 39: val_loss did not improve from 0.68380
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 836/836 [==============================] - 522s 624ms/step - loss: 0.6813 - dice_coef_liver: 0.9739 - dice_coef_tumor: 0.9321 - iou_liver: 0.9491 - iou_tumor: 0.8764 - sensitivity_liver: 0.9770 - sensitivity_tumor: 0.9280 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6838 - val_dice_coef_liver: 0.9729 - val_dice_coef_tumor: 0.9120 - val_iou_liver: 0.9472 - val_iou_tumor: 0.8448 - val_sensitivity_liver: 0.9779 - val_sensitivity_tumor: 0.9225 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9997 - lr: 9.0000e-06
# Epoch 40/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6812 - dice_coef_liver: 0.9741 - dice_coef_tumor: 0.9330 - iou_liver: 0.9495 - iou_tumor: 0.8779 - sensitivity_liver: 0.9772 - sensitivity_tumor: 0.9284 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 40: val_loss improved from 0.68380 to 0.68374, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 521s 623ms/step - loss: 0.6812 - dice_coef_liver: 0.9741 - dice_coef_tumor: 0.9330 - iou_liver: 0.9495 - iou_tumor: 0.8779 - sensitivity_liver: 0.9772 - sensitivity_tumor: 0.9284 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6837 - val_dice_coef_liver: 0.9727 - val_dice_coef_tumor: 0.9129 - val_iou_liver: 0.9469 - val_iou_tumor: 0.8449 - val_sensitivity_liver: 0.9786 - val_sensitivity_tumor: 0.9264 - val_specificity_liver: 0.9979 - val_specificity_tumor: 0.9997 - lr: 2.7000e-06
# Epoch 41/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6812 - dice_coef_liver: 0.9742 - dice_coef_tumor: 0.9334 - iou_liver: 0.9497 - iou_tumor: 0.8786 - sensitivity_liver: 0.9773 - sensitivity_tumor: 0.9294 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 41: val_loss improved from 0.68374 to 0.68356, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 523s 625ms/step - loss: 0.6812 - dice_coef_liver: 0.9742 - dice_coef_tumor: 0.9334 - iou_liver: 0.9497 - iou_tumor: 0.8786 - sensitivity_liver: 0.9773 - sensitivity_tumor: 0.9294 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6836 - val_dice_coef_liver: 0.9730 - val_dice_coef_tumor: 0.9143 - val_iou_liver: 0.9475 - val_iou_tumor: 0.8476 - val_sensitivity_liver: 0.9775 - val_sensitivity_tumor: 0.9248 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9997 - lr: 2.7000e-06
# Epoch 42/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6811 - dice_coef_liver: 0.9742 - dice_coef_tumor: 0.9335 - iou_liver: 0.9497 - iou_tumor: 0.8782 - sensitivity_liver: 0.9773 - sensitivity_tumor: 0.9297 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 42: val_loss did not improve from 0.68356
# 836/836 [==============================] - 522s 624ms/step - loss: 0.6811 - dice_coef_liver: 0.9742 - dice_coef_tumor: 0.9335 - iou_liver: 0.9497 - iou_tumor: 0.8782 - sensitivity_liver: 0.9773 - sensitivity_tumor: 0.9297 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6836 - val_dice_coef_liver: 0.9729 - val_dice_coef_tumor: 0.9139 - val_iou_liver: 0.9473 - val_iou_tumor: 0.8468 - val_sensitivity_liver: 0.9778 - val_sensitivity_tumor: 0.9229 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9997 - lr: 2.7000e-06
# Epoch 43/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6812 - dice_coef_liver: 0.9743 - dice_coef_tumor: 0.9328 - iou_liver: 0.9499 - iou_tumor: 0.8787 - sensitivity_liver: 0.9775 - sensitivity_tumor: 0.9289 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 43: val_loss did not improve from 0.68356
# 836/836 [==============================] - 522s 624ms/step - loss: 0.6812 - dice_coef_liver: 0.9743 - dice_coef_tumor: 0.9328 - iou_liver: 0.9499 - iou_tumor: 0.8787 - sensitivity_liver: 0.9775 - sensitivity_tumor: 0.9289 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6837 - val_dice_coef_liver: 0.9730 - val_dice_coef_tumor: 0.9126 - val_iou_liver: 0.9475 - val_iou_tumor: 0.8451 - val_sensitivity_liver: 0.9767 - val_sensitivity_tumor: 0.9260 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9997 - lr: 2.7000e-06
# Epoch 44/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6810 - dice_coef_liver: 0.9743 - dice_coef_tumor: 0.9347 - iou_liver: 0.9499 - iou_tumor: 0.8795 - sensitivity_liver: 0.9774 - sensitivity_tumor: 0.9308 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 44: val_loss did not improve from 0.68356
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1e-06.
# 836/836 [==============================] - 522s 624ms/step - loss: 0.6810 - dice_coef_liver: 0.9743 - dice_coef_tumor: 0.9347 - iou_liver: 0.9499 - iou_tumor: 0.8795 - sensitivity_liver: 0.9774 - sensitivity_tumor: 0.9308 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6837 - val_dice_coef_liver: 0.9730 - val_dice_coef_tumor: 0.9128 - val_iou_liver: 0.9475 - val_iou_tumor: 0.8455 - val_sensitivity_liver: 0.9770 - val_sensitivity_tumor: 0.9236 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9997 - lr: 2.7000e-06
# Epoch 45/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6812 - dice_coef_liver: 0.9743 - dice_coef_tumor: 0.9325 - iou_liver: 0.9500 - iou_tumor: 0.8782 - sensitivity_liver: 0.9774 - sensitivity_tumor: 0.9282 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 45: val_loss did not improve from 0.68356
# 836/836 [==============================] - 519s 620ms/step - loss: 0.6812 - dice_coef_liver: 0.9743 - dice_coef_tumor: 0.9325 - iou_liver: 0.9500 - iou_tumor: 0.8782 - sensitivity_liver: 0.9774 - sensitivity_tumor: 0.9282 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6836 - val_dice_coef_liver: 0.9731 - val_dice_coef_tumor: 0.9138 - val_iou_liver: 0.9476 - val_iou_tumor: 0.8466 - val_sensitivity_liver: 0.9773 - val_sensitivity_tumor: 0.9264 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9997 - lr: 1.0000e-06
# Epoch 46/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6811 - dice_coef_liver: 0.9744 - dice_coef_tumor: 0.9341 - iou_liver: 0.9500 - iou_tumor: 0.8794 - sensitivity_liver: 0.9775 - sensitivity_tumor: 0.9303 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 46: val_loss improved from 0.68356 to 0.68353, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 519s 620ms/step - loss: 0.6811 - dice_coef_liver: 0.9744 - dice_coef_tumor: 0.9341 - iou_liver: 0.9500 - iou_tumor: 0.8794 - sensitivity_liver: 0.9775 - sensitivity_tumor: 0.9303 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6835 - val_dice_coef_liver: 0.9730 - val_dice_coef_tumor: 0.9146 - val_iou_liver: 0.9475 - val_iou_tumor: 0.8484 - val_sensitivity_liver: 0.9774 - val_sensitivity_tumor: 0.9263 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9997 - lr: 1.0000e-06
# Epoch 47/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6810 - dice_coef_liver: 0.9744 - dice_coef_tumor: 0.9343 - iou_liver: 0.9501 - iou_tumor: 0.8802 - sensitivity_liver: 0.9775 - sensitivity_tumor: 0.9302 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 47: val_loss did not improve from 0.68353
# 836/836 [==============================] - 519s 621ms/step - loss: 0.6810 - dice_coef_liver: 0.9744 - dice_coef_tumor: 0.9343 - iou_liver: 0.9501 - iou_tumor: 0.8802 - sensitivity_liver: 0.9775 - sensitivity_tumor: 0.9302 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6837 - val_dice_coef_liver: 0.9731 - val_dice_coef_tumor: 0.9127 - val_iou_liver: 0.9476 - val_iou_tumor: 0.8458 - val_sensitivity_liver: 0.9776 - val_sensitivity_tumor: 0.9230 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9997 - lr: 1.0000e-06
# Epoch 48/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6813 - dice_coef_liver: 0.9744 - dice_coef_tumor: 0.9320 - iou_liver: 0.9501 - iou_tumor: 0.8780 - sensitivity_liver: 0.9775 - sensitivity_tumor: 0.9282 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 48: val_loss did not improve from 0.68353
# 836/836 [==============================] - 519s 620ms/step - loss: 0.6813 - dice_coef_liver: 0.9744 - dice_coef_tumor: 0.9320 - iou_liver: 0.9501 - iou_tumor: 0.8780 - sensitivity_liver: 0.9775 - sensitivity_tumor: 0.9282 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6837 - val_dice_coef_liver: 0.9731 - val_dice_coef_tumor: 0.9131 - val_iou_liver: 0.9476 - val_iou_tumor: 0.8463 - val_sensitivity_liver: 0.9776 - val_sensitivity_tumor: 0.9221 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9997 - lr: 1.0000e-06
# Epoch 49/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6809 - dice_coef_liver: 0.9744 - dice_coef_tumor: 0.9354 - iou_liver: 0.9501 - iou_tumor: 0.8816 - sensitivity_liver: 0.9775 - sensitivity_tumor: 0.9308 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 49: val_loss did not improve from 0.68353
# 836/836 [==============================] - 519s 620ms/step - loss: 0.6809 - dice_coef_liver: 0.9744 - dice_coef_tumor: 0.9354 - iou_liver: 0.9501 - iou_tumor: 0.8816 - sensitivity_liver: 0.9775 - sensitivity_tumor: 0.9308 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6837 - val_dice_coef_liver: 0.9730 - val_dice_coef_tumor: 0.9134 - val_iou_liver: 0.9475 - val_iou_tumor: 0.8468 - val_sensitivity_liver: 0.9776 - val_sensitivity_tumor: 0.9243 - val_specificity_liver: 0.9980 - val_specificity_tumor: 0.9997 - lr: 1.0000e-06
# Epoch 50/50
# 836/836 [==============================] - ETA: 0s - loss: 0.6809 - dice_coef_liver: 0.9745 - dice_coef_tumor: 0.9354 - iou_liver: 0.9502 - iou_tumor: 0.8822 - sensitivity_liver: 0.9776 - sensitivity_tumor: 0.9315 - specificity_liver: 0.9983 - specificity_tumor: 0.9998
# Epoch 50: val_loss improved from 0.68353 to 0.68346, saving model to /kaggle/working/WNet_Res50.h5
# 836/836 [==============================] - 519s 621ms/step - loss: 0.6809 - dice_coef_liver: 0.9745 - dice_coef_tumor: 0.9354 - iou_liver: 0.9502 - iou_tumor: 0.8822 - sensitivity_liver: 0.9776 - sensitivity_tumor: 0.9315 - specificity_liver: 0.9983 - specificity_tumor: 0.9998 - val_loss: 0.6835 - val_dice_coef_liver: 0.9731 - val_dice_coef_tumor: 0.9150 - val_iou_liver: 0.9477 - val_iou_tumor: 0.8485 - val_sensitivity_liver: 0.9778 - val_sensitivity_tumor: 0.9249 - val_specificity_liver: 0.9981 - val_specificity_tumor: 0.9997 - lr: 1.0000e-06

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'dice_coef_liver', 'dice_coef_tumor', 'iou_liver', 'iou_tumor', 'sensitivity_liver', 'sensitivity_tumor', 'specificity_liver', 'specificity_tumor', 'val_loss', 'val_dice_coef_liver', 'val_dice_coef_tumor', 'val_iou_liver', 'val_iou_tumor', 'val_sensitivity_liver', 'val_sensitivity_tumor', 'val_specificity_liver', 'val_specificity_tumor', 'lr'])

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WNet_Res50', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score_tumor=history['iou_tumor']
val_iou_score_tumor=history['val_iou_tumor']

iou_score_liver=history['iou_liver']
val_iou_score_liver=history['val_iou_liver']

loss=history['loss']
val_loss=history['val_loss']

train_dice_tumor=history['dice_coef_tumor']
val_dice_tumor=history['val_dice_coef_tumor']

train_dice_liver=history['dice_coef_liver']
val_dice_liver=history['val_dice_coef_liver']


epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score_liver, 'b', label='Training IOU liver', linewidth=1.5)
axes[1].plot(epoch, val_iou_score_liver, 'b--', label='Val IOU Liver', linewidth=1.5)
axes[1].plot(epoch, iou_score_tumor, 'r', label='Training IOU tumor', linewidth=1.5)
axes[1].plot(epoch, val_iou_score_tumor, 'r--', label='Val IOU tumor', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice_liver, 'b', label='Training DC liver', linewidth=1.5)
axes[2].plot(epoch, val_dice_liver, 'b--', label='Val DC liver', linewidth=1.5)
axes[2].plot(epoch, train_dice_tumor, 'r', label='Training DC tumor', linewidth=1.5)
axes[2].plot(epoch, val_dice_tumor, 'r--', label='Val DC tumor', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()


# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Testing Model

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                #mask = mask.astype(np.int32)
    

            """augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])"""
            images.append(image)
            masks.append(mask)
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        #masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        masks = np.array(tf.one_hot(masks, 3, dtype = tf.float32))
        return  images, masks

# Example usage of the CustomDataGenerator
test_generator = CustomDataGenerator(df_test, batch_size=16, image_size=(256, 256), shuffle=True)

# %%
results = model.evaluate(test_generator)
# Out:
# 216/216 [==============================] - 122s 564ms/step - loss: 0.6829 - dice_coef_liver: 0.9724 - dice_coef_tumor: 0.9211 - iou_liver: 0.9463 - iou_tumor: 0.8555 - sensitivity_liver: 0.9773 - sensitivity_tumor: 0.9308 - specificity_liver: 0.9980 - specificity_tumor: 0.9997

# %%
#!zip -r weights_WNet_Res50_AT_CL.zip /kaggle/working/WNet_maxpool.h5

# %%
#from IPython.display import FileLink
#FileLink(r'weights_WNet_Res50_AT_CL.zip')
